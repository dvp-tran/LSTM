# %% [markdown]
# # Training a caption generator
# This notebook implements the Show and Tell caption generation model described in our corresponding article. The key portions of this notebook are loading the data with `get_data`, processing the text data with `preProBuildWordVocab`, building the `Caption_Generator` in `train` and tracking our progress.
#
# *Note:* create a directory to save your tensorflow models and assign this directory path to the `model_path` variable.

# %%
import math
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import pickle
import cv2
import skimage

import tensorflow.python.platform
from keras.preprocessing import sequence
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
get_available_gpus()
# Out:
# [u'/gpu:0']

# %% [markdown]
# # Downloading Data
# As mentioned in the README, in order to run this notebook, you will need VGG-16 image embeddings for the Flickr-30K dataset. These image embeddings are available from our [Google Drive](https://drive.google.com/file/d/0B5o40yxdA9PqTnJuWGVkcFlqcG8/view?usp=sharing).
#
# Additionally, you will need the corresponding captions for these images (`results_20130124.token`), which can also be downloaded from our [Google Drive](https://drive.google.com/file/d/0B2vTU3h54lTydXFjSVM5T2t4WmM/view?usp=sharing).
#
# Place all of these downloads in the `./data/` folder.
#
# The feature embeddings will be in `./data/feats.npy` and the embeddings' corresponding captions will be saved to `./data/results_20130124.token` .

# %%
model_path = './models/tensorflow'
feature_path = './data/feats.npy'
annotation_path = './data/results_20130124.token'

# %% [markdown]
# ## Loading data
# Parse the image embedding features from the Flickr30k dataset `./data/feats.npy`, and load the caption data via `pandas` from `./data/results_20130124.token`

# %%
def get_data(annotation_path, feature_path):
    annotations = pd.read_table(annotation_path, sep='\t', header=None, names=['image', 'caption'])
    return np.load(feature_path,'r'), annotations['caption'].values

# %%
feats, captions = get_data(annotation_path, feature_path)

# %%
print(feats.shape)
print(captions.shape)
# Out:
# (158915, 4096)
# (158915,)

# %%
print(captions[0])
# Out:
# Two young guys with shaggy hair look at their hands while hanging out in the yard .

# %%
def preProBuildWordVocab(sentence_iterator, word_count_threshold=30): # function from Andre Karpathy's NeuralTalk
    print('preprocessing %d word vocab' % (word_count_threshold, ))
    word_counts = {}
    nsents = 0
    for sent in sentence_iterator:
      nsents += 1
      for w in sent.lower().split(' '):
        word_counts[w] = word_counts.get(w, 0) + 1
    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
    print('preprocessed words %d -> %d' % (len(word_counts), len(vocab)))

    ixtoword = {}
    ixtoword[0] = '.'  
    wordtoix = {}
    wordtoix['#START#'] = 0 
    ix = 1
    for w in vocab:
      wordtoix[w] = ix
      ixtoword[ix] = w
      ix += 1

    word_counts['.'] = nsents
    bias_init_vector = np.array([1.0*word_counts[ixtoword[i]] for i in ixtoword])
    bias_init_vector /= np.sum(bias_init_vector) 
    bias_init_vector = np.log(bias_init_vector)
    bias_init_vector -= np.max(bias_init_vector) 
    return wordtoix, ixtoword, bias_init_vector.astype(np.float32)

# %%
class Caption_Generator():
    def __init__(self, dim_in, dim_embed, dim_hidden, batch_size, n_lstm_steps, n_words, init_b):

        self.dim_in = dim_in
        self.dim_embed = dim_embed
        self.dim_hidden = dim_hidden
        self.batch_size = batch_size
        self.n_lstm_steps = n_lstm_steps
        self.n_words = n_words
        
        # declare the variables to be used for our word embeddings
        with tf.device("/cpu:0"):
            self.word_embedding = tf.Variable(tf.random_uniform([self.n_words, self.dim_embed], -0.1, 0.1), name='word_embedding')

        self.embedding_bias = tf.Variable(tf.zeros([dim_embed]), name='embedding_bias')
        
        # declare the LSTM itself
        self.lstm = tf.contrib.rnn.BasicLSTMCell(dim_hidden)
        
        # declare the variables to be used to embed the image feature embedding to the word embedding space
        self.img_embedding = tf.Variable(tf.random_uniform([dim_in, dim_hidden], -0.1, 0.1), name='img_embedding')
        self.img_embedding_bias = tf.Variable(tf.zeros([dim_hidden]), name='img_embedding_bias')

        # declare the variables to go from an LSTM output to a word encoding output
        self.word_encoding = tf.Variable(tf.random_uniform([dim_hidden, n_words], -0.1, 0.1), name='word_encoding')
        # initialize this bias variable from the preProBuildWordVocab output
        self.word_encoding_bias = tf.Variable(init_b, name='word_encoding_bias')

    def build_model(self):
        # declaring the placeholders for our extracted image feature vectors, our caption, and our mask
        # (describes how long our caption is with an array of 0/1 values of length `maxlen`  
        img = tf.placeholder(tf.float32, [self.batch_size, self.dim_in])
        caption_placeholder = tf.placeholder(tf.int32, [self.batch_size, self.n_lstm_steps])
        mask = tf.placeholder(tf.float32, [self.batch_size, self.n_lstm_steps])
        
        # getting an initial LSTM embedding from our image_imbedding
        image_embedding = tf.matmul(img, self.img_embedding) + self.img_embedding_bias
        
        # setting initial state of our LSTM
        state = self.lstm.zero_state(self.batch_size, dtype=tf.float32)

        total_loss = 0.0
        with tf.variable_scope("RNN"):
            for i in range(self.n_lstm_steps): 
                if i > 0:
                   #if this isn’t the first iteration of our LSTM we need to get the word_embedding corresponding
                   # to the (i-1)th word in our caption 
                    with tf.device("/cpu:0"):
                        current_embedding = tf.nn.embedding_lookup(self.word_embedding, caption_placeholder[:,i-1]) + self.embedding_bias
                else:
                     #if this is the first iteration of our LSTM we utilize the embedded image as our input 
                    current_embedding = image_embedding
                if i > 0: 
                    # allows us to reuse the LSTM tensor variable on each iteration
                    tf.get_variable_scope().reuse_variables()

                out, state = self.lstm(current_embedding, state)

                
                if i > 0:
                    #get the one-hot representation of the next word in our caption 
                    labels = tf.expand_dims(caption_placeholder[:, i], 1)
                    ix_range=tf.range(0, self.batch_size, 1)
                    ixs = tf.expand_dims(ix_range, 1)
                    concat = tf.concat([ixs, labels],1)
                    onehot = tf.sparse_to_dense(
                            concat, tf.stack([self.batch_size, self.n_words]), 1.0, 0.0)


                    #perform a softmax classification to generate the next word in the caption
                    logit = tf.matmul(out, self.word_encoding) + self.word_encoding_bias
                    xentropy = tf.nn.softmax_cross_entropy_with_logits(logits=logit, labels=onehot)
                    xentropy = xentropy * mask[:,i]

                    loss = tf.reduce_sum(xentropy)
                    total_loss += loss

            total_loss = total_loss / tf.reduce_sum(mask[:,1:])
            return total_loss, img,  caption_placeholder, mask

# %%
### Parameters ###
dim_embed = 256
dim_hidden = 256
dim_in = 4096
batch_size = 128
momentum = 0.9
n_epochs = 25

def train(learning_rate=0.001, continue_training=False):
    
    tf.reset_default_graph()

    feats, captions = get_data(annotation_path, feature_path)
    wordtoix, ixtoword, init_b = preProBuildWordVocab(captions)

    np.save('data/ixtoword', ixtoword)

    index = (np.arange(len(feats)).astype(int))
    np.random.shuffle(index)


    sess = tf.InteractiveSession()
    n_words = len(wordtoix)
    maxlen = np.max( [x for x in map(lambda x: len(x.split(' ')), captions) ] )
    caption_generator = Caption_Generator(dim_in, dim_hidden, dim_embed, batch_size, maxlen+2, n_words, init_b)

    loss, image, sentence, mask = caption_generator.build_model()

    saver = tf.train.Saver(max_to_keep=100)
    train_op = tf.train.AdamOptimizer(learning_rate).minimize(loss)
    tf.global_variables_initializer().run()

    if continue_training:
        saver.restore(sess,tf.train.latest_checkpoint(model_path))

    for epoch in range(n_epochs):
        for start, end in zip( range(0, len(index), batch_size), range(batch_size, len(index), batch_size)):

            current_feats = feats[index[start:end]]
            current_captions = captions[index[start:end]]
            current_caption_ind = [x for x in map(lambda cap: [wordtoix[word] for word in cap.lower().split(' ')[:-1] if word in wordtoix], current_captions)]

            current_caption_matrix = sequence.pad_sequences(current_caption_ind, padding='post', maxlen=maxlen+1)
            current_caption_matrix = np.hstack( [np.full( (len(current_caption_matrix),1), 0), current_caption_matrix] )

            current_mask_matrix = np.zeros((current_caption_matrix.shape[0], current_caption_matrix.shape[1]))
            nonzeros = np.array([x for x in map(lambda x: (x != 0).sum()+2, current_caption_matrix )])

            for ind, row in enumerate(current_mask_matrix):
                row[:nonzeros[ind]] = 1

            _, loss_value = sess.run([train_op, loss], feed_dict={
                image: current_feats.astype(np.float32),
                sentence : current_caption_matrix.astype(np.int32),
                mask : current_mask_matrix.astype(np.float32)
                })

            print("Current Cost: ", loss_value, "\t Epoch {}/{}".format(epoch, n_epochs), "\t Iter {}/{}".format(start,len(feats)))

        print("Saving the model from epoch: ", epoch)
        saver.save(sess, os.path.join(model_path, 'model'), global_step=epoch)
        learning_rate *= 0.95

# %%
try:
    train()
except KeyboardInterrupt:
    print('Exiting Training')
# Out:
# preprocessing 30 word vocab
# preprocessed words 20326 -> 2942
# /home/dvp_tran_tsp/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full((128, 1), 0) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# ('Current Cost: ', 5.4705009, '\t Epoch 0/25', '\t Iter 0/158915')
# ('Current Cost: ', 5.4165554, '\t Epoch 0/25', '\t Iter 128/158915')
# ('Current Cost: ', 5.3723087, '\t Epoch 0/25', '\t Iter 256/158915')
# ('Current Cost: ', 5.3748512, '\t Epoch 0/25', '\t Iter 384/158915')
# ('Current Cost: ', 5.3560524, '\t Epoch 0/25', '\t Iter 512/158915')
# ('Current Cost: ', 5.3057537, '\t Epoch 0/25', '\t Iter 640/158915')
# ('Current Cost: ', 5.19453, '\t Epoch 0/25', '\t Iter 768/158915')
# ('Current Cost: ', 5.3302321, '\t Epoch 0/25', '\t Iter 896/158915')
# ('Current Cost: ', 5.1843214, '\t Epoch 0/25', '\t Iter 1024/158915')
# ('Current Cost: ', 5.1666818, '\t Epoch 0/25', '\t Iter 1152/158915')
# ('Current Cost: ', 5.2109723, '\t Epoch 0/25', '\t Iter 1280/158915')
# ('Current Cost: ', 5.1901155, '\t Epoch 0/25', '\t Iter 1408/158915')
# ('Current Cost: ', 5.2526507, '\t Epoch 0/25', '\t Iter 1536/158915')
# ('Current Cost: ', 5.1791625, '\t Epoch 0/25', '\t Iter 1664/158915')
# ('Current Cost: ', 5.3043928, '\t Epoch 0/25', '\t Iter 1792/158915')
# ('Current Cost: ', 5.1489401, '\t Epoch 0/25', '\t Iter 1920/158915')
# ('Current Cost: ', 5.1254654, '\t Epoch 0/25', '\t Iter 2048/158915')
# ('Current Cost: ', 5.1813431, '\t Epoch 0/25', '\t Iter 2176/158915')
# ('Current Cost: ', 5.1770663, '\t Epoch 0/25', '\t Iter 2304/158915')
# ('Current Cost: ', 5.2222939, '\t Epoch 0/25', '\t Iter 2432/158915')
# ('Current Cost: ', 5.1795001, '\t Epoch 0/25', '\t Iter 2560/158915')
# ('Current Cost: ', 5.1436205, '\t Epoch 0/25', '\t Iter 2688/158915')
# ('Current Cost: ', 5.1245899, '\t Epoch 0/25', '\t Iter 2816/158915')
# ('Current Cost: ', 5.0946498, '\t Epoch 0/25', '\t Iter 2944/158915')
# ('Current Cost: ', 5.0659637, '\t Epoch 0/25', '\t Iter 3072/158915')
# ('Current Cost: ', 4.9953604, '\t Epoch 0/25', '\t Iter 3200/158915')
# ('Current Cost: ', 5.0793653, '\t Epoch 0/25', '\t Iter 3328/158915')
# ('Current Cost: ', 5.0755687, '\t Epoch 0/25', '\t Iter 3456/158915')
# ('Current Cost: ', 5.1565895, '\t Epoch 0/25', '\t Iter 3584/158915')
# ('Current Cost: ', 5.0060382, '\t Epoch 0/25', '\t Iter 3712/158915')
# ('Current Cost: ', 5.1669197, '\t Epoch 0/25', '\t Iter 3840/158915')
# ('Current Cost: ', 5.0913939, '\t Epoch 0/25', '\t Iter 3968/158915')
# ('Current Cost: ', 4.9541478, '\t Epoch 0/25', '\t Iter 4096/158915')
# ('Current Cost: ', 5.1747041, '\t Epoch 0/25', '\t Iter 4224/158915')
# ('Current Cost: ', 5.0456057, '\t Epoch 0/25', '\t Iter 4352/158915')
# ('Current Cost: ', 4.9536924, '\t Epoch 0/25', '\t Iter 4480/158915')
# ('Current Cost: ', 4.9385166, '\t Epoch 0/25', '\t Iter 4608/158915')
# ('Current Cost: ', 5.0662704, '\t Epoch 0/25', '\t Iter 4736/158915')
# ('Current Cost: ', 5.0132942, '\t Epoch 0/25', '\t Iter 4864/158915')
# ('Current Cost: ', 5.0381866, '\t Epoch 0/25', '\t Iter 4992/158915')
# ('Current Cost: ', 5.0136724, '\t Epoch 0/25', '\t Iter 5120/158915')
# ('Current Cost: ', 5.0833354, '\t Epoch 0/25', '\t Iter 5248/158915')
# ('Current Cost: ', 5.0312858, '\t Epoch 0/25', '\t Iter 5376/158915')
# ('Current Cost: ', 4.9090142, '\t Epoch 0/25', '\t Iter 5504/158915')
# ('Current Cost: ', 4.9444542, '\t Epoch 0/25', '\t Iter 5632/158915')
# ('Current Cost: ', 5.0034313, '\t Epoch 0/25', '\t Iter 5760/158915')
# ('Current Cost: ', 4.9491186, '\t Epoch 0/25', '\t Iter 5888/158915')
# ('Current Cost: ', 4.9579, '\t Epoch 0/25', '\t Iter 6016/158915')
# ('Current Cost: ', 4.9769149, '\t Epoch 0/25', '\t Iter 6144/158915')
# ('Current Cost: ', 5.0167398, '\t Epoch 0/25', '\t Iter 6272/158915')
# ('Current Cost: ', 4.8605256, '\t Epoch 0/25', '\t Iter 6400/158915')
# ('Current Cost: ', 4.8715682, '\t Epoch 0/25', '\t Iter 6528/158915')
# ('Current Cost: ', 4.8430161, '\t Epoch 0/25', '\t Iter 6656/158915')
# ('Current Cost: ', 4.9222097, '\t Epoch 0/25', '\t Iter 6784/158915')
# ('Current Cost: ', 4.9133983, '\t Epoch 0/25', '\t Iter 6912/158915')
# ('Current Cost: ', 4.8735633, '\t Epoch 0/25', '\t Iter 7040/158915')
# ('Current Cost: ', 4.9461069, '\t Epoch 0/25', '\t Iter 7168/158915')
# ('Current Cost: ', 4.9237862, '\t Epoch 0/25', '\t Iter 7296/158915')
# ('Current Cost: ', 4.7506185, '\t Epoch 0/25', '\t Iter 7424/158915')
# ('Current Cost: ', 4.8543682, '\t Epoch 0/25', '\t Iter 7552/158915')
# ('Current Cost: ', 4.7131934, '\t Epoch 0/25', '\t Iter 7680/158915')
# ('Current Cost: ', 4.8169522, '\t Epoch 0/25', '\t Iter 7808/158915')
# ('Current Cost: ', 4.7955003, '\t Epoch 0/25', '\t Iter 7936/158915')
# ('Current Cost: ', 4.7613916, '\t Epoch 0/25', '\t Iter 8064/158915')
# ('Current Cost: ', 4.7550817, '\t Epoch 0/25', '\t Iter 8192/158915')
# ('Current Cost: ', 4.8486886, '\t Epoch 0/25', '\t Iter 8320/158915')
# ('Current Cost: ', 4.687077, '\t Epoch 0/25', '\t Iter 8448/158915')
# ('Current Cost: ', 4.8905244, '\t Epoch 0/25', '\t Iter 8576/158915')
# ('Current Cost: ', 4.7250595, '\t Epoch 0/25', '\t Iter 8704/158915')
# ('Current Cost: ', 4.7135477, '\t Epoch 0/25', '\t Iter 8832/158915')
# ('Current Cost: ', 4.5645585, '\t Epoch 0/25', '\t Iter 8960/158915')
# ('Current Cost: ', 4.7066345, '\t Epoch 0/25', '\t Iter 9088/158915')
# ('Current Cost: ', 4.6408048, '\t Epoch 0/25', '\t Iter 9216/158915')
# ('Current Cost: ', 4.645184, '\t Epoch 0/25', '\t Iter 9344/158915')
# ('Current Cost: ', 4.708395, '\t Epoch 0/25', '\t Iter 9472/158915')
# ('Current Cost: ', 4.6278839, '\t Epoch 0/25', '\t Iter 9600/158915')
# ('Current Cost: ', 4.6722851, '\t Epoch 0/25', '\t Iter 9728/158915')
# ('Current Cost: ', 4.6342783, '\t Epoch 0/25', '\t Iter 9856/158915')
# ('Current Cost: ', 4.5740519, '\t Epoch 0/25', '\t Iter 9984/158915')
# ('Current Cost: ', 4.5848541, '\t Epoch 0/25', '\t Iter 10112/158915')
# ('Current Cost: ', 4.6097374, '\t Epoch 0/25', '\t Iter 10240/158915')
# ('Current Cost: ', 4.5940318, '\t Epoch 0/25', '\t Iter 10368/158915')
# ('Current Cost: ', 4.5495887, '\t Epoch 0/25', '\t Iter 10496/158915')
# ('Current Cost: ', 4.4782925, '\t Epoch 0/25', '\t Iter 10624/158915')
# ('Current Cost: ', 4.457706, '\t Epoch 0/25', '\t Iter 10752/158915')
# ('Current Cost: ', 4.4907403, '\t Epoch 0/25', '\t Iter 10880/158915')
# ('Current Cost: ', 4.5211177, '\t Epoch 0/25', '\t Iter 11008/158915')
# ('Current Cost: ', 4.5020494, '\t Epoch 0/25', '\t Iter 11136/158915')
# ('Current Cost: ', 4.5754867, '\t Epoch 0/25', '\t Iter 11264/158915')
# ('Current Cost: ', 4.5010538, '\t Epoch 0/25', '\t Iter 11392/158915')
# ('Current Cost: ', 4.4712338, '\t Epoch 0/25', '\t Iter 11520/158915')
# ('Current Cost: ', 4.4798822, '\t Epoch 0/25', '\t Iter 11648/158915')
# ('Current Cost: ', 4.459528, '\t Epoch 0/25', '\t Iter 11776/158915')
# ('Current Cost: ', 4.3752937, '\t Epoch 0/25', '\t Iter 11904/158915')
# ('Current Cost: ', 4.3960791, '\t Epoch 0/25', '\t Iter 12032/158915')
# ('Current Cost: ', 4.4364123, '\t Epoch 0/25', '\t Iter 12160/158915')
# ('Current Cost: ', 4.5594358, '\t Epoch 0/25', '\t Iter 12288/158915')
# ('Current Cost: ', 4.4675331, '\t Epoch 0/25', '\t Iter 12416/158915')
# ('Current Cost: ', 4.4079227, '\t Epoch 0/25', '\t Iter 12544/158915')
# ('Current Cost: ', 4.305306, '\t Epoch 0/25', '\t Iter 12672/158915')
# ('Current Cost: ', 4.3364582, '\t Epoch 0/25', '\t Iter 12800/158915')
# ('Current Cost: ', 4.2828264, '\t Epoch 0/25', '\t Iter 12928/158915')
# ('Current Cost: ', 4.3985229, '\t Epoch 0/25', '\t Iter 13056/158915')
# ('Current Cost: ', 4.4396806, '\t Epoch 0/25', '\t Iter 13184/158915')
# ('Current Cost: ', 4.2877631, '\t Epoch 0/25', '\t Iter 13312/158915')
# ('Current Cost: ', 4.2013211, '\t Epoch 0/25', '\t Iter 13440/158915')
# ('Current Cost: ', 4.2919636, '\t Epoch 0/25', '\t Iter 13568/158915')
# ('Current Cost: ', 4.3572087, '\t Epoch 0/25', '\t Iter 13696/158915')
# ('Current Cost: ', 4.2675862, '\t Epoch 0/25', '\t Iter 13824/158915')
# ('Current Cost: ', 4.3678389, '\t Epoch 0/25', '\t Iter 13952/158915')
# ('Current Cost: ', 4.2784748, '\t Epoch 0/25', '\t Iter 14080/158915')
# ('Current Cost: ', 4.2767882, '\t Epoch 0/25', '\t Iter 14208/158915')
# ('Current Cost: ', 4.2631035, '\t Epoch 0/25', '\t Iter 14336/158915')
# ('Current Cost: ', 4.1671247, '\t Epoch 0/25', '\t Iter 14464/158915')
# ('Current Cost: ', 4.2326097, '\t Epoch 0/25', '\t Iter 14592/158915')
# ('Current Cost: ', 4.15797, '\t Epoch 0/25', '\t Iter 14720/158915')
# ('Current Cost: ', 4.3008885, '\t Epoch 0/25', '\t Iter 14848/158915')
# ('Current Cost: ', 4.3202996, '\t Epoch 0/25', '\t Iter 14976/158915')
# ('Current Cost: ', 4.397305, '\t Epoch 0/25', '\t Iter 15104/158915')
# ('Current Cost: ', 4.3459358, '\t Epoch 0/25', '\t Iter 15232/158915')
# ('Current Cost: ', 4.2116375, '\t Epoch 0/25', '\t Iter 15360/158915')
# ('Current Cost: ', 4.2496839, '\t Epoch 0/25', '\t Iter 15488/158915')
# ('Current Cost: ', 4.0865269, '\t Epoch 0/25', '\t Iter 15616/158915')
# ('Current Cost: ', 4.2771735, '\t Epoch 0/25', '\t Iter 15744/158915')
# ('Current Cost: ', 4.3038535, '\t Epoch 0/25', '\t Iter 15872/158915')
# ('Current Cost: ', 4.012527, '\t Epoch 0/25', '\t Iter 16000/158915')
# ('Current Cost: ', 4.0992541, '\t Epoch 0/25', '\t Iter 16128/158915')
# ('Current Cost: ', 4.1624303, '\t Epoch 0/25', '\t Iter 16256/158915')
# ('Current Cost: ', 4.1343822, '\t Epoch 0/25', '\t Iter 16384/158915')
# ('Current Cost: ', 4.1264081, '\t Epoch 0/25', '\t Iter 16512/158915')
# ('Current Cost: ', 4.0676308, '\t Epoch 0/25', '\t Iter 16640/158915')
# ('Current Cost: ', 4.0764999, '\t Epoch 0/25', '\t Iter 16768/158915')
# ('Current Cost: ', 4.0715885, '\t Epoch 0/25', '\t Iter 16896/158915')
# ('Current Cost: ', 4.2105432, '\t Epoch 0/25', '\t Iter 17024/158915')
# ('Current Cost: ', 3.9730039, '\t Epoch 0/25', '\t Iter 17152/158915')
# ('Current Cost: ', 4.216341, '\t Epoch 0/25', '\t Iter 17280/158915')
# ('Current Cost: ', 4.1086226, '\t Epoch 0/25', '\t Iter 17408/158915')
# ('Current Cost: ', 4.1594195, '\t Epoch 0/25', '\t Iter 17536/158915')
# ('Current Cost: ', 4.0854373, '\t Epoch 0/25', '\t Iter 17664/158915')
# ('Current Cost: ', 4.1526504, '\t Epoch 0/25', '\t Iter 17792/158915')
# ('Current Cost: ', 4.0817952, '\t Epoch 0/25', '\t Iter 17920/158915')
# ('Current Cost: ', 4.1112809, '\t Epoch 0/25', '\t Iter 18048/158915')
# ('Current Cost: ', 4.0573087, '\t Epoch 0/25', '\t Iter 18176/158915')
# ('Current Cost: ', 3.9837871, '\t Epoch 0/25', '\t Iter 18304/158915')
# ('Current Cost: ', 4.160552, '\t Epoch 0/25', '\t Iter 18432/158915')
# ('Current Cost: ', 3.8987958, '\t Epoch 0/25', '\t Iter 18560/158915')
# ('Current Cost: ', 4.0269713, '\t Epoch 0/25', '\t Iter 18688/158915')
# ('Current Cost: ', 3.9071243, '\t Epoch 0/25', '\t Iter 18816/158915')
# ('Current Cost: ', 3.9645574, '\t Epoch 0/25', '\t Iter 18944/158915')
# ('Current Cost: ', 4.0003004, '\t Epoch 0/25', '\t Iter 19072/158915')
# ('Current Cost: ', 3.9321125, '\t Epoch 0/25', '\t Iter 19200/158915')
# ('Current Cost: ', 4.057611, '\t Epoch 0/25', '\t Iter 19328/158915')
# ('Current Cost: ', 3.878546, '\t Epoch 0/25', '\t Iter 19456/158915')
# ('Current Cost: ', 4.1211724, '\t Epoch 0/25', '\t Iter 19584/158915')
# ('Current Cost: ', 3.994365, '\t Epoch 0/25', '\t Iter 19712/158915')
# ('Current Cost: ', 3.9948614, '\t Epoch 0/25', '\t Iter 19840/158915')
# ('Current Cost: ', 3.8843405, '\t Epoch 0/25', '\t Iter 19968/158915')
# ('Current Cost: ', 3.8043041, '\t Epoch 0/25', '\t Iter 20096/158915')
# ('Current Cost: ', 3.9490967, '\t Epoch 0/25', '\t Iter 20224/158915')
# ('Current Cost: ', 4.0213947, '\t Epoch 0/25', '\t Iter 20352/158915')
# ('Current Cost: ', 4.0761528, '\t Epoch 0/25', '\t Iter 20480/158915')
# ('Current Cost: ', 3.9889588, '\t Epoch 0/25', '\t Iter 20608/158915')
# ('Current Cost: ', 3.98982, '\t Epoch 0/25', '\t Iter 20736/158915')
# ('Current Cost: ', 3.8652916, '\t Epoch 0/25', '\t Iter 20864/158915')
# ('Current Cost: ', 3.9520648, '\t Epoch 0/25', '\t Iter 20992/158915')
# ('Current Cost: ', 3.905879, '\t Epoch 0/25', '\t Iter 21120/158915')
# ('Current Cost: ', 3.9198704, '\t Epoch 0/25', '\t Iter 21248/158915')
# ('Current Cost: ', 3.9751625, '\t Epoch 0/25', '\t Iter 21376/158915')
# ('Current Cost: ', 3.8293796, '\t Epoch 0/25', '\t Iter 21504/158915')
# ('Current Cost: ', 4.0054398, '\t Epoch 0/25', '\t Iter 21632/158915')
# ('Current Cost: ', 4.0051441, '\t Epoch 0/25', '\t Iter 21760/158915')
# ('Current Cost: ', 3.9393532, '\t Epoch 0/25', '\t Iter 21888/158915')
# ('Current Cost: ', 3.9307449, '\t Epoch 0/25', '\t Iter 22016/158915')
# ('Current Cost: ', 3.9755371, '\t Epoch 0/25', '\t Iter 22144/158915')
# ('Current Cost: ', 3.7973077, '\t Epoch 0/25', '\t Iter 22272/158915')
# ('Current Cost: ', 4.0255494, '\t Epoch 0/25', '\t Iter 22400/158915')
# ('Current Cost: ', 3.9720526, '\t Epoch 0/25', '\t Iter 22528/158915')
# ('Current Cost: ', 4.032526, '\t Epoch 0/25', '\t Iter 22656/158915')
# ('Current Cost: ', 3.8347251, '\t Epoch 0/25', '\t Iter 22784/158915')
# ('Current Cost: ', 3.9258587, '\t Epoch 0/25', '\t Iter 22912/158915')
# ('Current Cost: ', 3.9177265, '\t Epoch 0/25', '\t Iter 23040/158915')
# ('Current Cost: ', 3.9144161, '\t Epoch 0/25', '\t Iter 23168/158915')
# ('Current Cost: ', 4.0115781, '\t Epoch 0/25', '\t Iter 23296/158915')
# ('Current Cost: ', 3.9451177, '\t Epoch 0/25', '\t Iter 23424/158915')
# ('Current Cost: ', 4.0009437, '\t Epoch 0/25', '\t Iter 23552/158915')
# ('Current Cost: ', 3.8996904, '\t Epoch 0/25', '\t Iter 23680/158915')
# ('Current Cost: ', 3.8839412, '\t Epoch 0/25', '\t Iter 23808/158915')
# ('Current Cost: ', 3.8960433, '\t Epoch 0/25', '\t Iter 23936/158915')
# ('Current Cost: ', 3.7959096, '\t Epoch 0/25', '\t Iter 24064/158915')
# ('Current Cost: ', 3.8353646, '\t Epoch 0/25', '\t Iter 24192/158915')
# ('Current Cost: ', 3.8651121, '\t Epoch 0/25', '\t Iter 24320/158915')
# ('Current Cost: ', 3.7964249, '\t Epoch 0/25', '\t Iter 24448/158915')
# ('Current Cost: ', 3.7558331, '\t Epoch 0/25', '\t Iter 24576/158915')
# ('Current Cost: ', 3.9785638, '\t Epoch 0/25', '\t Iter 24704/158915')
# ('Current Cost: ', 3.8184962, '\t Epoch 0/25', '\t Iter 24832/158915')
# ('Current Cost: ', 3.9155247, '\t Epoch 0/25', '\t Iter 24960/158915')
# ('Current Cost: ', 3.918189, '\t Epoch 0/25', '\t Iter 25088/158915')
# ('Current Cost: ', 3.9308884, '\t Epoch 0/25', '\t Iter 25216/158915')
# ('Current Cost: ', 3.7940183, '\t Epoch 0/25', '\t Iter 25344/158915')
# ('Current Cost: ', 3.9188755, '\t Epoch 0/25', '\t Iter 25472/158915')
# ('Current Cost: ', 3.9890103, '\t Epoch 0/25', '\t Iter 25600/158915')
# ('Current Cost: ', 3.8924923, '\t Epoch 0/25', '\t Iter 25728/158915')
# ('Current Cost: ', 3.8728411, '\t Epoch 0/25', '\t Iter 25856/158915')
# ('Current Cost: ', 3.9256444, '\t Epoch 0/25', '\t Iter 25984/158915')
# ('Current Cost: ', 3.7709653, '\t Epoch 0/25', '\t Iter 26112/158915')
# ('Current Cost: ', 3.807435, '\t Epoch 0/25', '\t Iter 26240/158915')
# ('Current Cost: ', 3.8877578, '\t Epoch 0/25', '\t Iter 26368/158915')
# ('Current Cost: ', 3.9786413, '\t Epoch 0/25', '\t Iter 26496/158915')
# ('Current Cost: ', 3.8112342, '\t Epoch 0/25', '\t Iter 26624/158915')
# ('Current Cost: ', 3.7960348, '\t Epoch 0/25', '\t Iter 26752/158915')
# ('Current Cost: ', 3.7099082, '\t Epoch 0/25', '\t Iter 26880/158915')
# ('Current Cost: ', 3.6856036, '\t Epoch 0/25', '\t Iter 27008/158915')
# ('Current Cost: ', 3.8081808, '\t Epoch 0/25', '\t Iter 27136/158915')
# ('Current Cost: ', 3.8208678, '\t Epoch 0/25', '\t Iter 27264/158915')
# ('Current Cost: ', 3.7353575, '\t Epoch 0/25', '\t Iter 27392/158915')
# ('Current Cost: ', 3.8142505, '\t Epoch 0/25', '\t Iter 27520/158915')
# ('Current Cost: ', 3.9206533, '\t Epoch 0/25', '\t Iter 27648/158915')
# ('Current Cost: ', 3.7936325, '\t Epoch 0/25', '\t Iter 27776/158915')
# ('Current Cost: ', 3.7219603, '\t Epoch 0/25', '\t Iter 27904/158915')
# ('Current Cost: ', 3.6821563, '\t Epoch 0/25', '\t Iter 28032/158915')
# ('Current Cost: ', 3.7328944, '\t Epoch 0/25', '\t Iter 28160/158915')
# ('Current Cost: ', 3.7374065, '\t Epoch 0/25', '\t Iter 28288/158915')
# ('Current Cost: ', 3.8590901, '\t Epoch 0/25', '\t Iter 28416/158915')
# ('Current Cost: ', 3.7875943, '\t Epoch 0/25', '\t Iter 28544/158915')
# ('Current Cost: ', 3.8821332, '\t Epoch 0/25', '\t Iter 28672/158915')
# ('Current Cost: ', 3.7620325, '\t Epoch 0/25', '\t Iter 28800/158915')
# ('Current Cost: ', 3.8493407, '\t Epoch 0/25', '\t Iter 28928/158915')
# ('Current Cost: ', 3.7727947, '\t Epoch 0/25', '\t Iter 29056/158915')
# ('Current Cost: ', 3.7457876, '\t Epoch 0/25', '\t Iter 29184/158915')
# ('Current Cost: ', 3.8953424, '\t Epoch 0/25', '\t Iter 29312/158915')
# ('Current Cost: ', 3.8761163, '\t Epoch 0/25', '\t Iter 29440/158915')
# ('Current Cost: ', 3.8167088, '\t Epoch 0/25', '\t Iter 29568/158915')
# ('Current Cost: ', 3.7486894, '\t Epoch 0/25', '\t Iter 29696/158915')
# ('Current Cost: ', 3.7858114, '\t Epoch 0/25', '\t Iter 29824/158915')
# ('Current Cost: ', 3.9281521, '\t Epoch 0/25', '\t Iter 29952/158915')
# ('Current Cost: ', 3.6733725, '\t Epoch 0/25', '\t Iter 30080/158915')
# ('Current Cost: ', 3.8703084, '\t Epoch 0/25', '\t Iter 30208/158915')
# ('Current Cost: ', 3.7096608, '\t Epoch 0/25', '\t Iter 30336/158915')
# ('Current Cost: ', 3.6676397, '\t Epoch 0/25', '\t Iter 30464/158915')
# ('Current Cost: ', 3.66434, '\t Epoch 0/25', '\t Iter 30592/158915')
# ('Current Cost: ', 3.8196251, '\t Epoch 0/25', '\t Iter 30720/158915')
# ('Current Cost: ', 3.7032306, '\t Epoch 0/25', '\t Iter 30848/158915')
# ('Current Cost: ', 3.757252, '\t Epoch 0/25', '\t Iter 30976/158915')
# ('Current Cost: ', 3.8045814, '\t Epoch 0/25', '\t Iter 31104/158915')
# ('Current Cost: ', 3.6517777, '\t Epoch 0/25', '\t Iter 31232/158915')
# ('Current Cost: ', 3.7091398, '\t Epoch 0/25', '\t Iter 31360/158915')
# ('Current Cost: ', 3.635406, '\t Epoch 0/25', '\t Iter 31488/158915')
# ('Current Cost: ', 3.5593839, '\t Epoch 0/25', '\t Iter 31616/158915')
# ('Current Cost: ', 3.6657777, '\t Epoch 0/25', '\t Iter 31744/158915')
# ('Current Cost: ', 3.7871003, '\t Epoch 0/25', '\t Iter 31872/158915')
# ('Current Cost: ', 3.7592843, '\t Epoch 0/25', '\t Iter 32000/158915')
# ('Current Cost: ', 3.8098636, '\t Epoch 0/25', '\t Iter 32128/158915')
# ('Current Cost: ', 3.7421925, '\t Epoch 0/25', '\t Iter 32256/158915')
# ('Current Cost: ', 3.5895627, '\t Epoch 0/25', '\t Iter 32384/158915')
# ('Current Cost: ', 3.7153611, '\t Epoch 0/25', '\t Iter 32512/158915')
# ('Current Cost: ', 3.624706, '\t Epoch 0/25', '\t Iter 32640/158915')
# ('Current Cost: ', 3.6782529, '\t Epoch 0/25', '\t Iter 32768/158915')
# ('Current Cost: ', 3.6416364, '\t Epoch 0/25', '\t Iter 32896/158915')
# ('Current Cost: ', 3.6551192, '\t Epoch 0/25', '\t Iter 33024/158915')
# ('Current Cost: ', 3.7336507, '\t Epoch 0/25', '\t Iter 33152/158915')
# ('Current Cost: ', 3.7049119, '\t Epoch 0/25', '\t Iter 33280/158915')
# ('Current Cost: ', 3.7851748, '\t Epoch 0/25', '\t Iter 33408/158915')
# ('Current Cost: ', 3.8140445, '\t Epoch 0/25', '\t Iter 33536/158915')
# ('Current Cost: ', 3.7557275, '\t Epoch 0/25', '\t Iter 33664/158915')
# ('Current Cost: ', 3.8542244, '\t Epoch 0/25', '\t Iter 33792/158915')
# ('Current Cost: ', 3.7709379, '\t Epoch 0/25', '\t Iter 33920/158915')
# ('Current Cost: ', 3.6423571, '\t Epoch 0/25', '\t Iter 34048/158915')
# ('Current Cost: ', 3.8736713, '\t Epoch 0/25', '\t Iter 34176/158915')
# ('Current Cost: ', 3.7679837, '\t Epoch 0/25', '\t Iter 34304/158915')
# ('Current Cost: ', 3.7906475, '\t Epoch 0/25', '\t Iter 34432/158915')
# ('Current Cost: ', 3.643935, '\t Epoch 0/25', '\t Iter 34560/158915')
# ('Current Cost: ', 3.6491587, '\t Epoch 0/25', '\t Iter 34688/158915')
# ('Current Cost: ', 3.6621807, '\t Epoch 0/25', '\t Iter 34816/158915')
# ('Current Cost: ', 3.7498758, '\t Epoch 0/25', '\t Iter 34944/158915')
# ('Current Cost: ', 3.6102014, '\t Epoch 0/25', '\t Iter 35072/158915')
# ('Current Cost: ', 3.6788859, '\t Epoch 0/25', '\t Iter 35200/158915')
# ('Current Cost: ', 3.7058067, '\t Epoch 0/25', '\t Iter 35328/158915')
# ('Current Cost: ', 3.6691189, '\t Epoch 0/25', '\t Iter 35456/158915')
# ('Current Cost: ', 3.7475879, '\t Epoch 0/25', '\t Iter 35584/158915')
# ('Current Cost: ', 3.7696633, '\t Epoch 0/25', '\t Iter 35712/158915')
# ('Current Cost: ', 3.6670032, '\t Epoch 0/25', '\t Iter 35840/158915')
# ('Current Cost: ', 3.6742749, '\t Epoch 0/25', '\t Iter 35968/158915')
# ('Current Cost: ', 3.6535201, '\t Epoch 0/25', '\t Iter 36096/158915')
# ('Current Cost: ', 3.6524224, '\t Epoch 0/25', '\t Iter 36224/158915')
# ('Current Cost: ', 3.7188799, '\t Epoch 0/25', '\t Iter 36352/158915')
# ('Current Cost: ', 3.6899619, '\t Epoch 0/25', '\t Iter 36480/158915')
# ('Current Cost: ', 3.6152284, '\t Epoch 0/25', '\t Iter 36608/158915')
# ('Current Cost: ', 3.5665393, '\t Epoch 0/25', '\t Iter 36736/158915')
# ('Current Cost: ', 3.6553226, '\t Epoch 0/25', '\t Iter 36864/158915')
# ('Current Cost: ', 3.6612132, '\t Epoch 0/25', '\t Iter 36992/158915')
# ('Current Cost: ', 3.6936154, '\t Epoch 0/25', '\t Iter 37120/158915')
# ('Current Cost: ', 3.6492212, '\t Epoch 0/25', '\t Iter 37248/158915')
# ('Current Cost: ', 3.6851904, '\t Epoch 0/25', '\t Iter 37376/158915')
# ('Current Cost: ', 3.6365287, '\t Epoch 0/25', '\t Iter 37504/158915')
# ('Current Cost: ', 3.5403533, '\t Epoch 0/25', '\t Iter 37632/158915')
# ('Current Cost: ', 3.7583902, '\t Epoch 0/25', '\t Iter 37760/158915')
# ('Current Cost: ', 3.6285434, '\t Epoch 0/25', '\t Iter 37888/158915')
# ('Current Cost: ', 3.6791179, '\t Epoch 0/25', '\t Iter 38016/158915')
# ('Current Cost: ', 3.8242588, '\t Epoch 0/25', '\t Iter 38144/158915')
# ('Current Cost: ', 3.7332222, '\t Epoch 0/25', '\t Iter 38272/158915')
# ('Current Cost: ', 3.6715953, '\t Epoch 0/25', '\t Iter 38400/158915')
# ('Current Cost: ', 3.667711, '\t Epoch 0/25', '\t Iter 38528/158915')
# ('Current Cost: ', 3.610122, '\t Epoch 0/25', '\t Iter 38656/158915')
# ('Current Cost: ', 3.5967662, '\t Epoch 0/25', '\t Iter 38784/158915')
# ('Current Cost: ', 3.5885355, '\t Epoch 0/25', '\t Iter 38912/158915')
# ('Current Cost: ', 3.6321194, '\t Epoch 0/25', '\t Iter 39040/158915')
# ('Current Cost: ', 3.8822613, '\t Epoch 0/25', '\t Iter 39168/158915')
# ('Current Cost: ', 3.5467992, '\t Epoch 0/25', '\t Iter 39296/158915')
# ('Current Cost: ', 3.5117612, '\t Epoch 0/25', '\t Iter 39424/158915')
# ('Current Cost: ', 3.5968595, '\t Epoch 0/25', '\t Iter 39552/158915')
# ('Current Cost: ', 3.6306612, '\t Epoch 0/25', '\t Iter 39680/158915')
# ('Current Cost: ', 3.6467526, '\t Epoch 0/25', '\t Iter 39808/158915')
# ('Current Cost: ', 3.607785, '\t Epoch 0/25', '\t Iter 39936/158915')
# ('Current Cost: ', 3.851222, '\t Epoch 0/25', '\t Iter 40064/158915')
# ('Current Cost: ', 3.6050417, '\t Epoch 0/25', '\t Iter 40192/158915')
# ('Current Cost: ', 3.6571608, '\t Epoch 0/25', '\t Iter 40320/158915')
# ('Current Cost: ', 3.7337091, '\t Epoch 0/25', '\t Iter 40448/158915')
# ('Current Cost: ', 3.6793742, '\t Epoch 0/25', '\t Iter 40576/158915')
# ('Current Cost: ', 3.7759359, '\t Epoch 0/25', '\t Iter 40704/158915')
# ('Current Cost: ', 3.5791063, '\t Epoch 0/25', '\t Iter 40832/158915')
# ('Current Cost: ', 3.6883512, '\t Epoch 0/25', '\t Iter 40960/158915')
# ('Current Cost: ', 3.6011407, '\t Epoch 0/25', '\t Iter 41088/158915')
# ('Current Cost: ', 3.5940051, '\t Epoch 0/25', '\t Iter 41216/158915')
# ('Current Cost: ', 3.4992125, '\t Epoch 0/25', '\t Iter 41344/158915')
# ('Current Cost: ', 3.6653583, '\t Epoch 0/25', '\t Iter 41472/158915')
# ('Current Cost: ', 3.7680485, '\t Epoch 0/25', '\t Iter 41600/158915')
# ('Current Cost: ', 3.6313903, '\t Epoch 0/25', '\t Iter 41728/158915')
# ('Current Cost: ', 3.5452247, '\t Epoch 0/25', '\t Iter 41856/158915')
# ('Current Cost: ', 3.67875, '\t Epoch 0/25', '\t Iter 41984/158915')
# ('Current Cost: ', 3.5375197, '\t Epoch 0/25', '\t Iter 42112/158915')
# ('Current Cost: ', 3.7330587, '\t Epoch 0/25', '\t Iter 42240/158915')
# ('Current Cost: ', 3.7149765, '\t Epoch 0/25', '\t Iter 42368/158915')
# ('Current Cost: ', 3.5234754, '\t Epoch 0/25', '\t Iter 42496/158915')
# ('Current Cost: ', 3.5213459, '\t Epoch 0/25', '\t Iter 42624/158915')
# ('Current Cost: ', 3.6300056, '\t Epoch 0/25', '\t Iter 42752/158915')
# ('Current Cost: ', 3.712127, '\t Epoch 0/25', '\t Iter 42880/158915')
# ('Current Cost: ', 3.6198535, '\t Epoch 0/25', '\t Iter 43008/158915')
# ('Current Cost: ', 3.6293056, '\t Epoch 0/25', '\t Iter 43136/158915')
# ('Current Cost: ', 3.6160343, '\t Epoch 0/25', '\t Iter 43264/158915')
# ('Current Cost: ', 3.6547065, '\t Epoch 0/25', '\t Iter 43392/158915')
# ('Current Cost: ', 3.5813344, '\t Epoch 0/25', '\t Iter 43520/158915')
# ('Current Cost: ', 3.6152499, '\t Epoch 0/25', '\t Iter 43648/158915')
# ('Current Cost: ', 3.6234088, '\t Epoch 0/25', '\t Iter 43776/158915')
# ('Current Cost: ', 3.5278523, '\t Epoch 0/25', '\t Iter 43904/158915')
# ('Current Cost: ', 3.6234164, '\t Epoch 0/25', '\t Iter 44032/158915')
# ('Current Cost: ', 3.5709517, '\t Epoch 0/25', '\t Iter 44160/158915')
# ('Current Cost: ', 3.6085763, '\t Epoch 0/25', '\t Iter 44288/158915')
# ('Current Cost: ', 3.5289874, '\t Epoch 0/25', '\t Iter 44416/158915')
# ('Current Cost: ', 3.5291038, '\t Epoch 0/25', '\t Iter 44544/158915')
# ('Current Cost: ', 3.5521059, '\t Epoch 0/25', '\t Iter 44672/158915')
# ('Current Cost: ', 3.4449015, '\t Epoch 0/25', '\t Iter 44800/158915')
# ('Current Cost: ', 3.487179, '\t Epoch 0/25', '\t Iter 44928/158915')
# ('Current Cost: ', 3.56987, '\t Epoch 0/25', '\t Iter 45056/158915')
# ('Current Cost: ', 3.4378932, '\t Epoch 0/25', '\t Iter 45184/158915')
# ('Current Cost: ', 3.5587039, '\t Epoch 0/25', '\t Iter 45312/158915')
# ('Current Cost: ', 3.670676, '\t Epoch 0/25', '\t Iter 45440/158915')
# ('Current Cost: ', 3.6302576, '\t Epoch 0/25', '\t Iter 45568/158915')
# ('Current Cost: ', 3.496968, '\t Epoch 0/25', '\t Iter 45696/158915')
# ('Current Cost: ', 3.4877934, '\t Epoch 0/25', '\t Iter 45824/158915')
# ('Current Cost: ', 3.4848115, '\t Epoch 0/25', '\t Iter 45952/158915')
# ('Current Cost: ', 3.6104164, '\t Epoch 0/25', '\t Iter 46080/158915')
# ('Current Cost: ', 3.5811229, '\t Epoch 0/25', '\t Iter 46208/158915')
# ('Current Cost: ', 3.6869659, '\t Epoch 0/25', '\t Iter 46336/158915')
# ('Current Cost: ', 3.6563015, '\t Epoch 0/25', '\t Iter 46464/158915')
# ('Current Cost: ', 3.5717459, '\t Epoch 0/25', '\t Iter 46592/158915')
# ('Current Cost: ', 3.4747732, '\t Epoch 0/25', '\t Iter 46720/158915')
# ('Current Cost: ', 3.6221485, '\t Epoch 0/25', '\t Iter 46848/158915')
# ('Current Cost: ', 3.4353225, '\t Epoch 0/25', '\t Iter 46976/158915')
# ('Current Cost: ', 3.5317345, '\t Epoch 0/25', '\t Iter 47104/158915')
# ('Current Cost: ', 3.5152843, '\t Epoch 0/25', '\t Iter 47232/158915')
# ('Current Cost: ', 3.622287, '\t Epoch 0/25', '\t Iter 47360/158915')
# ('Current Cost: ', 3.5911708, '\t Epoch 0/25', '\t Iter 47488/158915')
# ('Current Cost: ', 3.5182438, '\t Epoch 0/25', '\t Iter 47616/158915')
# ('Current Cost: ', 3.5381911, '\t Epoch 0/25', '\t Iter 47744/158915')
# ('Current Cost: ', 3.5273137, '\t Epoch 0/25', '\t Iter 47872/158915')
# ('Current Cost: ', 3.4721718, '\t Epoch 0/25', '\t Iter 48000/158915')
# ('Current Cost: ', 3.5836794, '\t Epoch 0/25', '\t Iter 48128/158915')
# ('Current Cost: ', 3.6350648, '\t Epoch 0/25', '\t Iter 48256/158915')
# ('Current Cost: ', 3.6095459, '\t Epoch 0/25', '\t Iter 48384/158915')
# ('Current Cost: ', 3.5598552, '\t Epoch 0/25', '\t Iter 48512/158915')
# ('Current Cost: ', 3.4344039, '\t Epoch 0/25', '\t Iter 48640/158915')
# ('Current Cost: ', 3.4492922, '\t Epoch 0/25', '\t Iter 48768/158915')
# ('Current Cost: ', 3.7054138, '\t Epoch 0/25', '\t Iter 48896/158915')
# ('Current Cost: ', 3.5771141, '\t Epoch 0/25', '\t Iter 49024/158915')
# ('Current Cost: ', 3.5880339, '\t Epoch 0/25', '\t Iter 49152/158915')
# ('Current Cost: ', 3.4140422, '\t Epoch 0/25', '\t Iter 49280/158915')
# ('Current Cost: ', 3.5370579, '\t Epoch 0/25', '\t Iter 49408/158915')
# ('Current Cost: ', 3.5748563, '\t Epoch 0/25', '\t Iter 49536/158915')
# ('Current Cost: ', 3.5066135, '\t Epoch 0/25', '\t Iter 49664/158915')
# ('Current Cost: ', 3.4110601, '\t Epoch 0/25', '\t Iter 49792/158915')
# ('Current Cost: ', 3.4682043, '\t Epoch 0/25', '\t Iter 49920/158915')
# ('Current Cost: ', 3.5030558, '\t Epoch 0/25', '\t Iter 50048/158915')
# ('Current Cost: ', 3.4866261, '\t Epoch 0/25', '\t Iter 50176/158915')
# ('Current Cost: ', 3.5464268, '\t Epoch 0/25', '\t Iter 50304/158915')
# ('Current Cost: ', 3.6152461, '\t Epoch 0/25', '\t Iter 50432/158915')
# ('Current Cost: ', 3.4978926, '\t Epoch 0/25', '\t Iter 50560/158915')
# ('Current Cost: ', 3.5495899, '\t Epoch 0/25', '\t Iter 50688/158915')
# ('Current Cost: ', 3.4663157, '\t Epoch 0/25', '\t Iter 50816/158915')
# ('Current Cost: ', 3.5458972, '\t Epoch 0/25', '\t Iter 50944/158915')
# ('Current Cost: ', 3.4933128, '\t Epoch 0/25', '\t Iter 51072/158915')
# ('Current Cost: ', 3.6483977, '\t Epoch 0/25', '\t Iter 51200/158915')
# ('Current Cost: ', 3.4425683, '\t Epoch 0/25', '\t Iter 51328/158915')
# ('Current Cost: ', 3.5917299, '\t Epoch 0/25', '\t Iter 51456/158915')
# ('Current Cost: ', 3.4219949, '\t Epoch 0/25', '\t Iter 51584/158915')
# ('Current Cost: ', 3.4691522, '\t Epoch 0/25', '\t Iter 51712/158915')
# ('Current Cost: ', 3.670785, '\t Epoch 0/25', '\t Iter 51840/158915')
# ('Current Cost: ', 3.4483166, '\t Epoch 0/25', '\t Iter 51968/158915')
# ('Current Cost: ', 3.5803001, '\t Epoch 0/25', '\t Iter 52096/158915')
# ('Current Cost: ', 3.4986579, '\t Epoch 0/25', '\t Iter 52224/158915')
# ('Current Cost: ', 3.4023869, '\t Epoch 0/25', '\t Iter 52352/158915')
# ('Current Cost: ', 3.5736153, '\t Epoch 0/25', '\t Iter 52480/158915')
# ('Current Cost: ', 3.686614, '\t Epoch 0/25', '\t Iter 52608/158915')
# ('Current Cost: ', 3.4797306, '\t Epoch 0/25', '\t Iter 52736/158915')
# ('Current Cost: ', 3.5660012, '\t Epoch 0/25', '\t Iter 52864/158915')
# ('Current Cost: ', 3.576853, '\t Epoch 0/25', '\t Iter 52992/158915')
# ('Current Cost: ', 3.659565, '\t Epoch 0/25', '\t Iter 53120/158915')
# ('Current Cost: ', 3.4414926, '\t Epoch 0/25', '\t Iter 53248/158915')
# ('Current Cost: ', 3.585649, '\t Epoch 0/25', '\t Iter 53376/158915')
# ('Current Cost: ', 3.4284096, '\t Epoch 0/25', '\t Iter 53504/158915')
# ('Current Cost: ', 3.3751962, '\t Epoch 0/25', '\t Iter 53632/158915')
# ('Current Cost: ', 3.4965751, '\t Epoch 0/25', '\t Iter 53760/158915')
# ('Current Cost: ', 3.6426024, '\t Epoch 0/25', '\t Iter 53888/158915')
# ('Current Cost: ', 3.5091803, '\t Epoch 0/25', '\t Iter 54016/158915')
# ('Current Cost: ', 3.6200664, '\t Epoch 0/25', '\t Iter 54144/158915')
# ('Current Cost: ', 3.4476998, '\t Epoch 0/25', '\t Iter 54272/158915')
# ('Current Cost: ', 3.4278858, '\t Epoch 0/25', '\t Iter 54400/158915')
# ('Current Cost: ', 3.4510655, '\t Epoch 0/25', '\t Iter 54528/158915')
# ('Current Cost: ', 3.6021926, '\t Epoch 0/25', '\t Iter 54656/158915')
# ('Current Cost: ', 3.6282337, '\t Epoch 0/25', '\t Iter 54784/158915')
# ('Current Cost: ', 3.6423187, '\t Epoch 0/25', '\t Iter 54912/158915')
# ('Current Cost: ', 3.5180833, '\t Epoch 0/25', '\t Iter 55040/158915')
# ('Current Cost: ', 3.6159077, '\t Epoch 0/25', '\t Iter 55168/158915')
# ('Current Cost: ', 3.4550629, '\t Epoch 0/25', '\t Iter 55296/158915')
# ('Current Cost: ', 3.4391062, '\t Epoch 0/25', '\t Iter 55424/158915')
# ('Current Cost: ', 3.5781028, '\t Epoch 0/25', '\t Iter 55552/158915')
# ('Current Cost: ', 3.4808249, '\t Epoch 0/25', '\t Iter 55680/158915')
# ('Current Cost: ', 3.4599693, '\t Epoch 0/25', '\t Iter 55808/158915')
# ('Current Cost: ', 3.5510359, '\t Epoch 0/25', '\t Iter 55936/158915')
# ('Current Cost: ', 3.4217591, '\t Epoch 0/25', '\t Iter 56064/158915')
# ('Current Cost: ', 3.4245553, '\t Epoch 0/25', '\t Iter 56192/158915')
# ('Current Cost: ', 3.4145074, '\t Epoch 0/25', '\t Iter 56320/158915')
# ('Current Cost: ', 3.4208429, '\t Epoch 0/25', '\t Iter 56448/158915')
# ('Current Cost: ', 3.5040121, '\t Epoch 0/25', '\t Iter 56576/158915')
