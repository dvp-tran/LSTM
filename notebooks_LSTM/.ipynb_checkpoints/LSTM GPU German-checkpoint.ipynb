# %% [markdown]
# # LSTM

# %% [markdown]
# - ## Preliminaries

# %% [markdown]
# - ### Imports

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout,TimeDistributed
from keras.layers import LSTM,SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import os, os.path
from os import listdir
from os.path import isfile, join
from unicodedata import normalize
# Out:
# Using TensorFlow backend.
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %% [markdown]
# - ### Check CPU usage

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
get_available_gpus()
# Out:
# [u'/gpu:0']

# %% [markdown]
# ----------

# %% [markdown]
# - ### Check and set Twitter's API

# %%
import twitter
api = twitter.Api(consumer_key='LyNVanTEQEOEGKfXAMeLv6AKG',
                    consumer_secret='0lJvhaaOP5cRZWm6rxwyBIAypd1P7eiDx9f74KBDlLrSldNuBQ',
                    access_token_key='855852332034265088-geTEVmA7xIsOD3WCZyfBNnqjRdS1MhW',
                    access_token_secret='kJMwMl67e3nYrqaGWzIizxzQpRZhtBfOnwPflO1fk3cOt')
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:11.707748. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
print(api.VerifyCredentials())
# Out:
# {"created_at": "Sat Apr 22 18:34:31 +0000 2017", "default_profile": true, "description": "Learning how to be creative", "followers_count": 1, "friends_count": 3, "id": 855852332034265088, "lang": "en", "location": "Somewhere in the cloud", "name": "ArtistBot", "profile_background_color": "F5F8FA", "profile_banner_url": "https://pbs.twimg.com/profile_banners/855852332034265088/1492892354", "profile_image_url": "http://pbs.twimg.com/profile_images/855878764143804417/r55Z2Js5_normal.jpg", "profile_link_color": "1DA1F2", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "screen_name": "TheTalkativeBot", "status": {"created_at": "Sun Apr 23 23:03:24 +0000 2017", "id": 856282386165792768, "id_str": "856282386165792768", "lang": "fr", "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">TheScenarioBot</a>", "text": "\u00b7m prems,\n    Mon Denancazan que si mentir\n    Tot ab la que say to mais copitz;\n    Estre breused'en velenca,\n    Mais"}, "statuses_count": 19}
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:12.154371. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [raw]
# api.PostUpdate("Today I am learning German, watch me improve! ;) ")

# %% [markdown]
# # I. Toy examples

# %% [markdown]
# - ### Test

# %% [markdown]
# ** 1. Load and convert data**

# %% [markdown]
# '''Example script to generate text from Nietzsche's writings.
# At least 20 epochs are required before the generated text
# starts sounding coherent.
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.
# '''

# %%
#Load and concatenate files:

DIR="../../LSTM/data/Gutenberg/ebooks-unzipped/German/"
all_files = [f for f in listdir(DIR) if isfile(join(DIR, f))]

#choose how many files to concatenate:
nb_files=2
if nb_files>len(all_files):
    nb_files=len(all_files)
    
    
out_path="german/data/"
if not os.path.exists(out_path):
    os.makedirs(out_path)
if not os.path.exists(out_path+"input/"):
    os.makedirs(out_path+"input/")
    
with open(out_path+'input/input_action.txt', 'w') as outfile:
    for fname in all_files[0:nb_files]:
        with open(DIR+fname) as infile:
            for line in infile:
                outfile.write(line)
        print ("Done concatenating file : %s" %fname)
# Out:
# Done concatenating file : 2146-8.txt
# Done concatenating file : 2409-8.txt
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:12.644901. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
#load file
file_name=out_path+'input/input_action.txt'
text = open(file_name).read()
text=normalize('NFKD',text.decode('latin1'))
print('corpus length:', len(text))

chars = sorted(list(set(text)))
VOCAB_SIZE = len(chars)
print('total chars:',VOCAB_SIZE)
# Out:
# corpus length: 497628
# total chars: 93
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:12.853888. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# **Warning:** The RNN takes in input numerical data hence the necessity to convert strings into numerical values.

# %%
#creating mapping between indexes and characters
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:12.926542. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# We’re gonna use Keras to create and train our Network, so we must convert the data into this form: (number_of_sequences, length_of_sequence, number_of_features).
# - nb of features = length of the char array
# - length of sequence = batch size
# - nb of sequence = len(data) divided by batch size.
#
# **Warning : ** target sequence is setted by shifting the source/input sequence by one character with both having the same length.

# %%
# %%time

SEQ_LENGTH=100
#Build three dimensional arrays
X = np.zeros((len(text)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE)) #input
y = np.zeros((len(text)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE)) #target

#Build sequences
for i in range(0, len(text)/SEQ_LENGTH):
    X_sequence = text[i*SEQ_LENGTH:(i+1)*SEQ_LENGTH]
    X_sequence_ix = [char_indices[value] for value in X_sequence]
    input_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
    for j in range(SEQ_LENGTH):
        input_sequence[j][X_sequence_ix[j]] = 1.
    X[i] = input_sequence

    y_sequence = text[i*SEQ_LENGTH+1:(i+1)*SEQ_LENGTH+1]
    y_sequence_ix = [char_indices[value] for value in y_sequence]
    target_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
    for j in range(SEQ_LENGTH):
        target_sequence[j][y_sequence_ix[j]] = 1.
    y[i] = target_sequence
# Out:
# CPU times: user 444 ms, sys: 40 ms, total: 484 ms
# Wall time: 484 ms
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:12.965591. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ** 2. Build the network**

# %%
HIDDEN_DIM= 500 #500
LAYER_NUM = 2


model = Sequential()
model.add(LSTM(HIDDEN_DIM, input_shape=(None, VOCAB_SIZE), return_sequences=True))
for i in range(LAYER_NUM - 1):
    model.add(LSTM(HIDDEN_DIM, return_sequences=True))
model.add(TimeDistributed(Dense(VOCAB_SIZE)))
model.add(Activation('softmax'))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:13.553666. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
def generate_text(model, length, vocab_size, ix_to_char):
    # starting with random character
    ix = [np.random.randint(vocab_size)]
    y_char = [ix_to_char[ix[-1]]]
    X = np.zeros((1, length, vocab_size))
    for i in range(length):
        # appending the last predicted character to sequence
        X[0, i, :][ix[-1]] = 1
        print(ix_to_char[ix[-1]], end="")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        y_char.append(ix_to_char[ix[-1]])
    return ('').join(y_char)
# Out:
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:18.126191. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Generate some sample before training to know how bad it is!
bla = generate_text(model, 100, VOCAB_SIZE, indices_char)
#api.PostUpdate(status=bla[0:123])
# Out:
# nCJJIIJW,<CCJJJJICCJJYCCJbbbbbbEEEE444!HHeeqqT!ttt5~5II5I5YY9Yxxxkkkkxkkxkkxk!x!!x!́!́x!!́M))))ZZZZZ
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 01:13:18.134918. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# **3. Train network**

# %%
#batch size equals to seq length here
BATCH_SIZE=100
#len of desired output
GENERATE_LENGTH=140
DIR=out_path+"weights/weight_attempt_s01/"
flag=True

try:
    onlyfiles = [f for f in listdir(DIR) if isfile(join(DIR, f))]
    nb_files = len(onlyfiles)
    name_template = onlyfiles[0][0:15]
except Exception as e:
    print(e)
    if not os.path.exists(DIR):
        os.makedirs(DIR)
    nb_files=0

if nb_files>0:
    nb_iteration=nb_files*20
    model.load_weights(DIR+onlyfiles[0][0:21]+str(nb_iteration)+'.hdf5')
else:
    nb_iteration=0
    
print("Starting at iteration : %s" %nb_iteration)
while flag==True:
    print('\n')
    print('-'*20)
    model.fit(X, y, batch_size=BATCH_SIZE, verbose=2, nb_epoch=1)
    nb_iteration += 1
    bla=generate_text(model, GENERATE_LENGTH,VOCAB_SIZE, indices_char)
    if nb_iteration % 20 == 0:
        print("\n\nIteration nb : %s" %nb_iteration)
        api.PostUpdate(status=bla[0:123])
        model.save_weights(DIR+'checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_iteration))
    if nb_iteration>=400:
        print("Stopping...")
        flag=False
# Out:
# Starting at iteration : 60
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.2085
# ́s and angenemmen Phisopo,
# and ar etwas it thell pay in donatoos so we von a you any of the controne or copf aule it one you and by
# minnic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1914
# _--
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# Lenardo sagte zu dem klepne Steine vo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1856
# len gegen ein jeder nichtsten
# geben, und als eine überergand zu sehen hie, als ohne ein lebensichte ein wenig von der neue nichts des Heil
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1795
# Oranien, hoch!
#
# Alle.  Hoch!  hoch!
#
# Soest.  Nun, Alter, bring' auch deine Gesundheit.
#
# Ruysum.  Unser Freiheit?
#
# Egmont.  Durch sei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1730
# ̈nde geleitet, scheint keine andere Absicht gehabt
# zu haben, als sich und andern alberne Streiche zurückel", sagte Juliette; "sieht
# nach
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1658
# X--"Eben deswegen", sagte jener, "red' ich
# mit niemanden darüber und mag, wie viel das Schlange neuge und Wildeln, das er sich hier nicht
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1614
# (grafen Er verdeute die Gassen in der Gast.  Er schien ties in die Welt aus der Mänderricken
# vor sich bei uns ein in die Nacht.
#
#
# Klär
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1552
# meiner Seite war, wie er den
# Kapelle stechel wissen, wo ich den schicksals erkennen könne..
#
# Regentin.  Ich habe nach Antont, manches al
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1512
# 200 billion Etexts given away this year.
#
# The Goal of Project Gutenberg is to Give Away One Trillion Etext
# Files by December am narment o
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1461
# meiner Seite war, wie er alles nach dem Pilger zu welden, und nicht
# allen manches Bedingung, da sie soll er als ein ander Teufelden, sich a
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1437
# Ch ist of entsagen.  Ihr mit the sond wort die Stande
# wieder zu fragen und zu bereiten und zu sein, in dem er sich von dem Gesichte
# des Mo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1420
# !  Gott geb' ihm langes
# Leben.
#
# Soest.  Hattet Ihr seinen Herrn Vater, Karl den Fünften, nicht liebe, sagte der Hände,
# "Und an einem s
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1360
# --
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen.
#
# Machiavell.  Du wasten, wie ich nicht l
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1329
# : denn ich einmal befreise
# hierhe; gelaust hat dem Gatte zu bemerken , umd zu des höchst unerbartet Inschrift
# verohrengleich, dem edle st
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1341
# Hause bedrohen.  Aber weil Sie jung sind,
# sage wie die Ankehmen den Orknis seiten noch alles diesen Dasselsen, hörte, wie er diesen Kopf w
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1260
# ; er glänzte golden, ihre
# Kleider schienen priesterlich, ihr Anblick leuchtete sanft; ich war
# im Begleibenden sind, diese gesterne Kapiel
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1250
# % er könnte sich aufdersen, sie nieder
# und verdründiger Mann hnat seinen Hoffnung wild der Verstand, die Einsie lange die Höhe nicht.
# W
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1233
# Karten drei Jahre vor uns
# verborgen gehalten hat und noch verborgen hält, sollen wir die
# unsrigen war.  Das in der Familie,
# einen Vorsat
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1216
# ken auf andere, hinter das zufrieden Soldaten auszusehen, wo
# ung zu erwarten, daß der Wände von einer großen Marke mit
# des mit allen anzu
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1193
# ; ich kenne mich selbst genug,
# und weiß, wie ich dem König angehöre; weit mehr als viele, die in sich.
#
# Julie (auf den Brief so darz Ab
#
# Iteration nb : 80
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1181
# .  Ich hatte einen alten Patron, der besaß Pergamum:  Schelten
# mich noch Verdreuen.  Ich glaube aber den Ferde auf.
#
#
#
#
#
#
#
#
#
#
# De
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1168
# ft den Glanzraum
# des Äthers verbirgt, hinderbünstlich geworden.
#
# Sie kann an der Brude hatte der Mühe einen so chnen Anstrechen einget
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1146
# Y OTh erretred by Jomerd ot alsowar
#     pbss be     tiece this "S                  nenertty or exeint any  p y and).  of you moue you wewir
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1135
# Oranien.  Egmont, ich trage viele Jahre her alle unsere Verhältnisse am
# Herzen, ich stehe immer wie ein Herzener gewiß sein.  Neuen Vater
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1106
# versetzte der Vater.--"Reiche
# mir Scheite! reinem Felix schien, einem Lagerbrichtig,
# das Lucidse!  Wir heir bewegte Wand.  Ich hatte mir d
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1113
# ten etwas zu
# fassen und fest zu setzen! Rechte Männer!  Dafür sind aber auch unsere
# Privilegien sonderte lästen zu verboten und schlong
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1087
# Y OTh erretred by Jomerd ute sitzen.  Ther
# tite from setzer astode from ally if this etext if you hancablest
# within tha mays for dis lises
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1068
# #2020 billion Etexts given away this year.
#
# The Goal of Project Gutenberg is to Give Away One Trillion Etext
# Files by December 31, 2001.
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1068
# kenden Pflichten kann uns nur die
# gewissenhafteste Ausübung befreien, und was gar nicht aufzulösen, in
# die Welt sich selbst und seinen F
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1062
# % es ist wehig?  Sie steht er in der Schleizen, die ich hier sehen, gegen die mit der
# Freunde deste beteugend, und wenn er nicht wieder vor
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1037
# gen.  "Heute", rief er aus, "soll uns die Langeweile vergangener
# Tage vergütet war.  Nun gostbar in jeden Deut", sie treiben
# sich alle fu
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1038
# Sie mein?"--Sie versetzte:
# "Nun ja doch", die sie die schreckliche Gewißheit immer gewisser Orzeung zu recht gegen immer nicht befand.
# Ver
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1027
# Wenn er sich nun aber mehr zuschriebe und Treuerheit und Bewinkung erhört sich auf diese
# Weinzugele, es ihm ganz an schaut und führt als
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1021
# ́s and By Computers, Since 1971**
#
# *These Etexts Prepared By Hundreds of Volunteers and Donations*
#
# Information on contacting Project Gu
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.1011
# Freund
# neulich ins Ohr sagte?  daß sie nachts einen Mann heimlich zu sich
# einläßt, da sie mich zürbt, sollte ihm des gleichem Herzen von
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.1007
# !  Gott geb' ihm langes
# Leben.
#
# Soest.  Hattet Ihr seinen Herrn Vater zu warfen gesagt, daß er, sagte der Brannug, der
# Bedenken des Freu
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0999
# Interesse überschauen,
# als ihm dessen Bewohner immer merkwürdiger geworden und durch die
# Harmonie nichtstens war man ihr nicht verschlos
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0987
# , ungern
# hört, in Zerstreuung spricht, muffig schweigt und, wenn gas da
# Gott einer Mittel zu rechten."
#
# Nun ein Wunder!"  eine verliere
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0989
# fte meiner
# nicht mehr; man schickte mich zu meinem Vater, an meine Arbeit; man
# antwortete nicht auf und ab, "dee Pferde, das diestenden Me
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0977
# (gut auf er nahe, gedacht.
#
# Soest.  Wer es dich betragen könnte.  Ich hoffte mit einem gewissen Fünste nahm das
# zuräckkenksam, wo daß
#
# Iteration nb : 100
#
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0970
# den möchte, wie mir manchmal die Lust ankommt, so wär' es
# auf diese Weise."  Die pilgernde Törin
# in den frost heriheingefund, wie es fu
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0973
# y form).
#
# [2] Honor the etext refund and replacement provisions of this
#    "Small Print!" statement.  If you do not, you can receive
# a r
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0960
# n einigemal im Leben, aber nie so grausam hab' ich den Schmerz
# empfunden, der mich nun ganz elend manches Umweg, aus der Stelle finden mußt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0958
# % er sich nur den
# König zu befragen.  Sie schien nicht zu unterhalten haben.
# Sie war es nicht geschwind für sie."  Lucinde er die
# Hand
#
# --------------------
# Epoch 1/1
# 91s - loss: 0.0960
# ch die
# welsche Majestät gleich das Pfötchen reichen und Friede machen.  Und den
# Frieden seid ihre, damals verschiedent er verlassen wir
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0949
# ber in dem
# gewöhnlichen Laufe der Dinge wohl schwerlich zusammentreffen möchten."
# Wegen jeder spreche Frauenzinzumamstiglen, so andere s
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0947
# Jetter.  Schön!  Schön!  nicht beweisen.  Er bedüre
# ihn!--Ich hab' ihn gehor.  Was fand sie in die Seinisches Hände
# Ein!  das Volk lei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0947
# an die kein Bürger denkt, der mit dem Nächsten
# nur beschäftigt ist, und der König verlangt Beistet.  Wer hätte scheinen der
# Syrnat an
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0932
# ̈re auf
# zu leben; aber ich habe gelebt.  So leb' auch du, mein Freund, gern und
# mit Lust, und scheuer.  Ich habe keinen Zugebocten waren,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0941
# !  daß wir uns bessern andere schickeit, deiner Mannsaro
# gefällt, uns weiß, wie lieb's verleren!  Was haben Manne!  wie ich mich hier zu u
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0928
# s haben.
#
# Andere.  Das Buch!  das Buch!
#
# Ein ander Freiheit.  Ich kenne die Welt aus dem Margen erwegen sie die Zeit hervorbringend aber
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0921
# Y OTh.
#
# Buyck (n allein, durchand includerligale Nagen sie ausgegeben könne.
#
# Ferdinand.  Da sollte ich mir die ersten, den einsam leic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0917
# $
#
# Klärchen.  Er?
#
# Mutter.  O ja!  es kommt eine Zeit!--Ihr Kinder seht nichts voraus und
# überhörungen zu stieden; ich wart' ich mir
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0917
# Chaise war leer, der Knabe stand bei mir einem Meine, den
# ich in den Fall gesetzte, als Felix bekehren, ob er sich hier nicht zu
# zersehen
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0914
# Verwunderung nahm zu.
#
# Julie.  Aber freilich Lucinde!  Sie ist der Inbegriff aller
# Vollkommenheiten.  Den gewiß ist es auch nicht zu mein
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0905
# Ihre Schilderung wieder auffrischen.  Halten Sie ihn
# kurz, ich bitte Sie; aber suchen Sie zu erfahren, und was in dem überall sein, unsöt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0912
# zu beherrschen,
# muß man ihn um sein selbst willen studieren.  Indem ich aber vom
# Höchsten und Letzt sahen, was die Aufstand über sich, W
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0902
# --
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# Regentin.  Schwieg einen Seele auf und
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0899
# len glauben,
# es sei um der Religion willen.  Ja, es hat sich.  Es ist groß, wenn eine  dam Herzen habe ich
# bekannt zu Antonien, das die We
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0902
# n eine Leidenschaft, wie sie ihn sonst nicht
# erst und verständige und befreien und Tolfe, kaum und fühlte sich doch gerade
# mit der Alten
#
# Iteration nb : 120
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0895
# und sprach zu dem Sternfreunde: "Ich weiß nicht, ob ich ihnen danken
# soll, daß Sie mir dieses Gestirn, und der Freund wie man von Mort zu v
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0891
# Reisegefährten in Verwahrung, und ich will
# aufrichtig bekennen, wo ich den Stein her habe.  Ich bin ein Bekläufe, so anntreckte Höhle ve
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0889
# $
#
# Egmont.  Der wäre?
#
# Oranien.  Zu sehen, was der Rumpf ohne Haupt anfinge.
#
# Egmont.  Wie?
#
# Oranien.  Laß uns gehenst.  Ferd' ich e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0887
# , der Beamte kam mit ihm und einem andern,
# ältlichen, noch freundlichern Manne zurück, und die Sache zuletzt Gatt laebt.  Die Sache leide
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0885
#
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, der die Stämte, der sich in
# den Rat f
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0884
# ́s nicht zu verstänken machte, daß die
# Ein anderne ausgezogenen Lenardosehen: "Du sollst die Kunst entschlossen, was eiches zuhrballen, so
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0879
# @TEN VORANTEY, OREL MADENTAL PTO TO TO TO  A PART
# TO SEMICT,
# FAR INDEXGURES IRULIMITED TO ANTIRY, CONICE, ONBEBED SO HuN NALLIMIETETTSAR
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0881
# Und die Furcht gesellt sich dazu, das Übel werde nur
# größer werden, die Anmut der Nachbarschaft von mir der Eltern Jüngling nicht weiter
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0880
# pro-
#    cessing or hypertext software, but only so long as
#    *EITHER*:
#
#    [*] The etext, when displayed triebst in fort, this rist any
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0873
# den sollest.  Gegeben Bruder!  A, doch auch einmal des Bedingen bei allein anderer
# Sar, wenn er sich das Geschnitz denn Gesells weileraten,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0871
# % er sich nicht so zurück; er warte des Lüchen fallchen Sie deshalber kommt in der welsen Kaup fahl.  Sie
# geringen wir diese Wall nach Ha
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0871
# ~
#
# Egmont.  Was soll ich mehr sagen?  Willst du mehr Worte machen, so
# steht's bei dir.  Es dreht sich allein!  so
# sind treues möge?  Am
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0866
# Veränderung dieser äußern Bedürfnisse, die so vieler
# Menschen Zeit und Kräfter des Volks, wie es denn man kennen andere Artig onteilang
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0864
# Vernünftige, bei dem reinsten Wohlwollen, dergleichen äußerungen für
# Phantasien, für übel der Rechtsgunde einer gewisse munter, der
# g
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0866
# in glücklich zu
# mancher Kenntnis und Meisterschaft fortschritt.  Späterhin war alles,
# was er von Ihnen durch das Herz?  Wie ich mit uns
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0864
# .  Nie hat er einen Schein vermieden; als wenn niemand
# Rechenschaft von ihm zu fordern hätte.  Noch verliebte sie, indem er die Höhe komm
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0865
# $
#
# Vansen.  So soll den Gegend ganz weiter, weil er sich in der Könige.
#
# Egmont.  Und der Krieg ist Inners Menschen, verreilt, er schwer
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0858
# ̈re auf
# zu leben; aber ich habe gelebt.  So leb' auch du, mein Freund, gern und
# mit Lust, und scheuer eilen noch.
#
# Soest.  Auf nichts an
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0860
# _--
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# "Wenn ich zu ihren "Sieß der Sper sta
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0854
# + sie vielleicht gegen ihre Neigung habe
# verheiraten wollen.  Hernach fiel er darauf, ob es nicht etwas für sie
# guter Tückern, nur das G
#
# Iteration nb : 140
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0847
# r erzählte darauf mit Hast, wie er, aus innerem geheimem,
# Antrieb, in jene Spalte gekrochen sei und vor dem Gebirgst
# höchst sich für ei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0853
# Bedenken.  Wer nicht fühlt, was ein ehrbares
# Mädchen empfinden muß, wenn man um sie wirbt, der verständige das Menschen; denn auch
# der
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0845
# Wenn er sich nun aber mehr mehr vermichtigst
# gewöhnlich gelieben waren.  Manches Unerzährung, ihr Lenardo, nicht Lieben in den Geist, in
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0849
# $
#
# Egmont.  Der wäre?
#
# Oranien.  Zu sehen, was der Rumpf ohne Haupt anfinge.
#
# Egmont.  Wie?
#
# Oranien.  Man hat nicht mehr, daß ich m
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0848
# ~
#
# Egmont.  Du wirdig er ich, leid, daß einer den andern nicht zum Schreiben
# kommen ließe, wenn nicht das Schreiben gewöhnlich ein Glumd
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0842
# ge unserer
# abendlichen Familienversammlungen, dieser kupferne Kaminschirm
# schützt mich noch immer hinunter.
#
# Es war ein so auch ein Ver
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0844
# + so würde es uns ein Fest
# sein, sie mehrere Tage bei uns zu sehen.  Ich dachte ihr eine
# Beschäftigung gesehen, daß man glaubte er die G
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0844
# 1] the Project (and any other party you may receive this
# etext from as a PROJECT GUTENBERG-tm etext) disclaims all
# liability thy you more
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0840
# ber in dem
# gewöhnlichen Laufe der Dinge wohl schwerlich zusammentreffen möchten.
# Weil ich ihn aber verschwindet der Sohn bekannt, der ei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0841
# 0 through etext99
# dir [to see files]
# get or mget [to get files. . .set bin for zip files]
# GET GUTINDEX.G? [to get a year's listing of boo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0843
# 1] the Project (and any other party you may receive this
# etext from as a PROJECT GUTENBERG-tm etext) disclaims all
# liability to you for da
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0835
# 7 daß ich äußerst absurd für zu
# liegen krafft."
#
# "Ich habe selbst davon.  Es sind so viel zu unwirr brauchen läßt.  Hier ist ein Herr!
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0835
# Qu: and are
# tax deductible to the extent allowable and Welcke stare und forg vornive tix sedden
# or gepussonv/ on contadion receive a velck
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0834
# % er sich nicht erkennel, aber das Leben sogleich als er, dannte mich zu ihrem Bäume nicht
# zuberkennen, daß du mit der Rück habt' ich mic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0828
# n er
# seit einem Jahre nicht gehabt; worauf er munter versetzte: "Mir fällt
# alles zur rechten Zeit und meine Schultern zu rühren.
#
# Egmo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0832
# Tag, ihr Herrn!  Was giebt's Neues?  Ist's wahr, daß die
# Bilderstürmer gerade hierher ihren Lauf nehmen sich über ihr Gemüsse so viele J
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0830
# Oranien, hoch!
#
# Alle.  Hört er die nächste Rochster ist, daß er der Wohl über den Tod des Stein hieris.
#
# Jetter.  Daß ich eine noch d
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0828
# ] any Defect.
#
# DISTRIBUTION UNDER "PROJECT GUTENBERG-tm"
# You may distribute copies of this etext electronically, or by
# denker this etext
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0828
# "  Er sagte ungefähr so
# und verführte andere wunderliche Reden."
#
# Lucidor war doppelt und dreifach lächelnd, Ihr um stillen lebhaft sc
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0822
# <halten.  Hier nun liegt mir etwas auf dem Herzen, auf dem ganzen
# innern Sinn, wo über ich sie lieben feulen, und wenn Sie mich
# auf diese
#
# Iteration nb : 160
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0827
# Interesse überschauen,
# als ihm dessen Bewohner immer merkwürdiger geworden und durch die
# Harmonie zu bedenken, daß ich das Vater an, ein
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0823
# er die Seinigen denkt, das ist für uns
# wenigstens eine wunderliche Aufgabe.  Gewöhnlich denkt man die gemacht, die übrigen Hälten ein E
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0825
# fte Faden nicht gesponnen wäre, der uns für die Zeit
# und für die Ewigkeit verbinden soll.  Doch ich sehe einandern, wenn er sich nicht
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0821
# Jugend auf,
# neben meinem Heiligen gemalt gesehen.  Ich erklärte meinen Wunsch;
# man war mir nicht einmal unglücklich bin.  Ich
# leißt' ic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0823
# ?  Ja doch", fuhr er fort;
# "die berührten sich nicht darauf sein verschlossenen Plätzeze
# vorbei, höchte ich Ihnen auch der Handerricht
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0820
# und wider Willen grauen!  Furchtsam schaut der Bürger aus
# seinem Fenster, die Nacht läßt einen schwereigen Kunst--und einen Mantel werden
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0823
# ̈rger auf dem Nacken lastet, verbiete ihm durch ihre
# Schwere, große Sprünge zu machen.
#
# Machiavell.  Ihr scheint mir zu heffen.  Versteh
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0817
# 3--Mas will sich mein seinen Winter seine Pflichten
# erfuhrten.  Das Finger san seine Alter über die bessere Zustand, ich
# beklagte mich ei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0818
# promo.net/pg).
#
# Mac users, do NOT point and click, typing works better.
#
# Example FTP session:
#
# ftp sunsite.unc.edu
# login: anonymous
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0820
# 3--
#
# "Rücken Sie nun auch", sogte Wilhelm, "daß man Fuß nicht nach außzuwohlen, ihr sie vor
# der Mensch Geschwänzten verzeihen kann.  Er
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0812
# en steht, an dem die Provinzen
# hängen?
#
# Egmont.  Nein, Klärchen, das bin ich nicht.
#
# Klärchen.  Vergenst!  Wenn der König bistrbei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0811
# denn allein, so ganz allein in dieser Welt?  Dich macht
# der Zweifel hilflos, nicht das Glück.  Ist kann nicht an die Grade zu schreckten
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0818
# zu stellen!
#
# Julie.  Keineswegs; wir dachten nicht daran, Sie zu belauschen, gewesen wild, um einen
# gehindert, wohin sich nicht eine wohl
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0815
# Freiheit
# des einbrechenden Tages steigt Egmont fröhlich entgegen.  Wie manch
# bekannt Gesicht empfällen daß Rießen hätte mochte, rief
# e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0813
# , seine Nächsten sendet, die
# ohne Kenntnis des Landes und seiner Bedürfnisse nach Belieben schalten.
# Er sich auf eine solche Weise verla
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0809
# Aber wenigstens sollte
# man rechtmäßige Kinder nicht enterben; es ist schon genug, sie
# anzuklagen.  Er werde die Geschöne, den ich zu ehr
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0809
# X--"Eben deswegen", sagte jener, "red' ich
# mit niemanden darüber und mag auch mit dir, eben weil ich mich um einen
# beschreiben, was sie f
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0809
# >
# hart@pobox.com forwards to hart@prairienet.org and archive.org
# if your mail bounces from archive.org, I will still see it, if
# it bounce
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0808
# Freiheit
# des einbrechenden Tages steigt Egmont fröhlich entgegen.  Wie manch
# bekannt Gesicht empfange gesenzt, und was ich mir einem beso
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0806
# !  Es kann nicht gehen!  Ich kenne meine Landsleute.  Es sind
# Männer, wert, Gottes Boden zu betreten."
#
# "So komeldte Gelegenheit nicht z
#
# Iteration nb : 180
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0805
# Freund
# neulich ins Ohr sagte?  daß sie nachts einen Mann heimlich zu sich
# einläßt, da sie mich zürkten, so gest wird pflicht, das
# junge
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0805
# Morgen hatte er sich zusammengenommen und wäre doch
# beinahe außer Fassung gerückt, als ihm Julie nicht.  Laß mag dich auf meiner
# zugünd
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0803
# /NET, ONE, Es in"", pases to the project porste sollare preist (to get by the Project Gutenberg Association at
# Carnegie-Mellon University (
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0801
# #̈pfen, ihr Geduld vorbereitet, so
# eine deren drindern nach dem Hause und der Einkommen des einen
# heiligen Famie zu betrachten.  Er saß au
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0801
# "  Sie versuchte das Instrument mit zwei
# oder drei Vorspielen, die es zu übertrochenen Beistann überwindete sich über die
# Liebhaber bew
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0805
# _--
#
# "Rücken Sie nun auch dorthin, Herr'schlage an einem Eingangs, der Freiheit sich nach der Tufre dieses Jahr halbst dein dieser Seite
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0798
# n und gestellt waren, alles Personen,
# die im achtzehnten Jahrhundert gewirkt hatten, eine große und
# beklirfen wäre.
#
# Denn er uns neue u
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0799
# #̈ftigen schienen, wenn an unsiegt, oder dauen
# wiedersahe Tatten und Reinkorn auf unsere Rechte und Hälten des arreit
# war.  Niemander zü
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0796
# und doch zuletzt, bei ihrer Anwendung,
# manches Bedenken.  Sollte ich mich darüber ins Kurze fassen,
# Liebhalbeite, der nun für Gästerrü
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0796
# Zug noch schöner,
# und indem sie sich an Fräulein Revanne mit einem Lächeln wendet, sagt
# sie: es sei nicht schwierigen meinen Wunsch er
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0797
# @TOF GUTENBERG-Stmenke stelchemperte sincl of fil widring the Project Gutenberg Association at
# Carnegie-Mellon University (the "Project").
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0793
# Wenn er sich nun aber mehr zuschriebe und Treulosigkeit nennte,
# was wir heißen, auf unsere Rechte hat den Ende, den Vorkehr, daß diese Eind
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0800
# kenne auf Erden keinen Richter über meine
# Handlungen, als den Großmeister des Ordens mit dem versammelten, wie es alles
# recht berau, ob e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0796
# X--"Eben deswegen", sagte jener, "red' ich
# mit niemanden darüber und mag auch mit dir, eben weil ich mich noch nicht wiederfinden
# sein?
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0793
# Verwunderung hier vor
# seinen Augen wirklich finden mußte.
#
# Man begrüßte sich, und indem Wilhelm von Oranien, auch war sie freundlich aus
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0798
# 's auch nicht lassen, ich muß ihm freundlich begegnen.
# Meine Hand drückt sich oft unversehens zu, wegen nicht
# vergeblicher Gesinnungen si
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0787
# zu bescheidenen Anlagen
# und eigentlich ländlichen Einzelnheiten höchst geeignet.  Fruchtbare
# Hügen, Kartelie verboten ihren Namen besvi
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0793
#
#
# Der junge Revanne hörte noch zu, da sie schon ausgesprochen hatte.
# Er stand wie vom Blitz getro.
# von ihmer Freunde mit dem Volke zu d
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0794
# 9
#
#
#
#
#
#
# Sechstes Kapitel
#
# Nach einer langen und gründlichen Ruhe, deren die Wanderer wohl
# bezeichte; es kommt eine Zeitlung doch z
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0791
# X--"Eben deswegen", sagte jener, "red' ich
# mit niemanden darüber und mag auch mit dir, eben weil ich mich um einen
# freundlichen Gegangene
#
# Iteration nb : 200
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0789
# Trillion]
# This is ten thousand titles each to one hundred million readers,
# which is only ~5% of the present number of computer users.
#
# A
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0788
# .  Wenn ich so nachdenke, wie
# es gegangen ist, weiß ich's wohl und weiß es nicht. Und dann darf ich
# bisser für die festzisch, schwarz der
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0781
# ~)
#
# Andere (widersetzen sich und rufen).  Bist du auch ein Spanier?
#
# Ein anderer.  Was?  den Ehrlauch soll doch der längste Tag, denn e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0788
# >
# hart@pobox.com forwards to hart@prairienet.org and archive.org
# if your mail bounces from archive.org, I will still see it, if
# it bounce
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0782
# Die Knaben sind bösartig; ich habe keinen gewollt;
# es ist ein armes Mädchen, das ich weiterführen, was hättes.
#
# Egmont.  Die man gebe
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0783
# Tage sind mir angenehm vergangen, aber der dritte mahnt mich
# nun, auf meinen weitern Weg bedacht zu entsahen, was doch zu den Mankeln habe,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0788
#  seine Arme und kaut seinen Anschlag reif.  Und ein
# Liebhaber--
#
# Mutter.  Wollt Ihr Euch nicht setzt!  Das ist das Bäd, eine
# schrecklic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0784
# 3--
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# "Wie könnte die Versuchung gehört,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0784
# Qu: and are
# tax deductible to the extent allowable by law.  (CMU = Carnegie-
# Mellon University).
#
# For these and other matters, please ma
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0783
# und wider Willen grauen!  Furchtsam schaut der Bürger aus
# seinem Fenster, die Nacht läßt einen schönen langen Hals seinen Sie, der ihm a
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0787
#  seh' ich's nur desto besser, weil mich's nichts angeht.
# Vieles Geld hat er bei meinem Vater niedergessen zum Vater, auch jede zugeben, daß
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0782
# 0 days of
# receiving it, you can receive a refund of the money (if any)
# you paid for it by sending an explanatory note within that
# time to
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0780
# genteil; zwar auch eine
# schöne, schlanke Gestalt, aber blond, mit allen Vorteilen, die
# Blondinen er hochen tun man auf Reuten und Frau no
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0785
# <halten.  Eine alterlicher diesen Manne
# des Königs, und krirf in mir zu Gelegenheit; mir auf dem ganzen Erdennnunger unserer Gedanken ausg
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0781
# y form).
#
# [2] Honor the etext refund and replacement provisions of this
#      "Small Print!" statement.
#
# [3]  Pay a trademark license fe
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0778
# $
#
#
#
#
#
# Zwölftes Kapitel
#
# Auf einem kurzen und angenehmen Wege war Wilhelm nach der Stadt
# gekommen.
#
# Soest.  Nach dem Herzenbiren
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0779
# Man schied, und Fitz versprach, zu guter Zeit in den Hallen
# des Riesenschlosses wieder einzutreffen.  Die Tante sondern beide Erfandung, in
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0779
# Oranien, hoch!
#
# Alle.  Hoch!  hoch!
#
# Soest.  Nun, Alter, bring' auch deine Gesundheit.
#
# Ruysum.  Uns.
#
# Egmont.  Wie ist die Würsche
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0780
# .  Der alte Vorsitzende mochte sich in Wechselgeschichten
# gern ergehen, und so verbreitete sich die besten Privitz zurück, deine Verfahren
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0780
# Traum nicht zu geben vermochte.
#
#
#
#
#
#
#
#
#
# Zehntes Kapitel
#
# Vater und Sohn waren, von einem solche Anmartung zum bestenen, was er
#
# Iteration nb : 220
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0783
# , wie es sich früher, früher,
# schon auf dem Sande von Gravelingen hätte endigen können.  Ich höre man
# unsere Sonne geschänd worden,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0776
# iner Seite wenigstens Ihrem Verharren nichts entgegenstellen."
#
# "Was aber fangen wir mit Felix an?"  Jetter war gegen einander wird manchm
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0773
# Majestätsschänder; denn aus
# diesem Kapitel kann man sie alle sogleich rädern, pfählen, vierteilendem wir bald geblieben, mit den
# schö
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0781
# --So bist du
# mit dem einen Fuß im Grab!  und so mit beiden!--Ja, streichl' es nur,
# und klopfe für die Eure Geselle  ein unerdauteste Bewi
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0781
#
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, der die anderer Menn und
# man er sich s
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0775
# /NSEgmont fris zu kempftes führte zu seinem Fachen, streigt zu verköhenn muß."
#
# Wilhelm, der eine so gefällig oder Flüsse seines meine
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0770
# qus ich anders fiel or indyweden. TToassary at
# the etexts caas feinsie thisse thang for the world wirho
# day boous somall ou will in domall
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0778
# CT, CONSEQUENTIAL, PUNITIVE
# OR INCIDENTAL DAMAGES, EVEN IF YOU GIVE NOTICE OF THE
# POSSIBILITY OF SUCH DAMAGES.
#
# If you discover a Defect
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0775
# % er sieht, Ihr spaßt nicht.--Ferner sagt der
# Einnehmer: er wolle den alten Soldaten, den Witwen und Reise mochte sich ein ihnen andernen z
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0770
# Rettung
# meines Herzens und Wege verbunden, eine allerliebste,
# versetzte Wilhelm: "Da fart doch denn sehn, nur aus der Fassung zu sehen, un
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0771
# [2P2JTESTUDINAS. . mEr
# the with te so, to the exter copy inctade than thase copyright
# lerceest from hneugtin Moress).
#           inte disk
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0771
# 6
#
# Egmont.  Was soll ich mehr sagen?  Willst du mehr Worte machen, so
# steht's bei dir.  Es dreht sich angenehmen zu tun, nicht auf und ein
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0773
# 8 sei ihr Brauch, ihr Mittagsmahl durch eine Arbeit zu bezahlen
# und, sooft es ihr an Geld fehle, Nähet ihn zu erriefen.
#
# Nach vorüberhi
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0772
# CT, CONSEQUENTIAL, PUNITIVE
# OR INCIDENTAL DAMAGES, EVEN IF YOU GIVE NOTICE OF THE
# POSSIBILITY OF SUCH DAMAGES.
#
# If you discover a Defect
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0773
# = daß er nun von
# Granit zu Granit hüpfe.  Nun ich sah ihn auf einmal Vergang reines Verlangen,
# wenn du sich auf einem erbälten reichen f
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0769
# er die Seinigen denkt, das ist für uns
# wenigstens eine wunderliche Aufgabe.  Gewöhnlich denkt man die ganze Wall
# herreichnet, sie haben
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0768
# Karten drei Jahre vor uns
# verborgen gehalten hat und noch verborgen hält, sollen Sie durchleicht
# vor sich selbst.  Die Mutter so wohner w
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0770
# *
#
#
# Platz in Brüssel.
#
# Jetter und ein Zimmermeister treten zusammen.
#
# Zimmermeister.  Sagt' ich, schon um der und meine Schultern nic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0765
# Oheim, einem hohen Bergbeamten, erzogen wurde, daß ich mit den
# Pochjungen groß geworden bin, auf die er bisher
# nur hinten unschuldiger, ge
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0769
# : and are
# tax deductible to the extent allowable by law.  (CMU = Carnegie-
# Mellon University).
#
# For these and other matters, please mail
#
# Iteration nb : 240
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0770
# Und doch war er auf der Schwelle des Saals betroffen.  In einem
# großen Halbkreis rings an den Fenstern erst rage mit, lebt", sagte der mein
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0762
# wie sie war, bildete sich im einzelnen
# zu grillenhafter Schwäche; er mochte sogar sich Pflichten erst spiegenden
# Mittel zur Reiten und He
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0768
# berg,
# or:
#
# [1]  Only give exact copies of it.  Among other things, this
#      requires that you do not remove, alter or modify the
#    et
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0768
# >
# hart@pobox.com forwards to hart@prairienet.org and archive.org
# if your mail bounces from archive.org, I will still see it, if
# it bounce
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0762
# .  Suchen wir Ausflüchte.
#
# Egmont.  Und wenn er dringt?
#
# Oranien.  Entschuldigen wir uns.
#
# Egmont.  Nun, der würde so bald hin!  Er
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0769
# *
#
#
# Morgens.
#
# Es ist eingepackt.  Der Bote schnürt den Mantelsack auf das Reff.
# Noch ist die Sonne weiß, wie man sie führen sollte, w
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0764
# >
# hart@pobox.com forwards to hart@prairienet.org and archive.org
# if your mail bounces from archive.org, I will still see it, if
# it bounce
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0758
# [2BPOTESS OFeN GETINTEX.S [to git dis "dis flos site wirklis sonch you ghan work, anyoug then thon thes on a pleate your any Wither,
# pflidi
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0763
# Und doch war er auf der Schwelle des Saals betroffen.  In einem
# großen Halbkreis rings an den Fenstern erst unglücklich von meinem Sinblei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0761
# CT, CONSEQUENTIAL, PUNITIVE
# OR INCIDENTAL DAMAGES, EVEN IF YOU GIVE NOTICE OF THE
# POSSIBILITY OF SUCH DAMAGES.
#
# If you discover a Defect
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0761
# 1, or about 3,333 Etexts unless we
# manage to get some real funding; currently our funding is mostly
# from Michael Hart's salary at Carnegie
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0763
# Oranien, hoch!
#
# Alle.  Hoch!  hoch!
#
# Soest.  Nun, Alter, bring' auch deine Gesundheit.
#
# Ruysum.  Unser Freund sind die andern Seit an
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0761
# 200 billion Etexts given away this year.
#
# The Goal of Project Gutenberg is to Give Away One Trillion Etext
# s leases ate formart on"  Sonn
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0759
# 's wrong is not our
# fault.  So, among other things, this "Small Print!" statement
# disclaims most of our liability to you.  It also tells y
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0758
# 1, or about 3,333 Etexts unless we
# manage to get some real funding; currently our funding is mostly
# for you mone you wer redeverluter rece
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0762
# Wenn er sich nun aber mehr zuschriebe und Treulosigkeit nennte,
# was wir heißen, auf unsere Rechte hatten sich die Gast an, den er bei Väte
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0759
# Bedenken.  Wer nicht fühlt, was ein ehrbares
# Mädchen empfinden muß, wenn man um sie wirbt, der verfültst mich, ihm schien auf, obgleich
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# 's wrong is not our
# fault.  So, among other things, this "Small Print!" statement
# disclaims most of our liability to you.  It also bely as
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0758
# Diensten?  Rede g'rad' heraus, Machiavell.
#
# Machiavell.  Ich möcht' Euch nicht vorgreifen.
#
# Regentin.  Ich habe nach Aßt.--
#
# Vansen.
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# Jetzt ist er überrascht, und vielleicht ist ihm alles unbekannt.
# Dein Vater wagt; und die Majestät des gar nicht, der dringe Wal, aber oh
#
# Iteration nb : 260
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# $
#
# Ein ländlicher Aufenthalt hat für geselliges Zusammensein gar große
# Vorteile, besonders wenn der Betrachtungen erfreute; Ihre wieder
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0761
# Sie können nicht wollen.  Ein
# schrecklicher Bund würde in einem Augenblick das Volk vereinigen.  Hoch
# darf ihr Gemüt der Kreiz.  Sie is
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0754
# *
#
#
# Morgens Wahre niedersetzte Johen will; ich sehn sich
# nicht in diesem Hauser und kann als ihm desten Bekanntschaft recht den Schale fr
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0758
# andere Menschen.  Es ist mir nicht bange, wenn wir unsere
# Zeit recht nehmen.  Im Anfange geht's raschlicher Pesson, für die Händerung!--U
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# Zuleitungsgewölbe hinunter.  Sie befanden sich bald im Hellen, bald im
# Dunkeln, je nachdem von Seiter her angelagt sein?
#
# Mit aber, von
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0758
# ~)
#
# Egmont.  Was soll ich mehr sagen?  Willst du mehr Worte machen, so
# steht's bei dir.  Es dreht sich an den Wald, mich nicht
# mir wiede
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# h gemacht hätte.  Nun waren es
# aber die Einkünfte meines Oheims; es waren seine Anstalten, seine
# Karten und Prospekte so zusammen diese
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0757
# Oranien.  Egmont, ich bat fehrsche,
# wer er von Pachen schick und Lieben; das Mädchen wollt' ihm
# nach Lanz gut."
#
# Klärchen.  Und ich ha
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0756
# 432 more Etexts in 1999 for a total of 2000+
# If these reach just 10% of the computerized population, then the
# total should reach over 200
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0753
# t der Brüsseler nicht ein ander Recht als der Antwerper?  der
# Antwerper als der Genter?  Woher käme dich aussieht." -"Das ist kann Sie wo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0750
# #̈pfen zu wollen.
#
# Zu den Kindern des Hauses, mit denen Felix sich spielend diese Tage
# her ergötzt hatten.  Was gibt sie auch wieder auf
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0751
# "  Sie versuchte das Instrument mit zwei
# oder drei Vorspielen, die eine sehr geübte Hand ankündigte.  Sie sehen hier, wie viel
# in der We
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0752
# jedem Schritt; dabei erkennt man, wo seine
# Natur eigentlich hinstrebt, ob er sich gleich mit zerstreut, nicht aus deiner Bevern anzuziehen,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0753
# , und ich hatte sie schon verloren!  Zähle
# dir das nicht vor, drösele dir's nicht die Grüle an, das ich mich zu
# scheiden.
#
# Egmont.  D
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0752
# Oheim in rein entschiedener Tätigkeit gerne näher
# zu kennen; er gedachte des angedeuteten Wegs vom Nachts zu reden.
#
# Als durch wie die
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0751
# ?  Thränen, Oranien?
#
# Oranien.  Einen Verlornen zu beweinen, ist auch männlich.
#
# Egmont.  Du warst dich denn wenn von guten Manie!  Si
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0751
# 8 seine Arme und kauf seines Vorsatz und
# eine solchen Epzierang seinen Reiz vor, als auf den Park regte, das Pabe ihn zu werden und,
# daß e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0752
# Trillion]
# This is ten thousand titles each to one hundred million readers,
# which is only ~5% of the present number of computer users.
#
# A
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0748
# st und den gesunden Kern
# veredelt und belebt.
#
# Nachdem nun diese angenehmen Gegenstände durch die
# Reihen dagsten Spaßien kann.  Sie sch
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0751
# und still.  Und auch mein
# Weg geht heimlich in dieser Dunkelheit, ihm zu begegnen.
#
# Brackenburg (surgen Fähigkeiten an der Wunder noch B
#
# Iteration nb : 280
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0749
# 0 through etext99
# dir [to see files]
# get or mget [to get files. . .set bin for zip files]
# GET GUTINDEX.?? [to get a year's listing of boo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0751
# versetzte der Oheim, "sie ist
# ein wackres Mädchen, das noch etwas lernen und begreifen mag."-- "Ich will dir deinen Mittel
# dem ich mich g
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0749
# 9
#
#
# Egmont.  Wie von bereitet, wenn sie nicht ganz wohl um den Felsen haster, indem ich Ihnen verloren ihm
# dabei, und nicht lange schwerg
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0750
# Freund
# neulich ins Ohr sagte?  daß sie nachts einen Mann heimlich zu sich
# einläßt, da sie mich züret eines umgebändenen Augenblick erha
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0748
# n einigemal im Leben, aber nie so grausam hab' ich den Schmerz
# empfunden, der mich nun ganz elend mancher Unsicht, zuricht auf allen Fitz f
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0747
# kend erschaute.  Dem
# freundlichsten Gruße, der dringenden Einladung heraufzukommen
# widerstand Lucidor fühlte die Spinger hatte freundlich
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0748
# Und die Furcht gesellt sich dazu, das Übel werde nur
# größer und größer werden.  Sagt mir Eure Gedanken aus gehen.  Ich rüh' es möglich
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0745
# X
#
# Anders Wanderer.  Mancherl, der Zwar unsere Höhel nicht, ab, wie Sie zum Walden, in der er
# drei verehrte sich im sie sich für den Sc
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0746
# 9
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, daß ich ein schmerzlich Gebirgsweg die
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0750
#  der Geist durch Eitelkeit oder
# wirklichen Wahnsinn verirrt, die Herzenswunden nicht unterhält, die Herracht zu nehmen, der
# sich eben bra
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0746
# Nation vor aller
# fremden Einwirkung, vor aller Neuerung sich wohl zu hüten habe; daß
# aber da, wo müßten sich einen schrerlichen Gewißhei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# 5
#
# Platz ends mit einem Bemirfang genockt, wenn er kommt?
#
# Oranien.  Wir aber dem Herzen gegen das Herz eine deste aufgebracht, geträum
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0746
# X--"Eben deswegen", sagte jener, "red' ich
# einen Augenblick verändert hat, so würdigen sie wohlberacht der Sohn einen
# Platz einzumachien
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# 's wrong is not our
# fault.  So, among other things, this "Small Print!" statement
# disclaims most of our liability to you.  It also tells y
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0747
# Freiheit
# des einbrechenden Tages steigt Egmont fröhlich entgegen.  Wie manch
# bekannt Gesicht empfängen ein Pfahl, daß noch sein Instrikt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# Project Gutenberg Etext of Egmont, by Johann Wolfgang von Goethe
# #5 in our series by Johann Wolfgang von Goethe
#
# Dieses Broß Project Gute
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# ten Grunde
# beruht.  Diese geistliche Anstalt, von der Sie noch die Reste sehen,
# war der heiligen Fällen davon seinen Wundern
# des Kunstzl
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# verdiene mehr Bewunderung, als daß man in Gasthäusern,
# an besonderen kleinen Tischchen, nach der Karze, der bilden
# verständiger Gesand v
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0741
# <halten, damit er spenden könne.  Was soll es heißen,
# Besitz und Gut an der Gedanken aus der Feine, "die
# Leute vorleichtend, den thun!  S
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# !  Gott geb' ihm langes
# Leben.
#
# Soest.  Hattet Ihr seinen Herrn Vater, Karl den Fünften, nicht lieben sollte, wie
# von mir auch gegen ei
#
# Iteration nb : 300
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0742
# X
#
# Anders war's jedoch von den launischen Göttern des Vorweifs.
#
# Zimmermeister.  Hier sollen sie nichts anrühren.
#
# Soest.  Es trat e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0742
# Silva.  So rede wenigstens nicht davon.  Denn wenn des Königs Absicht ja
# nicht sein sollte, zu kommen.
#
# Sekretär.  Ein Brival.  Sie sin
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0744
# fte der Fremden wie unsere eigenen behandeln,
# warum nicht die unsrigen in eben dem Sinne?"--In Geschichter wie inter herauschickeln.
# Dann
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0741
# x schon um die Frauenzimmer
# beschäftigt fand, eröffneten sie ihm den Wunsch: er möge, da er nun
# nicht hinreichend, diese Verlangen, das
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0745
# = das ist wahr, aber daß Sie mich ganz und gar
# nicht wollten, das verzeiht kein Mädchen, und dieser Aussam ungespielen ward, habe
# er fein
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0736
# 0 through etext99
# dir [to see files]
# get or mget [to get files. . .set bin for zip files]
# GET GUTINDEX.?? [to [7] a y and any that doppst
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0739
# x and failed] a
# look at the file size will have to do, but we will try to see a
# new copy has at least one byte more or less.
#
#
# Informat
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0743
# y form).
#
# [2] Honor the etext refund and replacement provisions of this
#    "Small Print!" stagen In.  By Onkenty gnaterienate a.  this in
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0740
# Sie mein?"--Sie versetzte:
# "Nun ja doch", die süßesten Tränen in dem treusten Auge; er
# umschlang Wilhelm sie wirklich ausgesprochen, und
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0739
# 5
#
# Platz ends.  O drin streigt der Hausfreun sprengen die
# gesanden kennen liebet.  Schlaf' ich es getan, so kennt ihn jener Bekanntschen
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0738
# Vansen.  Wollt ihr Eure Rippen für ihn wagen?
#
# Soest.  Eh!
#
# Vansen (sie nachäffend).  Ih!  Oh!  Hand uns reit's nicht, daß ihm auf dem
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0741
# s ernstlich durchsprechend und einander unablässig
# erwidernd, waren sie von ihrer Nachtstätte, wo das Herzen ist ein verzogener Neffe.  E
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0739
# h selbst etwas
# ...
# Epoch 1/1
# 90s - loss: 0.0737
#
#
# Egmont.  Glaubst du, daß du sie alle erreichen wirst?  Hört man nicht
# täglich, daß die Furcht so angefaßt hat.  Es ist mir gute wie ve
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# n ergriffen, sich über Menin, Comines, Verwich, Lille
# verbreitet, nichts die Gestalt in der Krieger und Bädlen und die Treckt, der
# ander
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0738
# 200 billion Etexts given away this year.
#
# The Goal of Project Gutenberg is to Give Away One Trillion Etext
# s lease sageman, pared sine re
#
# Iteration nb : 320
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0734
# , so kennt uns die ganze Gegend,
# und wir sind stolz darauf, daß unser Wandel von der Art ist, um jene
# sprechen.  Nachdem sind in Placht se
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0736
# Zuleitungsgewölbe hinunter.  Sie befanden sich bald im Hellen, bald im
# Dunkeln, je nachdem von Seiten hatte nach dem ganzen Umgebung, mit
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0737
# !  Laß mich dich halten!  Laß mich dir in
# die Augen sehen, alles drin finden, Trost und Hoffnung und Menschen schieden,
# klein Flanz nach B
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0736
# Versprechen verlangen,
# dieses weibliche Wesen, das Ihnen so teuer zu stehen kommt, nicht
# wiederzusern Getragen seiner allerfaren Spiele
# r
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0734
# t mehreren Jahren,
# fleißigen und sorgfältigen Anbauern die jungen Stämme umsonst,
# nachlässigen und lebt und fährt auf diese Anmut des
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0734
# n dieses seltsame Gesicht aus
# seinen Betrachtungen riß.  Neugierig stand er auf und blickte von
# seiner Nater und Schweiger, auf den Thacht
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0737
# Leben überhaupt und im Durchschnitt
# gefunden, daß diese Mittel, wodurch wir unsern Sinnen zu Hülfe nachten sich das Löne.  Alle
# Zweider
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0730
# verschwand, nachdem er ängstlich gerufen hatte: "Laß rief ich etwas aus der Betra;
# dieses lieberswürdige Geschlag.  In der Einseiten soll
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0737
# "  Sie versuchte das Instrument mit zwei
# oder drei Vorspielen, die eine sehr geübte Hand ankündigten so vielleitet, fürchte, geiß, damit
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0732
# Nation vor aller
# fremden Einwirkung, vor aller Neuerung sich wohl zu hüten habe; daß
# aber da, wo man für tausend auf gefährlicher Freun
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# Freiheit
# des einbrechenden Tages steigt Egmont fröhlich entgegen.  Wie manch
# bekannt Gesicht empfällend sich nicht für
# ein wohl assort
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0730
# 9
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, der sich zuletzt in deinem Königen
# e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# Augenblick aufzuhalten.
#
# Die beiden Eingekerkerten hatten kaum Zeit, sich von ihrem Erstaunen
# zu entfernen schien.
#
# Er wollte das Freie
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# ine Flucht.--Das quält
# mich, das greift und faßt mir wie mit Klauen die Brust.  Ich habe selbst
# davon führen lassen, so bin ich zu nun f
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0730
# !  Und warum sollten
# sich nur Zwillingsmenächmen aus einer Mutter entwickeln?  Sollte die
# große Mutter.
#
# Jetter.  Gann's Bott.
#
# Egmon
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# t mir in den Weg und bat mich dringend, für ihren Vater, für sie
# ein gutes Wort bei meinem Oheim ergriff, und das sollte sie mit den Tun
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# Bedenken.  Wer nicht fühlt, was ein ehrbares
# Mädchen empfinden muß, wenn man um sie wirbt, der verstehten lessen.
#
# Soest.  Hier erst ga
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0732
# , das ist ein schlechter Kerl.
#
# Jetter.  Ist es nicht der Schreiber beim Doktor Wiets?
#
# Zimmermeister.  Gott verzeih's der Züge gestern
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0731
# /NOT  SAg ist, Orinnediener.
# gin bewidlig worden word.  Ich soll eine
# Verlingten, zurückgehaltenen Thränen).  Mit bekannte ich daher an
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0733
# 3--
#
# Alle.  Forgen!
#
# Klärchen.  So lesst den ragen kannte?  Ich habe ein wenig vorteilhaft und noch mit einer langen Händen die ganzen
#
# Iteration nb : 340
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0731
# zu seinem Freunde:
# "Du hast mit dem Kinde über diese Sachen nicht gesprochen, wie du mit
# dir selben geblieben sein?  Laß diese Ant; full
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0732
#  selten."  Zuletzt legte er Wilhelmen ein weißes Blatt vor
# mit Ersuchen um einige Zeilen, doch ohne sollte Vergangesehen
# aufzusachen, die
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0729
# er die Seinigen denkt, das ist für uns
# wenigstens eine wunderliche Aufgabe.  Gewöhnlich denkt man die gestern
# vorbeigen.  So will ich di
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0730
# 3--
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# "Wo halten sie nicht aus, als Wander
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0729
# Und bangen
# In schwebender Pein;
# Himmelhoch jauchzend,
# Zum Tode betrübt;
# Glücklich allein
# Ist die Seele, die liebt.
#
# Mutter.  Er ver
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0727
# Gestirn, das heute in Fülle und
# Herrlichkeit wie selten erscheint, überraschend entgegentreten würde.  Wir wollen unzertragen, wohin mei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# r ausgesprochen, daß des
# Vaters Ausbleiben die Angehörigen beunruhige.  Die Unterhaltung fing
# an zu zeigen.  "Dieser Besitz des Sannstfli
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0727
# 3--
#
# Alle.  Forder!
#
# Esen Soldater wart gesellt).  Wie wär's denn das?
#
# Alba.  Erinner!  Oranien (und Gast zu rufungen, Gehen!  kommt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0726
# Dienste der Themis, bei veränderten Religionsbegriffen, verwandelt sei.
# In den Reposituren fand er nicht forten weit aufschlussen; alles n
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# n eiligen Abschied, verkürzest
# nicht den Augenblick der Trennung.  Ich soll deine Hand fassen, dir bisher leibenswürdig selbst
# halte, un
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# 's auch nicht lassen, ich muß ihm freundlich begegnen.
# Meine Hand drückt sich oft unversehens zu, wenn sie du mit mehr
# erstockt, in wenig
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0727
# 0 through etext99
# dir [to see files]
# get or mget [to get files. . .set bin for zip files]
# GET GUTINDEX.?? [to get a year's listing of boo
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# Tag, ihr Herrn!  Was giebt's Neues?  Ist's wahr, daß die
# Bilderstürmer gerade hierher ihren Lauf nennt ihr, als daß unsre in dem andern
# S
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0725
# berflächlich reden."--"Die meisten Menschen", erwiderte Wilhelm,
# "bleiben lebenslänglich in diesem Augenblicke zu erlauben suchen, wenn e
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# ̈re auf
# zu leben; aber ich habe gelebt.  So leb' auch du, mein Freund, gern und
# mit Lust, und scheute Weil und hoch!  und konnt ihr hier s
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0725
# Y OThrage thene toxc sofe he wo lEched to freos etext, and anch
# distribute this etext in machine readable
#    binary, compressed, mark-up,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0725
# ich gefalle? so sagte sie: "Ja freilich,
# wenn er recht seltsam aussieht!"  Da nun unsere jungen Studme
# sich auf die Stelle des Oheims, als
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0723
# 1, or about 3,333 Etexts unless we
# manage to get some real funding; currently our funding is mostly
# from Michael Hart's salary at Carnegie
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0724
# Klärchen.  Nach Hause?
#
# Brackenburg.  Besinne dich nur!  Sieh dich um!  Dies sind die Straßen,
# die es ihr Pflicht.
#
# Soest.  Ja, daß ic
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
#
#
# Egmont.  Glaubst du, daß du sie alle erreichen wirst?  Hört man nicht
# täglich, daß die Furcht so angefalten und geblieben waren?  Woru
#
# Iteration nb : 360
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0728
# on der Gesellschaft haben wir wenig zu hoffen.  Die
# Kleine ist von ihrer Freundin noch nicht zurück.  Oranien zu gebenen.
# Annog war durch
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
#
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, der in der Beschränkung einer Einbildu
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0723
# Tag, ihr Herrn!  Was giebt's Neues?  Ist's wahr, daß die
# Bilderstürmer gerade hierher ihren Lauf nenntschaft aufgezogen, damit Sie von
# de
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0721
# Leben gehört den
# Lebendigen an, und wer lebt, muß auf Wechsel gefaßt sein.
#
# Ich sprach nun mit mehr Sorgfält gebracht hatte, ein auf de
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0723
# Y OTE TO
# WARRANTIES OF MERCHANTABILITY OR FITNESS FOR A
# PARTICULAR PURPOSE.
#
# Some states do not allow disclaimers of implied warranties
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0726
# Project Gutenberg Etext of Egmont, by Johann Wolfgang von Goethe
# #5 in our series by Johann Wolfgang von Goethe
#
# Dieses Butens gewohnbebt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0724
# : and are
# tax deductible to the extent allowable by law.  (CMU = Carnegie-
# Mellon University).
#
# For these and other matters, please mail
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# [2P2PFOSTEST.  FrAs by legemer es, the Project etpers.
#
# and anders arm all our the with tist of this etext, or auf es
# will seates of 200,
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0721
# Project Gutenberg Etext of Egmont, by Johann Wolfgang von Goethe
# #5 in our series by Johann Wolfgang von Goethe
#
# Dieses Blote
# Traten Auf
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0726
# /NSEgmont from art other ist it o the lewall yrither thun
# und you      form the Project (and any other party you may receive this
# etext fr
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0721
# --
#
# "Rücken Sie nun auch dorthin, Herr Schwager, daß wir uns recht
# bequem in die Augen sehen."
#
# "Wenn ich Sie indese",  in der er kann
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0721
# ft ihr das?
#
# Jetter.  Erklärt's uns.
#
# Vansen.  Es ist so klar als die Sonne.  Müßt ihr nicht nach zu unter?
#
# Klärchen.  Du wirst Mu
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# Augen verborgen fließt sein Blut.
# Ängstlich im Schlafe liegt das betäubte Volk, und träumt von Reueses, und immer witdet einiges
# Betrag
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# Gespräche folgten; doch Wilhelms Aufmerksamkeit blieb auf die Gemälde
# gerichtet.  Der Wirt merkte die Gestalt des Mädchens des Königs b
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0718
# Interesse überschauen,
# als ihm dessen Bewohner immer mehr wissen.
#
# Vansen.  Wer will genug, und ich fürchterlichsten Schlafen, und wün
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# m Allgemeinen verharren, macht mich mit Eurer Geschichte bekannt,
# damit ich erfahre, wie es möglich geworde hatte, wenn sie miß
# ihn gezag
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0719
# : da ging's ehrlich und ordentlich zu.  Nun muß doch auch
# jeder thun, als ob er nötig wäre; und daher beautigt aus ihre Namen zu
# verbrei
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# 200 billion Etexts given away this year.
#
# The Goal of Project Gutenberg is to Give Away One Trillion Etext
# Files by December 31, 2001. [1
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# Jetter.  Schön!  Schön!  nicht beweisen.
#
# Soest.  Nicht merken lassen.
#
# Ein anderer.  Und nicht mehr zu sich in dasselber eine Schrift
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0718
# Karten drei Jahre vor uns
# verborgen gehalten hat und noch verborgen hält, sollen wir die
# unsrigen Beste und Einsicht von der Absicht verm
#
# Iteration nb : 380
#
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0720
# Man schied, und Fitz versprach, zu guter Zeit in den Hallen
# des Riesenschlosses wieder einzutreffen.  Die Pflichten und Freuden des Pflegev
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0720
# men, die Zeit noch hin, die keine Zeit mehr ist.
# Heut' steht die Welt auf einmal still; es stockt ihr anderes zu geben?" sagte Wilhelm, "da
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0722
# ~)
#
# Egmont.  Willkommen, Oranien.  Ihr scheint mir nicht ganz frei.
#
# Oranien.  Was sagt Ihr zu uns gewört!  Ach, Klärchen, von Gestalt
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0719
# kend erschaute.  Dem
# freundlichsten Gruße, der dringenden Einladung heraufzukommen
# widerstand Lucidor dazu, hören, wie sie seine Gegenwar
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0720
# *
#
#
# Platz man to hinther, 200, or froreice, this "Small Print!" statement.
#
# [3]  Pay a trademark license fee to the Project of 20% of th
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0718
# 1, or about 3,333 Etexts unless we
# manage to get some real funding; currently our funding is mostly
# from Michael Hart's salary at Carnegie
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0719
# Hause bedrohen.  Aber weil Sie jung sind,
# sage ich es Ihnen allein und im Vertrauen: Männer und Frauen zu beschweren
# seinen hören stehen
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0721
# )
#
# Andere.  Freiheit und Privilegien!  Privilegien und Freiheit!
#
# (Egmont tritt auf mit Begleitungen fühlten.
#
# Mutter.  Das ist nicht
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0715
# Leben gehört den
# Lebendigen an, und wer lebt, muß auf Wechsel gefaßt sein.
#
# Ich sprach nun mit mehr ein Großer Gebier wohl nicht leben.
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0717
# [2P2PbETTOr          or  o  nou any other and od be the 6ter this yur ins and within the Project Gutenberg Association at
# Carnegie-Mellon U
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0720
# + dich mit diesem Hammersten um den Schlerzheiten mit Gelegenheit und Reinbetragte
# seinen Weg, den ihn zum Freunde zu überzeugen wünscht
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0715
# Y O: any gedibation will drinnend work).  In you received this etext on a physical
# medium (such as a disk), you must return it with your re
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0717
#
#
#
#
#
#
#
#
#
#
# Drittes Kapitel
#
#
#
# Wilhelm an Natalien
#
# Soeben schließe ich eine angenehme, der in einsicht, mancher
# Wanderer zu t
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0715
# 6
#
# Egmont.  Der wäre?
#
# Oranien.  Zu sehen, was der Rumpf ohne Haupt anfinge.
#
# Egmont.  Wie?
#
# Oranien.  Man weil ihr denn auch die Na
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0719
# ?  Ja doch", fuhr er fort;
# "doch war der Scherzname gewöhnlicher.  Genug, das braune Mädchen
# trat herein, der du man nur für diese Nach
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0714
# )
#
# Andere.  Freiheit und Privilegien!  Privilegien und Freiheit!
#
# (Egmont tritt auf mit Begleitungen.  Er sind wie einen Weise bei der m
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0717
# 3-
#
# Egmont.  Nicht dem Falle zu Hüren dunch die
# Sorntan.  Sie erreult sich darauf in der Krieger!  Ja, ich kenne die Sache von
# der Neig
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0719
# Sie haben ihn als Mitschuldigen
# des Hochverrats enthauptet.
#
# Egmont.  Arme Seele!--Noch eins, und wird immer unter dem Geschinden sind, d
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0715
# #
#
#
#
#
#
#
# Sechstes Kapitel
#
# Nach einer langen und gründlichen Ruhe, deren die Wanderer wohl
# begenn.  Er saß nicht beiden sollen?  Er
#
# --------------------
# Epoch 1/1
# 90s - loss: 0.0713
# ft ihr das?
#
# Jetter.  Erklärt's uns.
#
# Vansen.  Es ist so klar als die Sonne.  Müßt ihr nicht nach zu lassen!  Wer tief in den
# Kreissc
#
# Iteration nb : 400
# Stopping...
# /home/duc-vinh/anaconda2/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-24 02:57:42.138547. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# **4. Generate text**

# %%
def save_text(model, length, vocab_size, ix_to_char):
    # starting with random character
    ix = [np.random.randint(vocab_size)]
    y_char = [ix_to_char[ix[-1]]]
    X = np.zeros((1, length, vocab_size))
    for i in range(length):
        # appending the last predicted character to sequence
        X[0, i, :][ix[-1]] = 1
        print(ix_to_char[ix[-1]], end="")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        y_char.append(ix_to_char[ix[-1]])
    if not os.path.exists(out_path+"generate/"):
        os.makedirs(out_path+"generate/")
    with open(out_path+"generate/output.txt","w") as f:
        f.write(('').join(y_char))
    return ('').join(y_char)

# %%
# %%time
out = save_text(model, 1500, VOCAB_SIZE, indices_char)
