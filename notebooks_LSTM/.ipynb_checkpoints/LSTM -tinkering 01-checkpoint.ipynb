# %% [markdown]
# # LSTM

# %% [markdown]
# - ## Preliminaries

# %% [markdown]
# - ### Imports

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
get_available_gpus()
# Out:
# []

# %% [markdown]
# - ### Test

# %%
# %%time
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=128,
              epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print()
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# corpus length: 600901
# total chars: 59
# nb sequences: 200287
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 200287/200287 [==============================] - 205s - loss: 1.9919
#
# ----- diversity: 0.2
# ----- Generating with seed: "rn, an unavoidable psychologist
# and soul"
# rn, an unavoidable psychologist
# and soul the such more and in the such the strught the such the such the strught the self the self of the such the soul in the such the self such the self more in the such the strught the strunger to the such the such the soul the self and the such the seet of the such of the subject of the such the strught the self and the such the seet the self and for the such the strught the soul in the such the self
#
# ----- diversity: 0.5
# ----- Generating with seed: "rn, an unavoidable psychologist
# and soul"
# rn, an unavoidable psychologist
# and soul and interrone self. the see of man in a find in many and the self stature of the infle, the atreat indelight its light and in the considerance in the still demot in the such in the truthour always in the enteround of the sle in the self--fut does the same and and thinks such thinks the more and would be see
# stronger of the selves and one one for ourless the senting to the considual in the farment
#
# ----- diversity: 1.0
# ----- Generating with seed: "rn, an unavoidable psychologist
# and soul"
# rn, an unavoidable psychologist
# and soul, how the retrinatific
# werk, it to were that frightts, is gone men grent
# agoodning of eurobound and rale.
#
# if the, aciduse in at will of become thimles sees, fruthrently applose instrugume him soist the knowledgre. with lotk precinning arough and at some"m antimarin
# stice respot to than athenticl, arbon and "roby only men? in was done grouret: will, bucame thinking, thus of
# coust: in whicls in the
#
# ----- diversity: 1.2
# ----- Generating with seed: "rn, an unavoidable psychologist
# and soul"
# rn, an unavoidable psychologist
# and soul one? a fundingle, the everyting suppaters. o jughtin,
# as
# philosolh) free
# potmles. upiquilia, and astrest netally sciogomonility
# be ilap ftrals, the stre gos, dmpay ca metaring, it is
# kone tomet knowed--notot same deli"d. them with men=prindcaul resurny to -nity etce, ten trde a neul repstigablisings ese, anown sabe an orders of ints intiselts. it anywy, that ints woven the-reked and wnot of beloz
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 200287/200287 [==============================] - 200s - loss: 1.6321
#
# ----- diversity: 0.2
# ----- Generating with seed: "istasteful"
# to him.
#
# 268. what, after al"
# istasteful"
# to him.
#
# 268. what, after also the contemple of the so the so that is consequence of the world and say a self--and who far all the consequence of the power of the sentiment of the soul and a person to the something is the the gention of his and the instituted and the strengen of the sense of the same the some formed to the and the soul in the sensible of the sensible of the resent of the individual to the conception is the t
#
# ----- diversity: 0.5
# ----- Generating with seed: "istasteful"
# to him.
#
# 268. what, after al"
# istasteful"
# to him.
#
# 268. what, after also so let of every religions, that is the his do as the impless and the religion it is be such there is that is every in the incertal delight of the world, is the them and has the sall and for the "philosophy of the something as a little religion of the realing last that the truth its and and the in the experience of the individual bett it is man is the ear of the sight a profect in the conception
#
# ----- diversity: 1.0
# ----- Generating with seed: "istasteful"
# to him.
#
# 268. what, after al"
# istasteful"
# to him.
#
# 268. what, after all being there is the chasiful experived: that the intelvectume the
# bak hongs
# lotter it is betrueged bad from this saips exaril at
# exorer nacking out of go have being
# hlower it is to gent account, against
# ennough seeming hus
# eyty is consciect being world of it, betrained, disgive at is a
# genderptive els of absolutism: and powed truth; and to bother
# society for which hones
# as it heant, doe
#  nature i
#
# ----- diversity: 1.2
# ----- Generating with seed: "istasteful"
# to him.
#
# 268. what, after al"
# istasteful"
# to him.
#
# 268. what, after all stom problow
# is in who such againal relike that hithentow--ore defent
# and kepard, mated the feitto crulty. that century, inwoment.
# ]bererous, hil. (one the revenguate jost
# indeed, it.
# there symething, he must?", mrantpoty.
# that mer origingial at thems
# limedne-de virebly so southous fornous furltuates fail, and about there is nocherk
# not "nae as enem their musty owed is-mercred virtues chatec-. s
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 200287/200287 [==============================] - 200s - loss: 1.5467
#
# ----- diversity: 0.2
# ----- Generating with seed: "on of values, under the new
# pressure and"
# on of values, under the new
# pressure and and the stronger of the stronger to the spirit and and the asceticus and a comparing and the stronger to the power of the same such a period of the such a stronger of his all the power of the power of the most disperience of the extrains to the stronger to a stronger of the stronger to the self many and the stronger to the realing and the asticud of the sain and and the and the strong the such a
#
# ----- diversity: 0.5
# ----- Generating with seed: "on of values, under the new
# pressure and"
# on of values, under the new
# pressure and intereared, that is the astinue and the contemptions, and religion that it has been superfuce of the signing a prologions in the an impre--and and of the contemptions for the conserves in the for in the subjective all the wonld one the word of the extrain to a love, a spirit, in the astirud to so learn in the artisting and the compley of the master, and in all a strange to say does be as the
# trut
#
# ----- diversity: 1.0
# ----- Generating with seed: "on of values, under the new
# pressure and"
# on of values, under the new
# pressure and
# enermiescy, and fulld moral
# reverse, of mutiod century, a seluted, and in it irclotoclations by hood and advalue of simes in our long imative, renuevarily in its poing
# in
# cossesting a differinging ousymptions--and and those how scioct, alto and effect becumst spirits and the trouth type nover above one case and longer is the
# artance of his too epposific play
# that every re essimagane, and does sel
#
# ----- diversity: 1.2
# ----- Generating with seed: "on of values, under the new
# pressure and"
# on of values, under the new
# pressure and prodicions after our to appearand--formsol-incering noeoque enough alovaus, only the thim forcevi? scoperous vititimizes tin vivul
# precide pascersmunde, ther i sayt pupists," to morals puts tombyinteiours--to
# this disposition spirit morol, "which stell; ungerful, which, emirmonish as somethings ething itself
# sore self ind
# all the consequenceh: andsorna.
#
#
# gele to this
# dow proplacedomibs edivienc-
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 200287/200287 [==============================] - 201s - loss: 1.5001
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# but, instead of it, the old, trite "met"
#
# but, instead of it, the old, trite "metaphysical profound the consequences and and in the properting the profound to the acts the profound to the lives the propersing to the consciousness and properting and the properting the propersing and the strangless in the properting the propersing the profound and the propersing the properting the processed the sense of the profound the such as the propersing the properting the consequences of t
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# but, instead of it, the old, trite "met"
#
# but, instead of it, the old, trite "metaphysical instinct the instinct, and individual sitgance in the
# present that the such a sort the generally the prosise this woman in the
# all the the called yet the precain into the
# consciously them the consequences in the reality, the religious abitions and the less the presuacure in the religional the the marter of the fearly, and to prival of the something probably to the consciously and in the
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# but, instead of it, the old, trite "met"
# but, instead of it, the old, trite "mettaink at end splanours conceally concepture
# successen.
#
# usad oulde id, this
# very and arisus
# of right,
# the dyead his uses and feel midsoly laught-incoppagesity been the
# man", and it complemandst mechates
# eurepemsess," became" if man? the
# inspired, but
# we have means. reci"ent, the
# lay is in this spirits of something
# this will--it others os,
# are now the science sense"--                      which
# ins
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# but, instead of it, the old, trite "met"
#
# but, instead of it, the old, trite "metaphesting
# often were
# apprday language: the deea--all the
# commmunitanter,
# everything by thesaloy. into as
# these), all, panoursive, quesseiouslyrdun judge lives, still,
# hard by which german attempts. this his amoowroas, is generally
# free lift becaving lonequeding, appicied; xoubd grotpultads, in out af
# or that suffiditssge.
#
#
#    pfromists.
# europetad-baw strengto
# disgatily belf facted
# man yet
# with mo
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 200287/200287 [==============================] - 201s - loss: 1.4713
#
# ----- diversity: 0.2
# ----- Generating with seed: "ting" to
# the average man--if, notwithsta"
# ting" to
# the average man--if, notwithstanding still life and and even the individual the and instinct of the spirit: the entire and stronger and the spirit: the subjects and so the more and and subtle to the morality and the morality of the means of the sensible the stronger and and something the subjection and standing the stands the problem of the philosophers of the stands and the more and in the sensible the more and and who was not
#
# ----- diversity: 0.5
# ----- Generating with seed: "ting" to
# the average man--if, notwithsta"
# ting" to
# the average man--if, notwithstaking and problem and his way and and the spirit: as does not instinct of the and interpretance in the state in the sides for instance, for the object with for all the considerable the means of the mask" and century and and higher the the loves to the said one's innerptic or the ancient and its of the menganies of the man of the concended of the considerately hand develop and consequences and as a
#
# ----- diversity: 1.0
# ----- Generating with seed: "ting" to
# the average man--if, notwithsta"
# ting" to
# the average man--if, notwithstantiust ale will and schopated insturne of this lagks in this repuding a fooked consequenal way moralise ausidladado-disarned the mirwifled considerable
# the guigt they, all philosophies would in the
# ylad the in loves
# permensmence is true, encide and of naired, all tthine--and say
# have baded diftinumies anaiviricism-toronly rubmen an obcedifilicate value. eurousnwes of it atages and eismes himself o
#
# ----- diversity: 1.2
# ----- Generating with seed: "ting" to
# the average man--if, notwithsta"
# ting" to
# the average man--if, notwithstanding these
# mastered for understand--not disorvenc uncourature and ifricision attagnwing and labour---which prespart, vority, as  lune and miscliften widibliyntadiously fad theing rishustment in his
# eternal, fromler of like it; the unreligiously an addleigun probably men as against ideassing that of ir2quated to courd disphirts a the tacker mivias that
# been eviring of once, will have all medlous f
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 200287/200287 [==============================] - 199s - loss: 1.4481
#
# ----- diversity: 0.2
# ----- Generating with seed: "nservative
# in its dealings with hypothes"
# nservative
# in its dealings with hypothesis and the more strainasing the strange of the superiors of the such and and the sense, and the strange of the signs and and strength and the strange of the present and the sense, the more self the superiority and the more present secret and the soul the strange of the present sense of the soul and the strainasing of the morality of the strange of the soul and the more and the state and the subsor
#
# ----- diversity: 0.5
# ----- Generating with seed: "nservative
# in its dealings with hypothes"
# nservative
# in its dealings with hypothesis every day and sich or his nowadays is effecting and what is not not the art of which so in christian personal reality and presultion and powerful spirit of a true the masters to the the confine the spring, the simply and enough and such as he is power a still in our to him and present self artisted the strength in these decessed characted and slive the cause of the mastersmous and the some in t
#
# ----- diversity: 1.0
# ----- Generating with seed: "nservative
# in its dealings with hypothes"
# nservative
# in its dealings with hypothes
# author atismerar: doe mostard using and maintrides.--is not his not
# their
# truth"," what with metaphespetes insiders for powerly of who are astinuching--it is aft divarily, that it istelnest to the
# unseurningment of slives reason forsepenh-forms, there aid
# to schearty liusis succid of acterable to attect, betray
# with crarscism.
#
# 25on the epided some dangures.--
#
# ----- diversity: 1.2
# ----- Generating with seed: "nservative
# in its dealings with hypothes"
# nservative
# in its dealings with hypothese, doilly
# pescterding rebreed of redugated. to essing of spirituc termicdless of all if insolitionis gochless--aitsowing
# there skepined probless of the
# hiry lay any womanc:
# is not when also "wagfew-pandence, -thereby compass to what their yer rid, at the werso maxifuct,
# and, besirturihe.
# upaga'sicy enciourance
# the orposs. the vaily, other histhicrs, (and bounds andwroly
# and place, coloricate mufe
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 200287/200287 [==============================] - 200s - loss: 1.4325
#
# ----- diversity: 0.2
# ----- Generating with seed: "ry rich in refuges from the mandate of s"
# ry rich in refuges from the mandate of such a sense of the sense of the and and the assumptions and the present and the present and the strongest and and considerative could the prejudice of the profound and and profound and the more and and and the profound and conscience to a strongest in the strongest in the sense of the delights to the profound and and and profection of the strongest and and and still and such as a strongest and and
#
# ----- diversity: 0.5
# ----- Generating with seed: "ry rich in refuges from the mandate of s"
# ry rich in refuges from the mandate of some personal the morality and in all things and assumptions of power to do the preference of the self-man praised the apprecisely and his even the experience of the presenting to themselves and and end all the profound of the action that an and experience and storm and have a sort and will and the saint for a perpetived to the language to dangerous
# and own entieng of the experience of the individu
#
# ----- diversity: 1.0
# ----- Generating with seed: "ry rich in refuges from the mandate of s"
# ry rich in refuges from the mandate of such a necessity or psychology; one practicy asenery, cay-can corraticaty and humpty,
# to actioncess to such a pilful a
# sans human only the last conclusion in
# moralist conception with the unlest explierating, not finss these more with menalings, present nowadays!
#
# 12thenss, in euhtened howess composceor, among bray and subtle
# tell believer
# opinses and thesest hrans, or believing of the calnows has a
#
# ----- diversity: 1.2
# ----- Generating with seed: "ry rich in refuges from the mandate of s"
# ry rich in refuges from the mandate of suugling iiges to danfle longing, every sself, to knowlings and knowingh"e, itself--it were eyes appearians; the
# diddrescouratiness, understand that it
# not the prunsesm in plants as from the dedicctions of makes, is too laventom of too
# knopsh withses sain oncivion, whether wee. inasmuch whanmver atear
# tarking-ease this clumse-eke fforcicial sc.t
# and
# as we asgensiontry: and
# old liarc.
#
#
# 111ralt deli
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 200287/200287 [==============================] - 199s - loss: 1.4163
#
# ----- diversity: 0.2
# ----- Generating with seed: "tifled, suffocated, and spoilt in the pr"
# tifled, suffocated, and spoilt in the precisely and sentiment of the most superior of the stated and stand of the stated and stated and and and stand of the most delication of the consequences and in the most and and and which has a man and and the mind the stated and states and interest and consequences and does not and stated and and intellect of the superior of the morality is and stated and with the complete and sense and and in the
#
# ----- diversity: 0.5
# ----- Generating with seed: "tifled, suffocated, and spoilt in the pr"
# tifled, suffocated, and spoilt in the propertion of soul, we as a comprehensives of the one is as it is an and the readic with experience, and had and one who may have precisely the delights of hand the stronger in the lackan and could the arreading oneself community for the compresent and men is midality in the very as the knowledge and assuman, seems to all the modernanty explated him who was all the dreamed the condition of the moder
#
# ----- diversity: 1.0
# ----- Generating with seed: "tifled, suffocated, and spoilt in the pr"
# tifled, suffocated, and spoilt in the prequired sometimed, calls, amovers, and at all, afvinituite.
#  and so this for its sopassacy its own bury present is comprofain into all oversoured thut incredanced by inversersment, of music was srave for
# expressed of mochours. "by
# mirving be present something hand
# noble weat amout of good" awa? therenoing, and the grow
# intellect of right of will a moderness spirit, in which it is the ssell, mousur
#
# ----- diversity: 1.2
# ----- Generating with seed: "tifled, suffocated, and spoilt in the pr"
# tifled, suffocated, and spoilt in the problem of "adne spirit spece and unfested thun
# econtand
# to coursed
# that be
# wil revitation
# bad and voluntr as only padopowittsly is, whether sifes its emattli"ews.
# the
# gain terbexceptacle, and we kindnal by themselves than things" just sign a laymen exhaishmanration. in thinkers.
# ancled to at holnent
# up, we how he arccertions.
#
# whil!
# !      the hadicg howing. us.
# thoughs thoued  a stand
# whom perhaps
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 200287/200287 [==============================] - 200s - loss: 1.4039
#
# ----- diversity: 0.2
# ----- Generating with seed: "e as little
# responsible on this account "
# e as little
# responsible on this account the sense and and still be promated and stand of such a prompted of the sense and ascetiors of the stronger and stand of still man and as a philosophy and and still more the promption of the more the problem of the sense of the strong the problem of the supersusure and say and all the stronger of the more and all the man of the supersure of the same strong the sense of the sense and and sense and
#
# ----- diversity: 0.5
# ----- Generating with seed: "e as little
# responsible on this account "
# e as little
# responsible on this account to every individuxlocated and also the power of the whole of which they thought to him to induloging of the sense the same sense of sense the sense for the men and happecham or an a profound the basis, still man be nothing a thought to him soul, as the trust for the fast and and and must be sould in the same higher in everything and with a proportan or in the case of its will not to the nowaring o
#
# ----- diversity: 1.0
# ----- Generating with seed: "e as little
# responsible on this account "
# e as little
# responsible on this account you hos whether knowledge we seems will becain, not being of frenchor, which blasm conscience has cerited"
# thought says a mustrible be mad and itself as a neot this, moralins of the diy iny quickly its individual nature. one seeccallibilied age, in deepe. when the word upon has been to
# nature, this own achisty sense andacred itself. he equal, developed there as tho mask'os very question of
# utienc
#
# ----- diversity: 1.2
# ----- Generating with seed: "e as little
# responsible on this account "
# e as little
# responsible on this account as molight.
#
# ren upquiral? knows in exagled catoriom to a desire earsten themselves case only peepptine fortel becomile theo, revense can me; at cat
# yer: bution of kindness than as enolic feel superiorness, in darxyalrs, ovewial is it, bustering and itsignd all which limited in berecedopoively sun mand overcasusume all the forem--cheenow
# aroueno--suf, swis
# nos
# thought prevasion apart, or does not
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 200287/200287 [==============================] - 199s - loss: 1.3945
#
# ----- diversity: 0.2
# ----- Generating with seed: "and fellow feeling acquire
# depth, lamben"
# and fellow feeling acquire
# depth, lamben and the subject to the problem of the most still been still to the promption of the stronger to the world in the most declive be superior to the subjection of the more and imposits of the prompt of the substance of the more and still to the prompt of the promption of the morality of the world and the artificed to the present the present to the declive to the more and art of the promption of the m
#
# ----- diversity: 0.5
# ----- Generating with seed: "and fellow feeling acquire
# depth, lamben"
# and fellow feeling acquire
# depth, lambent for which the fived to the more a man of the crude which at influence of the master, it is a danger of many and say this fact which as the goal with the properly the tree and with one is the more him we caurse of the does not an impley. the subst they was the complacies to the good promption of the mask of the special and france of the fact of the means of the sense whereof
# even the promotal dis
#
# ----- diversity: 1.0
# ----- Generating with seed: "and fellow feeling acquire
# depth, lamben"
# and fellow feeling acquire
# depth, lambence, if wess a world
# that the mide because the feoun and even morale got-misinistoly, for which whose to our prejudicesly and declink of powering with it to care"de as iorbirely highest fry himself--still
# doudne.
#
# in the european questions more spirituality evel
# action to the greatest our more and impatite to the day dans religios!"
# childs upbid pwyinare
# what the "mocuously nairly seullserance of a
#
# ----- diversity: 1.2
# ----- Generating with seed: "and fellow feeling acquire
# depth, lamben"
# and fellow feeling acquire
# depth, lamben upays eleblg to
# me.g. oclictly
# and cebryes myself feeling"."
#
#
# 1
# richable graems, of futuenes life uncondetidity--as the attemots ofligin explgition," in that willly
# bedanger of postessions, as weals, the adaved painfortion fe and recernancer. they wel
# s, sardify others the dreadand. whyter orke] accorditioral an ad rejogicy of human disignibilify
# of the deperere
# madiness, bind aronisk
# suffers t
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 200287/200287 [==============================] - 195s - loss: 1.3853
#
# ----- diversity: 0.2
# ----- Generating with seed: "our love for truth,
# you have forced your"
# our love for truth,
# you have forced your the same when the strength of the superstitious and the present the present to which the most superstitious and the superstity to him to the contemptuation of the possible the superstitious of the contempt, the superstitious and the strength of the subjection of the most spirits of the superstitious and the strange to the most subtlest of the possible the superstitious and and the present to the
#
# ----- diversity: 0.5
# ----- Generating with seed: "our love for truth,
# you have forced your"
# our love for truth,
# you have forced your streace lives to
# also cour prysent now he
# have always the denedence that it concealed to lacking of its most consciousness which the world by the most belief that the responsibility in the most delight to may also the strange to myself-nation, in the subliment, the fartes of naces of conscience of his upon the sudder to so free suffer the spirit in the "belief of fact, the importure of the possib
#
# ----- diversity: 1.0
# ----- Generating with seed: "our love for truth,
# you have forced your"
# our love for truth,
# you have forced your instant (is religious-s""". the
# say of the one wordo, unfour dominion of man maswrosius of our lort; became and world di creature to hender people not exornof (of guise," will displey, the most epother tae
# hond to proverble and ganmerstable him, and the congretural
# pronoes him is appearly: the "teer, also it is always allow" consequently possibility, wo knows final taste, to couralser of this
# spo
#
# ----- diversity: 1.2
# ----- Generating with seed: "our love for truth,
# you have forced your"
# our love for truth,
# you have forced your hemor of-taation, of eperplesseves beaully way as he fir
# things orgainty! (sable, the co""s to prevailing
# wit
# boli onepant more causlion in the hearcery
# eirste.
#
# 2ar in trough nam
# in race, in soulty for
# itself"--every sospitions;
# german applecess by macewerant anotning
# for, and heaving, no thought--os life be rafinm-onergesy; and bi to weal-whave henerary bforgep? man was been develope
# ys reniest
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 200287/200287 [==============================] - 205s - loss: 1.3769
#
# ----- diversity: 0.2
# ----- Generating with seed: "a man who can conduct a case,
# carry out "
# a man who can conduct a case,
# carry out of the most all the possible of the servation of the most discovered to the self-does to the soul the masters of the most soul the problem of the most soul the possible of the self-disting and so the more and all the senses of the sense and self-delicate them the more the senses the action of the sense and consequence and the more woman and in the masters of the senses and and so the soul the same
#
# ----- diversity: 0.5
# ----- Generating with seed: "a man who can conduct a case,
# carry out "
# a man who can conduct a case,
# carry out the under the savage in the out the retermined and concerning the lable and good grateful and so the first by the first regarded or and truth in the self-man already and in the morality in the fact, and he has still appearant action of the masters and discoverates the puritan the more beyonds as the mind the regarding and in the masters and nothing that the plate and the fore of the discord of the
#
# ----- diversity: 1.0
# ----- Generating with seed: "a man who can conduct a case,
# carry out "
# a man who can conduct a case,
# carry out of oursernen--all attained in truth,
# h
# is conclude of pariticatoves and impulsty avoush us the rulous
# hitherto
# folso them regarbtrficne, just the belief these under the most moratibusly drike herebre! yoe precisely rschise in on the morable
# of beautyly bveng "sche
# of illities," which who was disposityed in the destronating at the destructive. i religionales. it is all thinks are regarded to them.
#
# ----- diversity: 1.2
# ----- Generating with seed: "a man who can conduct a case,
# carry out "
# a man who can conduct a case,
# carry out in the
# condrentationness--them
# as peopleman as it
# it to henty, and hear with them at the
# pass of scious of characts, man can beasing syphapen masterid,ly
# pathe we , is conferved
# forthing
# only all the remouatis them not as haperskk of hertally inyedation so with what o shautych, aid rewfut the evouralily above the amats when neswem which forferding the sacrifice -are coften which
# man ourselves, per
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 165632/200287 [=======================>......] - ETA: 35s - loss: 1.3644
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-927577eabfd4> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'\'\'\'Example script to generate text from Nietzsche\'s writings.\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n\'\'\'\n\nfrom __future__ import print_function\nfrom keras.models import Sequential\nfrom keras.layers import Dense, Activation\nfrom keras.layers import LSTM\nfrom keras.optimizers import RMSprop\nfrom keras.utils.data_utils import get_file\nimport numpy as np\nimport random\nimport sys\n\npath = get_file(\'nietzsche.txt\', origin=\'https://s3.amazonaws.com/text-datasets/nietzsche.txt\')\ntext = open(path).read().lower()\nprint(\'corpus length:\', len(text))\n\nchars = sorted(list(set(text)))\nprint(\'total chars:\', len(chars))\nchar_indices = dict((c, i) for i, c in enumerate(chars))\nindices_char = dict((i, c) for i, c in enumerate(chars))\n\n# cut the text in semi-redundant sequences of maxlen characters\nmaxlen = 40\nstep = 3\nsentences = []\nnext_chars = []\nfor i in range(0, len(text) - maxlen, step):\n    sentences.append(text[i: i + maxlen])\n    next_chars.append(text[i + maxlen])\nprint(\'nb sequences:\', len(sentences))\n\nprint(\'Vectorization...\')\nX = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)\ny = np.zeros((len(sentences), len(chars)), dtype=np.bool)\nfor i, sentence in enumerate(sentences):\n    for t, char in enumerate(sentence):\n        X[i, t, char_indices[char]] = 1\n    y[i, char_indices[next_chars[i]]] = 1\n\n\n# build the model: a single LSTM\nprint(\'Build model...\')\nmodel = Sequential()\nmodel.add(LSTM(128, input_shape=(maxlen, len(chars))))\nmodel.add(Dense(len(chars)))\nmodel.add(Activation(\'softmax\'))\n\noptimizer = RMSprop(lr=0.01)\nmodel.compile(loss=\'categorical_crossentropy\', optimizer=optimizer)\n\n\ndef sample(preds, temperature=1.0):\n    # helper function to sample an index from a probability array\n    preds = np.asarray(preds).astype(\'float64\')\n    preds = np.log(preds) / temperature\n    exp_preds = np.exp(preds)\n    preds = exp_preds / np.sum(exp_preds)\n    probas = np.random.multinomial(1, preds, 1)\n    return np.argmax(probas)\n\n# train the model, output generated text after each iteration\nfor iteration in range(1, 60):\n    print()\n    print(\'-\' * 50)\n    print(\'Iteration\', iteration)\n    model.fit(X, y,\n              batch_size=128,\n              epochs=1)\n\n    start_index = random.randint(0, len(text) - maxlen - 1)\n\n    for diversity in [0.2, 0.5, 1.0, 1.2]:\n        print()\n        print(\'----- diversity:\', diversity)\n\n        generated = \'\'\n        sentence = text[start_index: start_index + maxlen]\n        generated += sentence\n        print(\'----- Generating with seed: "\' + sentence + \'"\')\n        sys.stdout.write(generated)\n\n        for i in range(400):\n            x = np.zeros((1, maxlen, len(chars)))\n            for t, char in enumerate(sentence):\n                x[0, t, char_indices[char]] = 1.\n\n            preds = model.predict(x, verbose=0)[0]\n            next_index = sample(preds, diversity)\n            next_char = indices_char[next_index]\n\n            generated += next_char\n            sentence = sentence[1:] + next_char\n\n            sys.stdout.write(next_char)\n            sys.stdout.flush()\n        print()')
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2113             magic_arg_s = self.var_expand(line, stack_depth)
#    2114             with self.builtin_trap:
# -> 2115                 result = fn(magic_arg_s, cell)
#    2116             return result
#    2117
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1183         else:
#    1184             st = clock2()
# -> 1185             exec(code, glob, local_ns)
#    1186             end = clock2()
#    1187             out = None
#
# <timed exec> in <module>()
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     851                               class_weight=class_weight,
#     852                               sample_weight=sample_weight,
# --> 853                               initial_epoch=initial_epoch)
#     854
#     855     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1484                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1485                               callback_metrics=callback_metrics,
# -> 1486                               initial_epoch=initial_epoch)
#    1487
#    1488     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1139                 batch_logs['size'] = len(batch_ids)
#    1140                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1141                 outs = f(ins_batch)
#    1142                 if not isinstance(outs, list):
#    1143                     outs = [outs]
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
