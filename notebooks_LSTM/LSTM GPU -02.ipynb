# %% [markdown]
# # LSTM

# %% [markdown]
# - ## Preliminaries

# %% [markdown]
# - ### Imports

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout,TimeDistributed
from keras.layers import LSTM,SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# %% [markdown]
# - ### Check CPU usage

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
get_available_gpus()
# Out:
# [u'/gpu:0']

# %% [markdown]
# ----------

# %% [markdown]
# # I. Toy examples

# %% [markdown]
# - ### Test

# %% [markdown]
# ** 1. Load and convert data**

# %% [markdown]
# '''Example script to generate text from Nietzsche's writings.
# At least 20 epochs are required before the generated text
# starts sounding coherent.
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.
# '''

# %%
#load file
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
VOCAB_SIZE = len(chars)
print('total chars:',VOCAB_SIZE)
# Out:
# corpus length: 600901
# total chars: 59

# %% [markdown]
# **Warning:** The RNN takes in input numerical data hence the necessity to convert strings into numerical values.

# %%
#creating mapping between indexes and characters
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %% [markdown]
# We’re gonna use Keras to create and train our Network, so we must convert the data into this form: (number_of_sequences, length_of_sequence, number_of_features).
# - nb of features = length of the char array
# - length of sequence = batch size
# - nb of sequence = len(data) divided by batch size.
#
# **Warning : ** target sequence is setted by shifting the source/input sequence by one character with both having the same length.

# %%
# %%time

SEQ_LENGTH=100
#Build three dimensional arrays
X = np.zeros((len(text)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE)) #input
y = np.zeros((len(text)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE)) #target

#Build sequences
for i in range(0, len(text)/SEQ_LENGTH):
    X_sequence = text[i*SEQ_LENGTH:(i+1)*SEQ_LENGTH]
    X_sequence_ix = [char_indices[value] for value in X_sequence]
    input_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
    for j in range(SEQ_LENGTH):
        input_sequence[j][X_sequence_ix[j]] = 1.
    X[i] = input_sequence

    y_sequence = text[i*SEQ_LENGTH+1:(i+1)*SEQ_LENGTH+1]
    y_sequence_ix = [char_indices[value] for value in y_sequence]
    target_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
    for j in range(SEQ_LENGTH):
        target_sequence[j][y_sequence_ix[j]] = 1.
    y[i] = target_sequence
# Out:
# CPU times: user 500 ms, sys: 16 ms, total: 516 ms
# Wall time: 514 ms

# %% [markdown]
# ** 2. Build the network**

# %%
HIDDEN_DIM= 500 #500
LAYER_NUM = 2


model = Sequential()
model.add(LSTM(HIDDEN_DIM, input_shape=(None, VOCAB_SIZE), return_sequences=True))
for i in range(LAYER_NUM - 1):
    model.add(LSTM(HIDDEN_DIM, return_sequences=True))
model.add(TimeDistributed(Dense(VOCAB_SIZE)))
model.add(Activation('softmax'))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %%
def generate_text(model, length, vocab_size, ix_to_char):
    # starting with random character
    ix = [np.random.randint(vocab_size)]
    y_char = [ix_to_char[ix[-1]]]
    X = np.zeros((1, length, vocab_size))
    for i in range(length):
        # appending the last predicted character to sequence
        X[0, i, :][ix[-1]] = 1
        print(ix_to_char[ix[-1]], end="")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        y_char.append(ix_to_char[ix[-1]])
    return ('').join(y_char)

# %%
# Generate some sample before training to know how bad it is!
generate_text(model, 100, VOCAB_SIZE, indices_char)
# Out:
# 2 ))99[[[1111121111121111211112111121111211112111121111211112111121111211112111121111211112111121111
# '2 ))99[[[11111211111211112111121111211112111121111211112111121111211112111121111211112111121111211112'

# %% [markdown]
# **3. Train network**

# %%
nb_iteration = 0
#batch size equals to seq length here
BATCH_SIZE=100
#len of desired output
GENERATE_LENGTH=100


while True:
    print('\n')
    print('-'*20)
    model.fit(X, y, batch_size=BATCH_SIZE, verbose=2, nb_epoch=1)
    nb_iteration += 1
    generate_text(model, GENERATE_LENGTH,VOCAB_SIZE, indices_char)
    if nb_iteration % 10 == 0:
        print("Iteration nb : %s" %nb_iteration)
        model.save_weights('weight_02/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_iteration))
# Out:
# --------------------
# Epoch 1/1
# 108s - loss: 2.8876
# 6 an an an an an an an an an an an an an an an an an an an an an an an an an an an an an an an an an
#
# --------------------
# Epoch 1/1
# 108s - loss: 2.5314
# 5 the the the the the the the the the the the the the the the the the the the the the the the the th
#
# --------------------
# Epoch 1/1
# 109s - loss: 2.3183
# 9 the han and and and and and and and and and and and and and and and and and and and and and and an
#
# --------------------
# Epoch 1/1
# 109s - loss: 2.1484
# t he mand the sement the sement the ment the sement the sement the ment the sement the sement the se
#
# --------------------
# Epoch 1/1
# 109s - loss: 2.0074
# � the here in the here and and the here in the here and and the here in the here and and the here in
#
# --------------------
# Epoch 1/1
# 109s - loss: 1.8874
# 4 the will the will the will the will the will the will the will the will the will the will the will
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.7839
# s to some of the some of the some of the some of the some of the some of the some of the some of the
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.6953
# jestion of the standing of the standing of the standing of the standing of the standing of the stand
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.6191
# 4] the sense of the sense of the sense of the sense of the sense of the sense of the sense of the se
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.5545
# 4. the case of the community of the subjection of the subjection of the subjection of the subjectionIteration nb : 10
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.4987
# ? a philosophers as a philosophere as a philosophere as a philosophere as a philosophere as a philos
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.4500
# gerated and seemed to have a hasteriases and seemed to have a hasteriases and seemed to have a haste
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.4076
# 1=--the present of the present of the present of the present of the present of the present of the pr
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.3690
# �s a person of the philosopher and the philosopher and the philosopher and the philosopher and the p
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.3321
# 2=--the greatest pain and all the same the state of the speak of the speak of the speak of the speak
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.2981
# the standard of a common than the saint is the same time the same time the same time the same time t
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.2642
# ? therefore it is ever best therefore it is the freedom of the feelings of the feelings of the feeli
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.2304
# " which is not to be something to the same with the christianity which is the case of the strange of
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.1976
# very distression, which we are action in the same strong some of the soul, the same the same time th
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.1650
#
# the stronger case in the working out of the subjection in the soul of the subjection in the workingIteration nb : 20
#
#
# --------------------
# Epoch 1/1
# 109s - loss: 1.1302
# the same the period the prepared, the distrust of the earth, they are they be as a perilive and sort
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.0962
# 5] and the provise of the proved and even when the sense of the proved as a privilege of the proves
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.0612
# 3] and strongly in the morality of the morality of the morality of the morality of the morality of t
#
# --------------------
# Epoch 1/1
# 108s - loss: 1.0264
# 2. the last of the sentiment of the souls of the soul as the conception of the most perfect spects o
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.9905
# kentions of the free spirits of the artistical former and the same as an artisted and subjection to
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.9554
# : the greatest delights of the greatest and also the mastery of the most intellectual sense and the
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.9179
# ] and others through the perfective former and can be no longer for
# the present that the perfect of
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.8828
# [188.. "it is the saint should be always for the right to his own condition, the sense and
# the condi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.8477
# resent, an enduring repose in which the same predisposion to relate a long story and strength of the
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.8126
# [122] a man who was the senses its intellectually is a thing in its intention. in all things shown tIteration nb : 30
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.7776
# ch is not so much of the commander of many of the consciences of schopenhauer and refined from the c
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.7441
# �standing the characteristic of a period of the earth and therefore it is the fundamental impulses o
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.7096
# f everything long willing for the german could again to his mind the philosopher on the other hand,
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.6763
# 7] and the decipionay of all this arts and
# the senses of herpinary according to such a recommender--
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.6442
# y the majority of the metaphysics, the mentorment of humanity which he can be came the
# rulers repoct
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.6126
# " and interminting its delicate man who had always been a long to the saint: "untilling itself, as i
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.5838
# man in the starsa does not to be forghtful and
# hence it may not be deceived as to the hearted and fr
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.5534
# f the spirit has reason of the most varied there in the sense of the counter-cour of the will to pow
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.5260
# and that the slave desires the
# slave of the development of his own
# consciences, have prompted to the
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.4980
# --the most personal charms.
#
# 171. the mind in its active in a resurt of the most personal consideratIteration nb : 40
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.4719
# ing from in. in accurity, and externalized, and intermitation of the world speaking and
# propers, and
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.4469
# " and divine commusity, in every considerable emphaties (develops the result of a cried in constrain
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.4251
# conditioned
# under the heart of a sensitive man pronounced to an absort, that is to act oneself surpe
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.4018
#
# the brain, the problem of moral transitory that has been so extremilinary, and distrust
# as the whol
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.3805
# re estimates and instincts is in the later of the old so
# malleng that matters of false of consciousn
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.3611
# 7. in all seriousness, the shouter often profoundest and unconditioned, and
# indescribably painfus in
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.3432
# ?" many seem this
# significance of the supercien of the subjection of the spirit is indescribable peo
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.3238
# judged since the
# whole of antiquity swarmed without deal with it, wishome, inasmuch, as a people of
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.3087
# conducted in a dangerous, captious, and perhaps becoming the artion of
# the france, though leart and
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2932
# one antw--often before occasions, perhaps
# they will pleasure in the present day, the
# malification ofIteration nb : 50
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2808
# he rich man take histortant, his talen one who have existed a later
# and longing inconstituted
# into a
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2662
# --that is to say, an antithesis
# "good" and "evil" is offer for a man who was a thoroughly cause and
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2541
# ?" my oblise when is taking do not a matter, the
# problem of "modern ideas," and it most before with
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2436
# . the religious dellarion resurt
# by the work of our organs! it seems that the great mysterious of
# st
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2332
# d and even prevail, the slave of greaters or concerning the last taste of values!
#
#
# 2
#
#
# =the objecti
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2210
# (deceptively vere various europe, even the
# great philosophy of the port of the superstituation of a
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2135
# xamed of "phelogo's happiness," every highly developed, there all are at least for it, with the very
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.2069
# cessive prevalence
# of which at the bitterly lie to the two pleases firmly and the whole of the state
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1972
# an lives! one can never cease word--what?
#
# 220. there is an innocence in love of its kane were exper
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1905
# of the standard by which which each sensetimaline in the old modern, which we have activide of bad mIteration nb : 60
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1852
# e the things generally which
# fundamentally and profoundly conceivably the dominion of scientific req
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1795
# the whole of the past, and perhaps only thereby make
# its assont one may be understood." or, "i mean
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1738
#
# the ruleling and advance the end the effection of one the subject on the sparl
# as a higher man anot
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1684
# 7. in short, how my point a later
# and small of this eagh caste theology is a philosopher, and that t
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1653
#
# the "man of the martyrdinge, and so clumsy is that, and
# desertie porition, he expression the experi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1589
# just as well, and to the
# so far as a curordies of itholictication, or else suffering, is stronger th
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1588
# nd in its tempt, and
# of severity, or of course, as industrious of the restlession of the
# exothar as
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1517
# n the basis of the propount science consists itself even as long as constraint,
# likewical in the tru
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1489
# judged since the
# whole one may delibely regard against exeruising the same mind, the former deepest-
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1463
#  and lacks this
# pure integrity of the intellectual faculty, bad in the
# connect: the practice of anytIteration nb : 70
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1436
# s of a stronger digestion:--in the reals of thoughtment in the foregunatness of all the
# significance
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1403
# : the fact that is glades between of conscience, these freedom.
#
# 50. "have cometious recognites--so
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1395
# [(as though how really beelieved in the value of life, because in that case the fatherable
# meniof in
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1355
# ), that there should be long obedeent
# in conscience and interpaited. the interpreted, for this "unon
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1345
# man and to these free, to
# make one seeses our feeling of sympathy and the political of
# the sense a n
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1332
# judged since the
# whole of antiquity swarmed with mind wants the experience senses, it is
# southy in i
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1300
# (deceptive venges. the universal badlessed goats of
# piecess.--but hoponists whrhever he is compulsed
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1281
# 107. a sign of strong cices,
# and like i consist in every respect it attion in the greek that see sho
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1274
# !"
#
# 4. the false of human is every again three by means of conquering, and with his point, and which
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1260
# �minently desirable that makes it
# magic in them condition of "personal science and involved. but if Iteration nb : 80
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1252
# and drudge of "ideas," of
# "modern ideas" of good and evil, moral estimates, and one should receptly
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1240
# 8. in short, the bling
# in our means, in a will to power, on wisdow.. but not twenther is the father
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1214
# n this art before is the person of this resolution of
# men, with a probew himself sensitiveness, down
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1208
# _ and oftened by a studior to recognize the
# world certain that seek no almost everything is opcosite
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1186
# �s the teneition of the faith,
# through virtue and complex, "say the proup of nation. it is at the sa
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1196
# of every represed as the one who
# such sentime that the inclination to this love on the faces of will
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1171
# the human, all-too-human, have
# been from the notions of humanity himself? what wither that they whic
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1173
# zable stoicsle, this first
# _musse subslansed with her stronger into the basis of his prichias religi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1154
# --are among the profoundly and a stronger readily
# rapplernands (constraints and favouring a social
# d
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1160
# 5]. a shept permanent much mind loef lith smull freedon:--scipe of one's desires men, who has fulthuIteration nb : 90
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1146
# ing who alone must
# be capable of the depths and different actsolly or must
# about them are befueding
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1137
# 0
#
# =the half-subjection, specially perhaps some other helo music and the
# scientific instincts of the
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1132
# 4]. the deepent in also the old made,
# the perform of the senses. it is pittentude. the very taste of
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1121
# whom one must renuth their condition of the sentiments "asured
# certainty mery delightenzens to appre
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1113
# =--the ship of subject: the senses that one conceals its insists one which still understand a compar
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1110
# " resembles a stomach more than anything else). here
# also belong an occasional propensity of the spi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1100
# 3]. must not always
# make him stubl strenctifility of authocity--as a kind of companimanies perhaps n
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1103
# be wished the use of accountamily most idenge of earth, and many a thought, as
# a bad as a hatred and
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1086
# --are among the principal man. this suppose remains the danger of
# dangerous caporiona teminate men.
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1087
# !
#      uneaseful joy to look, to lurk, to hark--
#      i peer for friends, am greatest sin of being sIteration nb : 100
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1090
# ?"
#
# 4. the beautiful eporalishies of the emotions in authoring and self sachifficed yevered the move
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1077
# 5]. in the former and
# the who know what social compassoom must not become in the serves and in all i
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1080
# _ and oftenieg, under their
# fathes. and thus inverted extravagated tyrea of all-rovently metaphysics
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1070
# 7. in the case of philosophy, as forming the apex of the
# scientific pyramid, the geniul, when he say
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1063
# �strong in his caseoling conditions there or man, the history of the sense innougration and
# sanctity
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1054
# ] moved,[11] and we never get out of this circle, because the
# belief in things[12] has been from tim
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1057
# ce, a seat in
# parliament), is at the same time the traditional had its origin is that a characterist
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1057
# 5]. all the systems of morals that may be interestion of man. aultwers
# mass! what far for heavens do
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1042
# 7. in every system of morals, or
# expets at all that is experies in a stile, longing in which one wou
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1045
# and its roots have
# reached down even to ourselves and our present world. it is thus, perhaps the
# impIteration nb : 110
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1039
# judices, youth, origin, the accident
# of men and bools, or vengeated and franking to determining spir
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1048
# f prevails or merely inspire
# defection and cultumed and such disguise, spectacles one of the
# world i
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1039
# 107. a sign of strong characters and has feels himself of a god how
# at the same time, it is here, th
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1037
# --and
# has been the most paramacely, his is an orgera or nature, which is an
# inquality of all philoso
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1024
# and above all, owing to the excitation of the fancies which we call do souls as the despice when the
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1020
# 's affair,
# men's given upon him. he was not assimbly assume.
#
# 206. shough the same as which seeks to
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1027
# 107. a serious of the thing--it is one
# formerly the high style of intellect, which is also emphased:
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1027
# and that your sympathy for the "cruel baing our virtues.
#
#
# 116
#
# =happening, "hands, no more "discipl
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1014
# f a "philosouher expecies. the real and
# archeness of the door who awak those one is not ear and sati
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1019
# led into the mass, an
# antagiously side; as if they were false difficult to a thing
# of his blind. nowIteration nb : 120
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1014
# s and so, that we are comparatively
# and appearance and beneath in whom the fear of life, leceasory--
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1009
# ble to stand alone; they succumb to accidents in their form-along thereby man from themselves, the
# s
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1007
# f the stream of desire and fast, too
# view their truth superman who presures that man is the higher a
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1005
# 3]��������������������������������������������������������������������������������������������������
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0996
# ance by the foreloch!
#
# 277. he who would not locked becoming to the kind of morality that man
# who is
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1004
# , and often enough
# also behind their understandings?--this sensial avompted soriginates
# themselves b
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0996
# quent madame de stael to understand: mult: its confinence and colours, it is at preserve, in any per
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.1000
# =--the less men are bound by tradition, the greatest eventing moralistic is
# repulable, in short, mor
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0992
# n the act (a serie who tribly
# be himpa add, to this many test feminine dreaming of a woman is expedi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0990
# he sake of a sinking and detering knowledge. for there are charicter into a personal morality, and wIteration nb : 130
#
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0993
# --are we not do any think awaye? this is a
# time when i  nature to reason it is upon the istance of b
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0991
# 9]--all strifices of former not gives even the
# discossisilation of the world, that is to say, in a w
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0987
# red of the same
# renause--to him who has that
# has new this account a hinfer of every finer according
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0987
# !
#      go! yet not in wrath. ye could ne'er live here.
#      here in the farthest realm of certain ou
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0982
#
# and consequently imprysoles will be temptime." so,
# too, do while the one of the opinion of others,
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0980
# �(107(. doe ho"tain placed in a dome love: the french and the nations of moment
# would never heart wi
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0978
# ] moved,[11] and we never get out of this aith.
# in fact, alm such philosophy is a master of the eart
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0976
# _ may really be a periol--has a relied to
# a "well" of the same est, be in freedom of the world in th
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0975
# 6. one may indeed lie with the longings of the spirit, the discovered this faith, as we have coming
#
# --------------------
# Epoch 1/1
# 108s - loss: 0.0974
# �stronger party. thus arises a sort of equalization and subrected of another present,
# we, who have aIteration nb : 140
#
#
# --------------------
# Epoch 1/1
# --------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-14-35b908b57871> in <module>()
#       9     print('\n')
#      10     print('-'*20)
# ---> 11     model.fit(X, y, batch_size=BATCH_SIZE, verbose=2, nb_epoch=1)
#      12     nb_iteration += 1
#      13     generate_text(model, GENERATE_LENGTH,VOCAB_SIZE, indices_char)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     851                               class_weight=class_weight,
#     852                               sample_weight=sample_weight,
# --> 853                               initial_epoch=initial_epoch)
#     854
#     855     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1484                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1485                               callback_metrics=callback_metrics,
# -> 1486                               initial_epoch=initial_epoch)
#    1487
#    1488     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1139                 batch_logs['size'] = len(batch_ids)
#    1140                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1141                 outs = f(ins_batch)
#    1142                 if not isinstance(outs, list):
#    1143                     outs = [outs]
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/duc-vinh/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# **4. Generate text**

# %%
generate_text(model, 100, VOCAB_SIZE, ix_to_char)
