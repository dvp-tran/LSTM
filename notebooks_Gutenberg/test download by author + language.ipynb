# %%
# bulkdownload.py
#
# Downloads all eBooks from a mirror of Project Gutenberg's website, for a specific language.
#
# Software by Michiel Overtoom, motoom@xs4all.nl, July 2009, March 2012. Adapted in 2016 for mirrors.

'''
Scraping eBooks from Gutenbergs web site isn't allowed anymore.
Instead, you look in http://www.gutenberg.org/MIRRORS.ALL for a mirror nearby you.
You might want to choose a HTTP mirror because FTP mirrors are slow with urllib.urlretrieve (but FTP mirrors are OK if you can use wget).
Choose a suitable mirror URL and put it in the MIRROR variable below.

The program then fetches {MIRROR}/GUTINDEX.ZIP, which is the compressed book index.
In this zip is a textfile called GUTINDEX.ALL, in it every eBook is listed starting on the beginning
of a line, followed by lines of attributes:

    Zur Psychopathologie des Alltagslebens, by Sigmund Freud                 24429
      [Subtitle: Uber Vergessen, Versprechen, Vergreifen, Aberglaube und Irrtum]
      [Language: German]
    Hempfield, by David Grayson                                              33251
     [Subtitle: A Novel]
     [Illustrator: Thomas Fogarty]
    De slavernij in Suriname, by Julien Wolbers                              31060
     [Subtitle: of dezelfde gruwelen der slavernij, die in de 'Negerhut'
      geschetst zijn, bestaan ook in onze West-Indische Kolonien]
     [Language: Dutch]
    De schipbreuk van de "Berlin" 21 Februari 1907, by Jean Louis Pisuisse   33254
     [Subtitle: Volledig verhaal van de scheepsramp
      aan den Hoek van Holland]
     [Illustrator: Louis Raemaekers]
     [Language: Dutch]

The first line has a title and an eBook id number ("De slavernij in Suriname, by J.W.  31060").
Now, where to find the eBook text 31060?
For that, the program fetches {MIRROR}/ls-lR.gz, which contains the compressed directory & file index
in a textfile called 'ls-lR'. It contains chunks like:

    ./3/1/0/6/31060:
    total 156
    -rw-rw-r-- 1 gbnewby pg 77617 Jan 24  2010 31060-8.txt
    -rw-rw-r-- 1 gbnewby pg 29926 Jan 24  2010 31060-8.zip
    drwxrwxr-x 3 gbnewby pg  4096 Jan 24  2010 31060-h
    -rw-rw-r-- 1 gbnewby pg 35794 Jan 24  2010 31060-h.zip

We're interested in the file '31060-0.zip', '31060-8.zip' or '31060.zip'.
From the chunk above we learn it can be found in the directory /3/1/0/6/31060, thus:

    {MIRROR}/3/1/0/6/31060/31060-8.zip

This file is downloaded in the directory 'ebooks-zipped', and contains the eBook text '31060-8.txt',
which is eventually extracted into 'ebooks-unzipped'. Other programs take it from there.

'''


import urllib
import re
import os
import zipfile
import gzip
import datetime
import codecs
import glob
import shutil

MIRROR = "http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/"
LANGUAGE = "French"


def older(a, b):
    '''Return True is file 'a' is older than file 'b'.'''
    if not os.path.exists(a) or not os.path.exists(b):
        return False
    sta = os.stat(a)
    stb = os.stat(b)
    return sta <= stb


def fetch(mirrorurl, filename, outputfilename):
    '''Fetch a file from a gutenberg mirror, if it hasn't been fetched earlier today.'''
    mustdownload = False
    if os.path.exists(filename):
        st = os.stat(filename)
        modified = datetime.date.fromtimestamp(st.st_mtime)
        today = datetime.date.today()
        if modified == today:
            print "%s exists, and is up-to-date. No need to download it." % filename
        else:
            print "%d exists, but is out of date. Downloading..." % filename
            mustdownload = True
    else:
        print "%s not found, downloading..." % filename
        mustdownload = True

    if mustdownload:
        url = mirrorurl + filename
        urllib.urlretrieve(url, outputfilename)


# Ensure directories exist.
if not os.path.exists("../data/Gutenberg"):
    os.mkdir("../data/Gutenberg")
if not os.path.exists("../data/Gutenberg/indexes"):
    os.mkdir("../data/Gutenberg/indexes/")

if not os.path.exists("../data/Gutenberg/ebooks-zipped"):
    os.mkdir("../data/Gutenberg/ebooks-zipped/")

if not os.path.exists("../data/Gutenberg/ebooks-unzipped"):
    os.mkdir("../data/Gutenberg/ebooks-unzipped/")


# Download the book index, and unzip it.
fetch(MIRROR, "GUTINDEX.zip", "../data/Gutenberg/indexes/GUTINDEX.zip")
if not os.path.exists("../data/Gutenberg/indexes/GUTINDEX.ALL") or older("../data/Gutenberg/indexes/GUTINDEX.ALL",
                                                                         "../data/Gutenberg/indexes/GUTINDEX.zip"):
    print "Extracting GUTINDEX.ALL from GUTINDEX.zip..."
    zipfile.ZipFile("../data/Gutenberg/indexes/GUTINDEX.zip").extractall("../data/Gutenberg/indexes/")


# Download the file index, and gunzip it.
fetch(MIRROR, "ls-lR.gz", "../data/Gutenberg/indexes/ls-lR.gz")
if not os.path.exists("../data/Gutenberg/indexes/ls-lR") or older("../data/Gutenberg/indexes/ls-lR",
                                                                  "../data/Gutenberg/indexes/ls-lR.gz"):
    print "Extracting ls-lR from ls-lR.gz..."
    inf = gzip.open("../data/Gutenberg/indexes/ls-lR.gz", "rb")
    outf = open("../data/Gutenberg/indexes/ls-lR", "wb")
    outf.write(inf.read())
    inf.close()
    outf.close()


# Parse the file index
print "Parsing file index..."
mirrordir = {}
mirrorname = {}
re_txt0file = re.compile(r".*? (\d+\-0\.zip)") # UTF-8 encoded (?)
re_txt8file = re.compile(r".*? (\d+\-8\.zip)") # latin-8 encoded (?)
re_txtfile = re.compile(r".*? (\d+\.zip)") # ascii encoded 
for line in open("../data/Gutenberg/indexes/ls-lR"):
    if line.startswith("./"):
        line = line[2:].strip()
        if line.endswith(":"):
            line = line[:-1]
        if line.endswith("old") or "-" in line:
            continue
        lastseendir = line
        continue
    m = re_txt0file.match(line)
    if not m:
        m = re_txt8file.match(line)
    if not m:
        m = re_txtfile.match(line)
    if m:
        filename = m.groups()[0]
        if "-" in filename: # For filenames like '12104-0.zip'.
            nr, _ = filename.split("-")
        elif "." in filename: # For filenames like '32901.zip'.
            nr, _ = filename.split(".")
        else:
            print "Unexpected filename:", filename
        ebookno = int(nr)
        if not ebookno in mirrordir:
            mirrordir[ebookno] = lastseendir
            mirrorname[ebookno] = filename


# Parse the GUTINDEX.ALL file and extract all language-specific titles from it.
print "Parsing book index..."
inpreamble = True
ebooks = {} # number -> title
ebookslanguage = {} # number -> language
ebookno = None
nr = 0
langre = re.compile(r"\[Language: (\w+)\]")
for line in codecs.open("../data/Gutenberg/indexes/GUTINDEX.ALL", encoding="utf8"):
    line = line.replace(u"\xA0", u" ") # Convert non-breaking spaces to ordinary spaces.

    if inpreamble: # Skip the explanation at the start of the file.
        if "TITLE and AUTHOR" in line and "ETEXT NO." in line:
            inpreamble = False
        else:
            continue

    if not line.strip():
        continue # Ignore empty lines.

    if line.startswith("<==End of GUTINDEX.ALL"):
        break # Done.

    if line.startswith((u" ", u"\t", u"[")):
        # Attribute line; see if it specifies the language.
        m = langre.search(line)
        if m:
            language = m.group(1)
            ebookslanguage[ebookno] = language
    else:
        # Possibly title line: "The German Classics     51389"
        parts = line.strip().rsplit(" ", 1)
        if len(parts) < 2:
            continue
        title, ebookno = parts
        title = title.strip()
        try:
            if ebookno.endswith(("B", "C")):
                ebookno = ebookno[:-1]
            ebookno = int(ebookno)
            # It's a genuine title.
            ebooks[ebookno] = title
        except ValueError:
            continue # Missing or invalid ebook number

# Default language is English; mark every eBook which hasn't a language specified as English.
for nr, title in ebooks.iteritems():
    if not nr in ebookslanguage:
        ebookslanguage[nr] = "English"

if 0:
    # Print report of found eBooks.
    nr = 0
    for ebookno in sorted(ebooks.keys()):
        if ebookslanguage[ebookno] != LANGUAGE:
            continue
        titel = ebooks[ebookno].encode("ascii", "replace")
        filename = mirrorname.get(ebookno, "UNKNOWN")
        filedir = mirrordir.get(ebookno, "UNKNOWN")
        print "%d. %s (%s in %s)" % (ebookno, titel, filename, filedir)
        nr += 1
    print "%d ebooks found for language %s" % (nr, LANGUAGE)

# Fetch the eBook zips.
for nr, ebookno in enumerate(sorted(ebooks.keys())):
    if ebookslanguage[ebookno] != LANGUAGE: # Only fetch books for specified language.
        continue
    filedir = mirrordir.get(ebookno)
    filename = mirrorname.get(ebookno)
    if not filedir or not filename:
        continue
    url = MIRROR + filedir + "/" + filename
    fn = os.path.join("../data/Gutenberg/ebooks-zipped", filename)
    if os.path.exists(fn):
        print "(%d/%d) %s exists, download not necessary" % (nr, len(ebooks), fn)
    else:
        print "(%d/%d) downloading %s..." % (nr, len(ebooks), fn)
        # Slow with FTP mirrors; prefer a HTTP mirror.
        urllib.urlretrieve(url, fn)

        # Fast, but requires external wget utility.
        # cmd = "wget -O %s %s" % (fn, url)
        # os.system(cmd)
# Out:
# GUTINDEX.zip not found, downloading...
# ls-lR.gz not found, downloading...
# Parsing file index...
# Parsing book index...
# (248/54439) ../data/Gutenberg/ebooks-zipped/249.zip exists, download not necessary
# (795/54439) ../data/Gutenberg/ebooks-zipped/796-0.zip exists, download not necessary
# (796/54439) ../data/Gutenberg/ebooks-zipped/797-8.zip exists, download not necessary
# (797/54439) ../data/Gutenberg/ebooks-zipped/798-8.zip exists, download not necessary
# (798/54439) ../data/Gutenberg/ebooks-zipped/799-0.zip exists, download not necessary
# (799/54439) ../data/Gutenberg/ebooks-zipped/800-8.zip exists, download not necessary
# (800/54439) ../data/Gutenberg/ebooks-zipped/801-8.zip exists, download not necessary
# (801/54439) ../data/Gutenberg/ebooks-zipped/802-8.zip exists, download not necessary
# (802/54439) ../data/Gutenberg/ebooks-zipped/803-8.zip exists, download not necessary
# (1255/54439) ../data/Gutenberg/ebooks-zipped/1256-0.zip exists, download not necessary
# (1338/54439) ../data/Gutenberg/ebooks-zipped/1339-0.zip exists, download not necessary
# (1909/54439) ../data/Gutenberg/ebooks-zipped/1910.zip exists, download not necessary
# (1980/54439) ../data/Gutenberg/ebooks-zipped/1981.zip exists, download not necessary
# (2417/54439) ../data/Gutenberg/ebooks-zipped/2419-0.zip exists, download not necessary
# (2648/54439) ../data/Gutenberg/ebooks-zipped/2650-0.zip exists, download not necessary
# (2680/54439) ../data/Gutenberg/ebooks-zipped/2682-8.zip exists, download not necessary
# (2996/54439) ../data/Gutenberg/ebooks-zipped/2998-0.zip exists, download not necessary
# (2997/54439) downloading ../data/Gutenberg/ebooks-zipped/2999-0.zip...
# (2998/54439) downloading ../data/Gutenberg/ebooks-zipped/3000-0.zip...
# (3454/54439) downloading ../data/Gutenberg/ebooks-zipped/3456-8.zip...
# (3642/54439) downloading ../data/Gutenberg/ebooks-zipped/3644-8.zip...
# (3643/54439) downloading ../data/Gutenberg/ebooks-zipped/3645-8.zip...
# (4545/54439) downloading ../data/Gutenberg/ebooks-zipped/4548-8.zip...
# (4556/54439) downloading ../data/Gutenberg/ebooks-zipped/4559-8.zip...
# (4558/54439) downloading ../data/Gutenberg/ebooks-zipped/4561-8.zip...
# (4559/54439) downloading ../data/Gutenberg/ebooks-zipped/4562-8.zip...
# (4560/54439) downloading ../data/Gutenberg/ebooks-zipped/4563-8.zip...
# (4561/54439) downloading ../data/Gutenberg/ebooks-zipped/4564-8.zip...
# (4562/54439) downloading ../data/Gutenberg/ebooks-zipped/4565-8.zip...
# (4563/54439) downloading ../data/Gutenberg/ebooks-zipped/4566-8.zip...
# (4564/54439) downloading ../data/Gutenberg/ebooks-zipped/4567-8.zip...
# (4565/54439) downloading ../data/Gutenberg/ebooks-zipped/4568-8.zip...
# (4566/54439) downloading ../data/Gutenberg/ebooks-zipped/4569-8.zip...
# (4644/54439) downloading ../data/Gutenberg/ebooks-zipped/4647.zip...
# (4645/54439) downloading ../data/Gutenberg/ebooks-zipped/4648.zip...
# (4646/54439) downloading ../data/Gutenberg/ebooks-zipped/4649.zip...
# (4647/54439) downloading ../data/Gutenberg/ebooks-zipped/4650-8.zip...
# (4648/54439) downloading ../data/Gutenberg/ebooks-zipped/4651-8.zip...
# (4684/54439) downloading ../data/Gutenberg/ebooks-zipped/4688-8.zip...
# (4704/54439) downloading ../data/Gutenberg/ebooks-zipped/4708-8.zip...
# (4713/54439) downloading ../data/Gutenberg/ebooks-zipped/4717-8.zip...
# (4714/54439) downloading ../data/Gutenberg/ebooks-zipped/4718-8.zip...
# (4736/54439) downloading ../data/Gutenberg/ebooks-zipped/4740-8.zip...
# (4767/54439) downloading ../data/Gutenberg/ebooks-zipped/4771-8.zip...
# (4768/54439) downloading ../data/Gutenberg/ebooks-zipped/4772-8.zip...
# (4787/54439) downloading ../data/Gutenberg/ebooks-zipped/4791-8.zip...
# (4928/54439) downloading ../data/Gutenberg/ebooks-zipped/4933-8.zip...
# (4930/54439) downloading ../data/Gutenberg/ebooks-zipped/4935-0.zip...
# (4931/54439) downloading ../data/Gutenberg/ebooks-zipped/4936-0.zip...
# (4963/54439) downloading ../data/Gutenberg/ebooks-zipped/4968-8.zip...
# (5076/54439) downloading ../data/Gutenberg/ebooks-zipped/5081-8.zip...
# (5077/54439) downloading ../data/Gutenberg/ebooks-zipped/5082-0.zip...
# (5090/54439) downloading ../data/Gutenberg/ebooks-zipped/5095-8.zip...
# (5091/54439) downloading ../data/Gutenberg/ebooks-zipped/5096-8.zip...
# (5092/54439) downloading ../data/Gutenberg/ebooks-zipped/5097-8.zip...
# (5100/54439) downloading ../data/Gutenberg/ebooks-zipped/5105-8.zip...
# (5121/54439) downloading ../data/Gutenberg/ebooks-zipped/5126-0.zip...
# (5125/54439) downloading ../data/Gutenberg/ebooks-zipped/5130-8.zip...
# (5133/54439) downloading ../data/Gutenberg/ebooks-zipped/5138-8.zip...
# (5142/54439) downloading ../data/Gutenberg/ebooks-zipped/5147-8.zip...
# (5149/54439) downloading ../data/Gutenberg/ebooks-zipped/5154-8.zip...
# (5153/54439) downloading ../data/Gutenberg/ebooks-zipped/5158-8.zip...
# (5173/54439) downloading ../data/Gutenberg/ebooks-zipped/5178-8.zip...
# (5245/54439) downloading ../data/Gutenberg/ebooks-zipped/5250-8.zip...
# (5253/54439) downloading ../data/Gutenberg/ebooks-zipped/5258-8.zip...
# (5313/54439) downloading ../data/Gutenberg/ebooks-zipped/5318-8.zip...
# (5418/54439) downloading ../data/Gutenberg/ebooks-zipped/5423-0.zip...
# (5638/54439) downloading ../data/Gutenberg/ebooks-zipped/5644-8.zip...
# (5705/54439) downloading ../data/Gutenberg/ebooks-zipped/5711-8.zip...
# (5775/54439) downloading ../data/Gutenberg/ebooks-zipped/5781-8.zip...
# (5885/54439) downloading ../data/Gutenberg/ebooks-zipped/5892-8.zip...
# (6092/54439) downloading ../data/Gutenberg/ebooks-zipped/6099-8.zip...
# (6302/54439) downloading ../data/Gutenberg/ebooks-zipped/6309-8.zip...
# (6311/54439) downloading ../data/Gutenberg/ebooks-zipped/6318-8.zip...
# (6312/54439) downloading ../data/Gutenberg/ebooks-zipped/6319-0.zip...
# (6370/54439) downloading ../data/Gutenberg/ebooks-zipped/6377-0.zip...
# (6463/54439) downloading ../data/Gutenberg/ebooks-zipped/6470-8.zip...
# (6477/54439) downloading ../data/Gutenberg/ebooks-zipped/6484-8.zip...
# (6490/54439) downloading ../data/Gutenberg/ebooks-zipped/6497-0.zip...
# (6494/54439) downloading ../data/Gutenberg/ebooks-zipped/6501-0.zip...
# (6551/54439) downloading ../data/Gutenberg/ebooks-zipped/6558-8.zip...
# (6684/54439) downloading ../data/Gutenberg/ebooks-zipped/6691-8.zip...
# (6732/54439) downloading ../data/Gutenberg/ebooks-zipped/6739-8.zip...
# (6831/54439) downloading ../data/Gutenberg/ebooks-zipped/6838-8.zip...
# (6959/54439) downloading ../data/Gutenberg/ebooks-zipped/6966.zip...
# (6987/54439) downloading ../data/Gutenberg/ebooks-zipped/6994-0.zip...
# (7005/54439) downloading ../data/Gutenberg/ebooks-zipped/7012-8.zip...
# (7166/54439) downloading ../data/Gutenberg/ebooks-zipped/7173-8.zip...
# (7256/54439) downloading ../data/Gutenberg/ebooks-zipped/7263-8.zip...
# (7261/54439) downloading ../data/Gutenberg/ebooks-zipped/7268-8.zip...
# (7435/54439) downloading ../data/Gutenberg/ebooks-zipped/7442-0.zip...
# (7454/54439) downloading ../data/Gutenberg/ebooks-zipped/7461-8.zip...
# (7455/54439) downloading ../data/Gutenberg/ebooks-zipped/7462-8.zip...
# (7762/54439) downloading ../data/Gutenberg/ebooks-zipped/7770-8.zip...
# (7763/54439) downloading ../data/Gutenberg/ebooks-zipped/7771-8.zip...
# (7764/54439) downloading ../data/Gutenberg/ebooks-zipped/7772-8.zip...
# (7801/54439) downloading ../data/Gutenberg/ebooks-zipped/7809-8.zip...
# (7804/54439) downloading ../data/Gutenberg/ebooks-zipped/7812-8.zip...
# (7810/54439) downloading ../data/Gutenberg/ebooks-zipped/7818.zip...
# (7846/54439) downloading ../data/Gutenberg/ebooks-zipped/7854-8.zip...
# (8066/54439) downloading ../data/Gutenberg/ebooks-zipped/8074-8.zip...
# (8165/54439) downloading ../data/Gutenberg/ebooks-zipped/8173-8.zip...
# (8166/54439) downloading ../data/Gutenberg/ebooks-zipped/8174-8.zip...
# (8167/54439) downloading ../data/Gutenberg/ebooks-zipped/8175-8.zip...
# (8178/54439) downloading ../data/Gutenberg/ebooks-zipped/8186.zip...
# (8408/54439) downloading ../data/Gutenberg/ebooks-zipped/8416-8.zip...
# (8445/54439) downloading ../data/Gutenberg/ebooks-zipped/8453.zip...
# (8446/54439) downloading ../data/Gutenberg/ebooks-zipped/8454-8.zip...
# (8482/54439) downloading ../data/Gutenberg/ebooks-zipped/8490-8.zip...
# (8512/54439) downloading ../data/Gutenberg/ebooks-zipped/8520-8.zip...
# (8516/54439) downloading ../data/Gutenberg/ebooks-zipped/8524-8.zip...
# (8533/54439) downloading ../data/Gutenberg/ebooks-zipped/8541-8.zip...
# (8552/54439) downloading ../data/Gutenberg/ebooks-zipped/8560-8.zip...
# (8553/54439) downloading ../data/Gutenberg/ebooks-zipped/8561-8.zip...
# (8555/54439) downloading ../data/Gutenberg/ebooks-zipped/8563-8.zip...
# (8642/54439) downloading ../data/Gutenberg/ebooks-zipped/8650-0.zip...
# (8684/54439) downloading ../data/Gutenberg/ebooks-zipped/8692-0.zip...
# (8685/54439) downloading ../data/Gutenberg/ebooks-zipped/8693-0.zip...
# (8704/54439) downloading ../data/Gutenberg/ebooks-zipped/8712-8.zip...
# (8711/54439) downloading ../data/Gutenberg/ebooks-zipped/8719-0.zip...
# (8731/54439) downloading ../data/Gutenberg/ebooks-zipped/8739-8.zip...
# (8814/54439) downloading ../data/Gutenberg/ebooks-zipped/8822-8.zip...
# (8855/54439) downloading ../data/Gutenberg/ebooks-zipped/8863-8.zip...
# (8856/54439) downloading ../data/Gutenberg/ebooks-zipped/8864-8.zip...
# (8868/54439) downloading ../data/Gutenberg/ebooks-zipped/8876-8.zip...
# (8899/54439) downloading ../data/Gutenberg/ebooks-zipped/8907-8.zip...
# (8938/54439) downloading ../data/Gutenberg/ebooks-zipped/8946-8.zip...
# (9045/54439) downloading ../data/Gutenberg/ebooks-zipped/9053-8.zip...
# (9253/54439) downloading ../data/Gutenberg/ebooks-zipped/9261-8.zip...
# (9254/54439) downloading ../data/Gutenberg/ebooks-zipped/9262-8.zip...
# (9445/54439) downloading ../data/Gutenberg/ebooks-zipped/9453-8.zip...
# (9628/54439) downloading ../data/Gutenberg/ebooks-zipped/9637-8.zip...
# (9629/54439) downloading ../data/Gutenberg/ebooks-zipped/9638-8.zip...
# (9630/54439) downloading ../data/Gutenberg/ebooks-zipped/9639-8.zip...
# (9634/54439) downloading ../data/Gutenberg/ebooks-zipped/9643-8.zip...
# (9635/54439) downloading ../data/Gutenberg/ebooks-zipped/9644-8.zip...
# (9636/54439) downloading ../data/Gutenberg/ebooks-zipped/9645-8.zip...
# (9646/54439) downloading ../data/Gutenberg/ebooks-zipped/9655-8.zip...
# (9809/54439) downloading ../data/Gutenberg/ebooks-zipped/9818-8.zip...
# (9815/54439) downloading ../data/Gutenberg/ebooks-zipped/9824-8.zip...
# (9882/54439) downloading ../data/Gutenberg/ebooks-zipped/9891-8.zip...
# (9883/54439) downloading ../data/Gutenberg/ebooks-zipped/9892-8.zip...
# (9884/54439) downloading ../data/Gutenberg/ebooks-zipped/9893-8.zip...
# (9885/54439) downloading ../data/Gutenberg/ebooks-zipped/9894-8.zip...
# (9936/54439) downloading ../data/Gutenberg/ebooks-zipped/9945-8.zip...
# (9967/54439) downloading ../data/Gutenberg/ebooks-zipped/9976-8.zip...
# (10044/54439) downloading ../data/Gutenberg/ebooks-zipped/10053-8.zip...
# (10052/54439) downloading ../data/Gutenberg/ebooks-zipped/10061-8.zip...
# (10151/54439) downloading ../data/Gutenberg/ebooks-zipped/10160-8.zip...
# (10280/54439) downloading ../data/Gutenberg/ebooks-zipped/10289-8.zip...
# (10281/54439) downloading ../data/Gutenberg/ebooks-zipped/10290-8.zip...
# (10337/54439) downloading ../data/Gutenberg/ebooks-zipped/10346-8.zip...
# (10375/54439) downloading ../data/Gutenberg/ebooks-zipped/10384-8.zip...
# (10376/54439) downloading ../data/Gutenberg/ebooks-zipped/10385-8.zip...
# (10433/54439) downloading ../data/Gutenberg/ebooks-zipped/10442-8.zip...
# (10595/54439) downloading ../data/Gutenberg/ebooks-zipped/10604-8.zip...
# (10669/54439) downloading ../data/Gutenberg/ebooks-zipped/10678-8.zip...
# (10671/54439) downloading ../data/Gutenberg/ebooks-zipped/10680-8.zip...
# (10673/54439) downloading ../data/Gutenberg/ebooks-zipped/10682-8.zip...
# (10674/54439) downloading ../data/Gutenberg/ebooks-zipped/10683-8.zip...
# (10676/54439) downloading ../data/Gutenberg/ebooks-zipped/10685-8.zip...
# (10678/54439) downloading ../data/Gutenberg/ebooks-zipped/10687-8.zip...
# (10680/54439) downloading ../data/Gutenberg/ebooks-zipped/10689-8.zip...
# (10688/54439) downloading ../data/Gutenberg/ebooks-zipped/10697-8.zip...
# (10737/54439) downloading ../data/Gutenberg/ebooks-zipped/10746-8.zip...
# (10755/54439) downloading ../data/Gutenberg/ebooks-zipped/10764-8.zip...
# (10759/54439) downloading ../data/Gutenberg/ebooks-zipped/10768-8.zip...
# (10765/54439) downloading ../data/Gutenberg/ebooks-zipped/10774-8.zip...
# (10766/54439) downloading ../data/Gutenberg/ebooks-zipped/10775-8.zip...
# (10815/54439) downloading ../data/Gutenberg/ebooks-zipped/10824-8.zip...
# (10832/54439) downloading ../data/Gutenberg/ebooks-zipped/10841-8.zip...
# (10897/54439) downloading ../data/Gutenberg/ebooks-zipped/10906-8.zip...
# (10944/54439) downloading ../data/Gutenberg/ebooks-zipped/10953-8.zip...
# (10973/54439) downloading ../data/Gutenberg/ebooks-zipped/10982-8.zip...
# (11026/54439) downloading ../data/Gutenberg/ebooks-zipped/11035-8.zip...
# (11027/54439) downloading ../data/Gutenberg/ebooks-zipped/11036-8.zip...
# (11028/54439) downloading ../data/Gutenberg/ebooks-zipped/11037-8.zip...
# (11029/54439) downloading ../data/Gutenberg/ebooks-zipped/11038-8.zip...
# (11033/54439) downloading ../data/Gutenberg/ebooks-zipped/11042-8.zip...
# (11037/54439) downloading ../data/Gutenberg/ebooks-zipped/11046-8.zip...
# (11039/54439) downloading ../data/Gutenberg/ebooks-zipped/11048-8.zip...
# (11040/54439) downloading ../data/Gutenberg/ebooks-zipped/11049-8.zip...
# (11122/54439) downloading ../data/Gutenberg/ebooks-zipped/11131-8.zip...
# (11123/54439) downloading ../data/Gutenberg/ebooks-zipped/11132-8.zip...
# (11166/54439) downloading ../data/Gutenberg/ebooks-zipped/11175-8.zip...
# (11167/54439) downloading ../data/Gutenberg/ebooks-zipped/11176-8.zip...
# (11169/54439) downloading ../data/Gutenberg/ebooks-zipped/11178-8.zip...
# (11190/54439) downloading ../data/Gutenberg/ebooks-zipped/11199-8.zip...
# (11291/54439) downloading ../data/Gutenberg/ebooks-zipped/11300-8.zip...
# (11292/54439) downloading ../data/Gutenberg/ebooks-zipped/11301-8.zip...
# (11371/54439) downloading ../data/Gutenberg/ebooks-zipped/11380-8.zip...
# (11414/54439) downloading ../data/Gutenberg/ebooks-zipped/11423-8.zip...
# (11425/54439) downloading ../data/Gutenberg/ebooks-zipped/11434-8.zip...
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-1-181c03af7088> in <module>()
#     245         print "(%d/%d) downloading %s..." % (nr, len(ebooks), fn)
#     246         # Slow with FTP mirrors; prefer a HTTP mirror.
# --> 247         urllib.urlretrieve(url, fn)
#     248
#     249         # Fast, but requires external wget utility.
#
# /home/paul/anaconda2/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# /home/paul/anaconda2/lib/python2.7/urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     243             except IOError:
#     244                 pass
# --> 245         fp = self.open(url, data)
#     246         try:
#     247             headers = fp.info()
#
# /home/paul/anaconda2/lib/python2.7/urllib.pyc in open(self, fullurl, data)
#     211         try:
#     212             if data is None:
# --> 213                 return getattr(self, name)(url)
#     214             else:
#     215                 return getattr(self, name)(url, data)
#
# /home/paul/anaconda2/lib/python2.7/urllib.pyc in open_http(self, url, data)
#     349         for args in self.addheaders: h.putheader(*args)
#     350         h.endheaders(data)
# --> 351         errcode, errmsg, headers = h.getreply()
#     352         fp = h.getfile()
#     353         if errcode == -1:
#
# /home/paul/anaconda2/lib/python2.7/httplib.pyc in getreply(self, buffering)
#    1194         try:
#    1195             if not buffering:
# -> 1196                 response = self._conn.getresponse()
#    1197             else:
#    1198                 #only add this keyword if non-default for compatibility
#
# /home/paul/anaconda2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /home/paul/anaconda2/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /home/paul/anaconda2/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /home/paul/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
# Unzip them.
errors = []
for fn in glob.glob("../data/Gutenberg/ebooks-zipped/*.zip"):
    print "extracting", fn
    try:
        zipfile.ZipFile(fn).extractall("../data/Gutenberg/ebooks-unzipped/")
    except zipfile.BadZipfile:
        errors.append("Error: can't unzip %s" % fn) # Some files in the Gutenberg archive are damaged.

# Some extracted files will end up in a subdirectory. Move them up into 'ebooks-unzipped' and remove the empty subdirectory.
for dirn in glob.glob("../data/Gutenberg/ebooks-unzipped/*"):
    if os.path.isdir(dirn):
        print "moving", dirn
        for fn in glob.glob(os.path.join(dirn, "*")):
            parts = fn.split(os.sep)
            ofn = os.path.join("../data/Gutenberg/ebooks-unzipped", parts[-1])
            if os.path.exists(ofn):
                os.unlink(ofn)
            shutil.move(fn, "../data/Gutenberg/ebooks-unzipped")
        os.rmdir(dirn)

if errors:
    print "Errors:"
    for error in errors:
        print error
# Out:
# extracting ../data/Gutenberg/ebooks-zipped/10906-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4771-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10346-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8560-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7770-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11037-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5781-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/3000-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/4565-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/801-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10061-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10680-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11300-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8946-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8186.zip
# extracting ../data/Gutenberg/ebooks-zipped/5711-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/2650-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/6497-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/8175-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8174-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11049-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11046-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8520-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4718-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11178-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6691-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/3645-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10768-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7812-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6319-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/5644-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6099-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10687-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/799-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/9637-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11199-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10053-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7461-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7268-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5178-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8490-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8692-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/5147-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10764-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5081-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5126-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/5258-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8561-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4772-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7263-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/2419-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/9639-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9891-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11038-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7442-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/3644-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/796-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/4562-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8173-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11301-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5096-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4566-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4568-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10841-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5250-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8712-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4648.zip
# extracting ../data/Gutenberg/ebooks-zipped/8864-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4740-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5154-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4564-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/2998-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/5082-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/802-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4688-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/803-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9945-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10682-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10678-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10289-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8719-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/10685-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5097-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5095-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/1256-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/798-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8454-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/3456-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/1981.zip
# extracting ../data/Gutenberg/ebooks-zipped/10697-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9824-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10775-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10604-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7771-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6558-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6966.zip
# extracting ../data/Gutenberg/ebooks-zipped/10290-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10982-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9894-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9262-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9053-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4968-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4567-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9892-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7818.zip
# extracting ../data/Gutenberg/ebooks-zipped/9453-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4791-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10160-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6470-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8863-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5138-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4935-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/10824-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10953-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9645-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4548-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10385-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8524-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10442-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8541-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7173-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5892-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9655-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6377-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/8416-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/2999-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/10746-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4649.zip
# extracting ../data/Gutenberg/ebooks-zipped/6994-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/4717-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11132-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8693-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/8876-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6501-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/7462-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7772-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11042-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7809-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8453.zip
# extracting ../data/Gutenberg/ebooks-zipped/797-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4561-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11176-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5158-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9976-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11175-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/249.zip
# extracting ../data/Gutenberg/ebooks-zipped/9643-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6318-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4651-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6484-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/800-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/1910.zip
# extracting ../data/Gutenberg/ebooks-zipped/8650-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/5423-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/7854-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9893-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11131-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10683-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4650-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4563-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9818-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11380-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8563-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10774-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/6739-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5105-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/7012-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4708-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9261-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4647.zip
# extracting ../data/Gutenberg/ebooks-zipped/6838-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4569-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8907-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9638-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10384-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4933-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8074-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5130-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4559-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/5318-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/2682-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11423-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11036-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/4936-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/11048-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/9644-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8822-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/10689-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/8739-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/1339-0.zip
# extracting ../data/Gutenberg/ebooks-zipped/6309-8.zip
# extracting ../data/Gutenberg/ebooks-zipped/11035-8.zip
# moving ../data/Gutenberg/ebooks-unzipped/10685
# moving ../data/Gutenberg/ebooks-unzipped/11046
# moving ../data/Gutenberg/ebooks-unzipped/11035
# moving ../data/Gutenberg/ebooks-unzipped/10697
# moving ../data/Gutenberg/ebooks-unzipped/11037
# moving ../data/Gutenberg/ebooks-unzipped/10841
# moving ../data/Gutenberg/ebooks-unzipped/10290
# moving ../data/Gutenberg/ebooks-unzipped/10775
# moving ../data/Gutenberg/ebooks-unzipped/10678
# moving ../data/Gutenberg/ebooks-unzipped/10385
# moving ../data/Gutenberg/ebooks-unzipped/10289
# moving ../data/Gutenberg/ebooks-unzipped/10687
# moving ../data/Gutenberg/ebooks-unzipped/11036
# moving ../data/Gutenberg/ebooks-unzipped/10682
# moving ../data/Gutenberg/ebooks-unzipped/11038
# moving ../data/Gutenberg/ebooks-unzipped/10768
# moving ../data/Gutenberg/ebooks-unzipped/11049
# moving ../data/Gutenberg/ebooks-unzipped/10982
# moving ../data/Gutenberg/ebooks-unzipped/11042
# moving ../data/Gutenberg/ebooks-unzipped/10384
# moving ../data/Gutenberg/ebooks-unzipped/10689
# moving ../data/Gutenberg/ebooks-unzipped/10683
# moving ../data/Gutenberg/ebooks-unzipped/10604
# moving ../data/Gutenberg/ebooks-unzipped/10680
# moving ../data/Gutenberg/ebooks-unzipped/10824
# moving ../data/Gutenberg/ebooks-unzipped/10346
# moving ../data/Gutenberg/ebooks-unzipped/10160
# Errors:
# Error: can't unzip ../data/Gutenberg/ebooks-zipped/2998-0.zip

# %%
if not os.path.exists("../data/test"):
    os.mkdir("../data/test")
