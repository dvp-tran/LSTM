# %%
# bulkdownload.py
#
# Downloads all eBooks from a mirror of Project Gutenberg's website, for a specific language.
#
# Software by Michiel Overtoom, motoom@xs4all.nl, July 2009, March 2012. Adapted in 2016 for mirrors.

'''
Scraping eBooks from Gutenbergs web site isn't allowed anymore.
Instead, you look in http://www.gutenberg.org/MIRRORS.ALL for a mirror nearby you.
You might want to choose a HTTP mirror because FTP mirrors are slow with urllib.urlretrieve (but FTP mirrors are OK if you can use wget).
Choose a suitable mirror URL and put it in the MIRROR variable below.

The program then fetches {MIRROR}/GUTINDEX.ZIP, which is the compressed book index.
In this zip is a textfile called GUTINDEX.ALL, in it every eBook is listed starting on the beginning
of a line, followed by lines of attributes:

    Zur Psychopathologie des Alltagslebens, by Sigmund Freud                 24429
      [Subtitle: Uber Vergessen, Versprechen, Vergreifen, Aberglaube und Irrtum]
      [Language: German]
    Hempfield, by David Grayson                                              33251
     [Subtitle: A Novel]
     [Illustrator: Thomas Fogarty]
    De slavernij in Suriname, by Julien Wolbers                              31060
     [Subtitle: of dezelfde gruwelen der slavernij, die in de 'Negerhut'
      geschetst zijn, bestaan ook in onze West-Indische Kolonien]
     [Language: Dutch]
    De schipbreuk van de "Berlin" 21 Februari 1907, by Jean Louis Pisuisse   33254
     [Subtitle: Volledig verhaal van de scheepsramp
      aan den Hoek van Holland]
     [Illustrator: Louis Raemaekers]
     [Language: Dutch]

The first line has a title and an eBook id number ("De slavernij in Suriname, by J.W.  31060").
Now, where to find the eBook text 31060?
For that, the program fetches {MIRROR}/ls-lR.gz, which contains the compressed directory & file index
in a textfile called 'ls-lR'. It contains chunks like:

    ./3/1/0/6/31060:
    total 156
    -rw-rw-r-- 1 gbnewby pg 77617 Jan 24  2010 31060-8.txt
    -rw-rw-r-- 1 gbnewby pg 29926 Jan 24  2010 31060-8.zip
    drwxrwxr-x 3 gbnewby pg  4096 Jan 24  2010 31060-h
    -rw-rw-r-- 1 gbnewby pg 35794 Jan 24  2010 31060-h.zip

We're interested in the file '31060-0.zip', '31060-8.zip' or '31060.zip'.
From the chunk above we learn it can be found in the directory /3/1/0/6/31060, thus:

    {MIRROR}/3/1/0/6/31060/31060-8.zip

This file is downloaded in the directory 'ebooks-zipped', and contains the eBook text '31060-8.txt',
which is eventually extracted into 'ebooks-unzipped'. Other programs take it from there.

'''


import urllib
import re
import os
import zipfile
import gzip
import datetime
import codecs
import glob
import shutil

MIRROR = "http://www.mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg/"
LANGUAGE = "English"


def older(a, b):
    '''Return True is file 'a' is older than file 'b'.'''
    if not os.path.exists(a) or not os.path.exists(b):
        return False
    sta = os.stat(a)
    stb = os.stat(b)
    return sta <= stb


def fetch(mirrorurl, filename, outputfilename):
    '''Fetch a file from a gutenberg mirror, if it hasn't been fetched earlier today.'''
    mustdownload = False
    if os.path.exists(filename):
        st = os.stat(filename)
        modified = datetime.date.fromtimestamp(st.st_mtime)
        today = datetime.date.today()
        if modified == today:
            print "%s exists, and is up-to-date. No need to download it." % filename
        else:
            print "%d exists, but is out of date. Downloading..." % filename
            mustdownload = True
    else:
        print "%s not found, downloading..." % filename
        mustdownload = True

    if mustdownload:
        url = mirrorurl + filename
        urllib.urlretrieve(url, outputfilename)


# Ensure directories exist.
if not os.path.exists("../data/Gutenberg"):
    os.mkdir("../data/Gutenberg")
if not os.path.exists("../data/Gutenberg/indexes"):
    os.mkdir("../data/Gutenberg/indexes/")

if not os.path.exists("../data/Gutenberg/ebooks-zipped"):
    os.mkdir("../data/Gutenberg/ebooks-zipped/")

if not os.path.exists("../data/Gutenberg/ebooks-unzipped"):
    os.mkdir("../data/Gutenberg/ebooks-unzipped/")

if not os.path.exists("../data/Gutenberg/ebooks-unzipped/"+LANGUAGE):
    os.mkdir("../data/Gutenberg/ebooks-unzipped/"+LANGUAGE)

# Download the book index, and unzip it.
fetch(MIRROR, "GUTINDEX.zip", "../data/Gutenberg/indexes/GUTINDEX.zip")
if not os.path.exists("../data/Gutenberg/indexes/GUTINDEX.ALL") or older("../data/Gutenberg/indexes/GUTINDEX.ALL",
                                                                         "../data/Gutenberg/indexes/GUTINDEX.zip"):
    print "Extracting GUTINDEX.ALL from GUTINDEX.zip..."
    zipfile.ZipFile("../data/Gutenberg/indexes/GUTINDEX.zip").extractall("../data/Gutenberg/indexes/")


# Download the file index, and gunzip it.
fetch(MIRROR, "ls-lR.gz", "../data/Gutenberg/indexes/ls-lR.gz")
if not os.path.exists("../data/Gutenberg/indexes/ls-lR") or older("../data/Gutenberg/indexes/ls-lR",
                                                                  "../data/Gutenberg/indexes/ls-lR.gz"):
    print "Extracting ls-lR from ls-lR.gz..."
    inf = gzip.open("../data/Gutenberg/indexes/ls-lR.gz", "rb")
    outf = open("../data/Gutenberg/indexes/ls-lR", "wb")
    outf.write(inf.read())
    inf.close()
    outf.close()


# Parse the file index
print "Parsing file index..."
mirrordir = {}
mirrorname = {}
re_txt0file = re.compile(r".*? (\d+\-0\.zip)") # UTF-8 encoded (?)
re_txt8file = re.compile(r".*? (\d+\-8\.zip)") # latin-8 encoded (?)
re_txtfile = re.compile(r".*? (\d+\.zip)") # ascii encoded 
for line in open("../data/Gutenberg/indexes/ls-lR"):
    if line.startswith("./"):
        line = line[2:].strip()
        if line.endswith(":"):
            line = line[:-1]
        if line.endswith("old") or "-" in line:
            continue
        lastseendir = line
        continue
    m = re_txt0file.match(line)
    if not m:
        m = re_txt8file.match(line)
    if not m:
        m = re_txtfile.match(line)
    if m:
        filename = m.groups()[0]
        if "-" in filename: # For filenames like '12104-0.zip'.
            nr, _ = filename.split("-")
        elif "." in filename: # For filenames like '32901.zip'.
            nr, _ = filename.split(".")
        else:
            print "Unexpected filename:", filename
        ebookno = int(nr)
        if not ebookno in mirrordir:
            mirrordir[ebookno] = lastseendir
            mirrorname[ebookno] = filename


# Parse the GUTINDEX.ALL file and extract all language-specific titles from it.
print "Parsing book index..."
inpreamble = True
ebooks = {} # number -> title
ebookslanguage = {} # number -> language
ebookno = None
nr = 0
langre = re.compile(r"\[Language: (\w+)\]")
for line in codecs.open("../data/Gutenberg/indexes/GUTINDEX.ALL", encoding="utf8"):
    line = line.replace(u"\xA0", u" ") # Convert non-breaking spaces to ordinary spaces.

    if inpreamble: # Skip the explanation at the start of the file.
        if "TITLE and AUTHOR" in line and "ETEXT NO." in line:
            inpreamble = False
        else:
            continue

    if not line.strip():
        continue # Ignore empty lines.

    if line.startswith("<==End of GUTINDEX.ALL"):
        break # Done.

    if line.startswith((u" ", u"\t", u"[")):
        # Attribute line; see if it specifies the language.
        m = langre.search(line)
        if m:
            language = m.group(1)
            ebookslanguage[ebookno] = language
    else:
        # Possibly title line: "The German Classics     51389"
        parts = line.strip().rsplit(" ", 1)
        if len(parts) < 2:
            continue
        title, ebookno = parts
        title = title.strip()
        try:
            if ebookno.endswith(("B", "C")):
                ebookno = ebookno[:-1]
            ebookno = int(ebookno)
            # It's a genuine title.
            ebooks[ebookno] = title
        except ValueError:
            continue # Missing or invalid ebook number

# Default language is English; mark every eBook which hasn't a language specified as English.
for nr, title in ebooks.iteritems():
    if not nr in ebookslanguage:
        ebookslanguage[nr] = "English"

if 0:
    # Print report of found eBooks.
    nr = 0
    for ebookno in sorted(ebooks.keys()):
        if ebookslanguage[ebookno] != LANGUAGE:
            continue
        titel = ebooks[ebookno].encode("ascii", "replace")
        filename = mirrorname.get(ebookno, "UNKNOWN")
        filedir = mirrordir.get(ebookno, "UNKNOWN")
        print "%d. %s (%s in %s)" % (ebookno, titel, filename, filedir)
        nr += 1
    print "%d ebooks found for language %s" % (nr, LANGUAGE)

# Fetch the eBook zips.
for nr, ebookno in enumerate(sorted(ebooks.keys())):
    if ebookslanguage[ebookno] != LANGUAGE: # Only fetch books for specified language.
        continue
    filedir = mirrordir.get(ebookno)
    filename = mirrorname.get(ebookno)
    if not filedir or not filename:
        continue
    url = MIRROR + filedir + "/" + filename
    fn = os.path.join("../data/Gutenberg/ebooks-zipped", filename)
    if os.path.exists(fn):
        print "(%d/%d) %s exists, download not necessary" % (nr, len(ebooks), fn)
    else:
        print "(%d/%d) downloading %s..." % (nr, len(ebooks), fn)
        # Slow with FTP mirrors; prefer a HTTP mirror.
        urllib.urlretrieve(url, fn)

        # Fast, but requires external wget utility.
        # cmd = "wget -O %s %s" % (fn, url)
        # os.system(cmd)
# Out:
# GUTINDEX.zip not found, downloading...
# ls-lR.gz not found, downloading...
# Parsing file index...
# Parsing book index...
# (0/54439) downloading ../data/Gutenberg/ebooks-zipped/1.zip...
# (1/54439) downloading ../data/Gutenberg/ebooks-zipped/2.zip...
# (2/54439) downloading ../data/Gutenberg/ebooks-zipped/3.zip...
# (3/54439) downloading ../data/Gutenberg/ebooks-zipped/4.zip...
# (4/54439) downloading ../data/Gutenberg/ebooks-zipped/5.zip...
# (5/54439) downloading ../data/Gutenberg/ebooks-zipped/6.zip...
# (6/54439) downloading ../data/Gutenberg/ebooks-zipped/7.zip...
# (7/54439) downloading ../data/Gutenberg/ebooks-zipped/8.zip...
# (8/54439) downloading ../data/Gutenberg/ebooks-zipped/9.zip...
# (9/54439) downloading ../data/Gutenberg/ebooks-zipped/10.zip...
# (10/54439) downloading ../data/Gutenberg/ebooks-zipped/11-0.zip...
# (11/54439) downloading ../data/Gutenberg/ebooks-zipped/12-0.zip...
# (12/54439) downloading ../data/Gutenberg/ebooks-zipped/13-0.zip...
# (13/54439) downloading ../data/Gutenberg/ebooks-zipped/14.zip...
# (14/54439) downloading ../data/Gutenberg/ebooks-zipped/15.zip...
# (15/54439) downloading ../data/Gutenberg/ebooks-zipped/16-0.zip...
# (16/54439) downloading ../data/Gutenberg/ebooks-zipped/17.zip...
# (17/54439) downloading ../data/Gutenberg/ebooks-zipped/18.zip...
# (18/54439) downloading ../data/Gutenberg/ebooks-zipped/19.zip...
# (19/54439) downloading ../data/Gutenberg/ebooks-zipped/20.zip...
# (20/54439) downloading ../data/Gutenberg/ebooks-zipped/21-0.zip...
# (21/54439) downloading ../data/Gutenberg/ebooks-zipped/22.zip...
# (22/54439) downloading ../data/Gutenberg/ebooks-zipped/23.zip...
# (23/54439) downloading ../data/Gutenberg/ebooks-zipped/24-0.zip...
# (24/54439) downloading ../data/Gutenberg/ebooks-zipped/25.zip...
# (25/54439) downloading ../data/Gutenberg/ebooks-zipped/26.zip...
# (26/54439) downloading ../data/Gutenberg/ebooks-zipped/27.zip...
# (27/54439) downloading ../data/Gutenberg/ebooks-zipped/28.zip...
# (28/54439) downloading ../data/Gutenberg/ebooks-zipped/29.zip...
# (29/54439) downloading ../data/Gutenberg/ebooks-zipped/30.zip...
# (30/54439) downloading ../data/Gutenberg/ebooks-zipped/31.zip...
# (31/54439) downloading ../data/Gutenberg/ebooks-zipped/32-0.zip...
# (32/54439) downloading ../data/Gutenberg/ebooks-zipped/33.zip...
# (33/54439) downloading ../data/Gutenberg/ebooks-zipped/34.zip...
# (34/54439) downloading ../data/Gutenberg/ebooks-zipped/35.zip...
# (35/54439) downloading ../data/Gutenberg/ebooks-zipped/36.zip...
# (36/54439) downloading ../data/Gutenberg/ebooks-zipped/37.zip...
# (37/54439) downloading ../data/Gutenberg/ebooks-zipped/38.zip...
# (38/54439) downloading ../data/Gutenberg/ebooks-zipped/39.zip...
# (40/54439) downloading ../data/Gutenberg/ebooks-zipped/41-0.zip...
# (41/54439) downloading ../data/Gutenberg/ebooks-zipped/42.zip...
# (42/54439) downloading ../data/Gutenberg/ebooks-zipped/43-0.zip...
# (43/54439) downloading ../data/Gutenberg/ebooks-zipped/44-0.zip...
# (44/54439) downloading ../data/Gutenberg/ebooks-zipped/45-0.zip...
# (45/54439) downloading ../data/Gutenberg/ebooks-zipped/46-8.zip...
# (46/54439) downloading ../data/Gutenberg/ebooks-zipped/47-0.zip...
# (47/54439) downloading ../data/Gutenberg/ebooks-zipped/48.zip...
# (48/54439) downloading ../data/Gutenberg/ebooks-zipped/49.zip...
# (49/54439) downloading ../data/Gutenberg/ebooks-zipped/50.zip...
# (50/54439) downloading ../data/Gutenberg/ebooks-zipped/51-0.zip...
# (51/54439) downloading ../data/Gutenberg/ebooks-zipped/52.zip...
# (52/54439) downloading ../data/Gutenberg/ebooks-zipped/53.zip...
# (53/54439) downloading ../data/Gutenberg/ebooks-zipped/54.zip...
# (54/54439) downloading ../data/Gutenberg/ebooks-zipped/55.zip...
# (55/54439) downloading ../data/Gutenberg/ebooks-zipped/56-8.zip...
# (56/54439) downloading ../data/Gutenberg/ebooks-zipped/57.zip...
# (57/54439) downloading ../data/Gutenberg/ebooks-zipped/58.zip...
# (58/54439) downloading ../data/Gutenberg/ebooks-zipped/59.zip...
# (59/54439) downloading ../data/Gutenberg/ebooks-zipped/60-0.zip...
# (60/54439) downloading ../data/Gutenberg/ebooks-zipped/61.zip...
# (61/54439) downloading ../data/Gutenberg/ebooks-zipped/62.zip...
# (62/54439) downloading ../data/Gutenberg/ebooks-zipped/63.zip...
# (63/54439) downloading ../data/Gutenberg/ebooks-zipped/64.zip...
# (64/54439) downloading ../data/Gutenberg/ebooks-zipped/65.zip...
# (65/54439) downloading ../data/Gutenberg/ebooks-zipped/66.zip...
# (66/54439) downloading ../data/Gutenberg/ebooks-zipped/67.zip...
# (67/54439) downloading ../data/Gutenberg/ebooks-zipped/68.zip...
# (68/54439) downloading ../data/Gutenberg/ebooks-zipped/69.zip...
# (69/54439) downloading ../data/Gutenberg/ebooks-zipped/70-0.zip...
# (70/54439) downloading ../data/Gutenberg/ebooks-zipped/71.zip...
# (71/54439) downloading ../data/Gutenberg/ebooks-zipped/72.zip...
# (72/54439) downloading ../data/Gutenberg/ebooks-zipped/73.zip...
# (73/54439) downloading ../data/Gutenberg/ebooks-zipped/74-0.zip...
# (74/54439) downloading ../data/Gutenberg/ebooks-zipped/75.zip...
# (75/54439) downloading ../data/Gutenberg/ebooks-zipped/76-0.zip...
# (76/54439) downloading ../data/Gutenberg/ebooks-zipped/77.zip...
# (77/54439) downloading ../data/Gutenberg/ebooks-zipped/78.zip...
# (78/54439) downloading ../data/Gutenberg/ebooks-zipped/79.zip...
# (79/54439) downloading ../data/Gutenberg/ebooks-zipped/80.zip...
# (80/54439) downloading ../data/Gutenberg/ebooks-zipped/81.zip...
# (81/54439) downloading ../data/Gutenberg/ebooks-zipped/82-0.zip...
# (82/54439) downloading ../data/Gutenberg/ebooks-zipped/83.zip...
# (83/54439) downloading ../data/Gutenberg/ebooks-zipped/84.zip...
# (84/54439) downloading ../data/Gutenberg/ebooks-zipped/85.zip...
# (85/54439) downloading ../data/Gutenberg/ebooks-zipped/86-0.zip...
# (86/54439) downloading ../data/Gutenberg/ebooks-zipped/87.zip...
# (87/54439) downloading ../data/Gutenberg/ebooks-zipped/88.zip...
# (89/54439) downloading ../data/Gutenberg/ebooks-zipped/90.zip...
# (90/54439) downloading ../data/Gutenberg/ebooks-zipped/91-0.zip...
# (91/54439) downloading ../data/Gutenberg/ebooks-zipped/92.zip...
# (92/54439) downloading ../data/Gutenberg/ebooks-zipped/93-0.zip...
# (93/54439) downloading ../data/Gutenberg/ebooks-zipped/94-0.zip...
# (94/54439) downloading ../data/Gutenberg/ebooks-zipped/95-0.zip...
# (95/54439) downloading ../data/Gutenberg/ebooks-zipped/96.zip...
# (96/54439) downloading ../data/Gutenberg/ebooks-zipped/97.zip...
# (97/54439) downloading ../data/Gutenberg/ebooks-zipped/98-0.zip...
# (98/54439) downloading ../data/Gutenberg/ebooks-zipped/99.zip...
# (99/54439) downloading ../data/Gutenberg/ebooks-zipped/100.zip...
# (100/54439) downloading ../data/Gutenberg/ebooks-zipped/101.zip...
# (101/54439) downloading ../data/Gutenberg/ebooks-zipped/102-0.zip...
# (102/54439) downloading ../data/Gutenberg/ebooks-zipped/103.zip...
# (103/54439) downloading ../data/Gutenberg/ebooks-zipped/104.zip...
# (104/54439) downloading ../data/Gutenberg/ebooks-zipped/105-8.zip...
# (105/54439) downloading ../data/Gutenberg/ebooks-zipped/106.zip...
# (106/54439) downloading ../data/Gutenberg/ebooks-zipped/107-8.zip...
# (107/54439) downloading ../data/Gutenberg/ebooks-zipped/108-0.zip...
# (108/54439) downloading ../data/Gutenberg/ebooks-zipped/109.zip...
# (109/54439) downloading ../data/Gutenberg/ebooks-zipped/110-8.zip...
# (110/54439) downloading ../data/Gutenberg/ebooks-zipped/111-0.zip...
# (111/54439) downloading ../data/Gutenberg/ebooks-zipped/112-8.zip...
# (112/54439) downloading ../data/Gutenberg/ebooks-zipped/113.zip...
# (113/54439) downloading ../data/Gutenberg/ebooks-zipped/114.zip...
# (114/54439) downloading ../data/Gutenberg/ebooks-zipped/115.zip...
# (116/54439) downloading ../data/Gutenberg/ebooks-zipped/117.zip...
# (117/54439) downloading ../data/Gutenberg/ebooks-zipped/118.zip...
# (118/54439) downloading ../data/Gutenberg/ebooks-zipped/119-0.zip...
# (119/54439) downloading ../data/Gutenberg/ebooks-zipped/120.zip...
# (120/54439) downloading ../data/Gutenberg/ebooks-zipped/121-0.zip...
# (121/54439) downloading ../data/Gutenberg/ebooks-zipped/122-0.zip...
# (122/54439) downloading ../data/Gutenberg/ebooks-zipped/123.zip...
# (123/54439) downloading ../data/Gutenberg/ebooks-zipped/124.zip...
# (124/54439) downloading ../data/Gutenberg/ebooks-zipped/125-0.zip...
# (125/54439) downloading ../data/Gutenberg/ebooks-zipped/126.zip...
# (126/54439) downloading ../data/Gutenberg/ebooks-zipped/127.zip...
# (127/54439) downloading ../data/Gutenberg/ebooks-zipped/128.zip...
# (128/54439) downloading ../data/Gutenberg/ebooks-zipped/129.zip...
# (129/54439) downloading ../data/Gutenberg/ebooks-zipped/130.zip...
# (130/54439) downloading ../data/Gutenberg/ebooks-zipped/131.zip...
# (131/54439) downloading ../data/Gutenberg/ebooks-zipped/132.zip...
# (132/54439) downloading ../data/Gutenberg/ebooks-zipped/133-0.zip...
# (133/54439) downloading ../data/Gutenberg/ebooks-zipped/134-0.zip...
# (134/54439) downloading ../data/Gutenberg/ebooks-zipped/135-0.zip...
# (135/54439) downloading ../data/Gutenberg/ebooks-zipped/136.zip...
# (136/54439) downloading ../data/Gutenberg/ebooks-zipped/137-0.zip...
# (137/54439) downloading ../data/Gutenberg/ebooks-zipped/138.zip...
# (138/54439) downloading ../data/Gutenberg/ebooks-zipped/139.zip...
# (139/54439) downloading ../data/Gutenberg/ebooks-zipped/140-0.zip...
# (140/54439) downloading ../data/Gutenberg/ebooks-zipped/141-0.zip...
# (141/54439) downloading ../data/Gutenberg/ebooks-zipped/142-0.zip...
# (142/54439) downloading ../data/Gutenberg/ebooks-zipped/143-0.zip...
# (143/54439) downloading ../data/Gutenberg/ebooks-zipped/144-0.zip...
# (144/54439) downloading ../data/Gutenberg/ebooks-zipped/145-8.zip...
# (145/54439) downloading ../data/Gutenberg/ebooks-zipped/146.zip...
# (146/54439) downloading ../data/Gutenberg/ebooks-zipped/147-0.zip...
# (147/54439) downloading ../data/Gutenberg/ebooks-zipped/148-8.zip...
# (148/54439) downloading ../data/Gutenberg/ebooks-zipped/149.zip...
# (149/54439) downloading ../data/Gutenberg/ebooks-zipped/150.zip...
# (150/54439) downloading ../data/Gutenberg/ebooks-zipped/151.zip...
# (151/54439) downloading ../data/Gutenberg/ebooks-zipped/152.zip...

# %%
# Unzip them.
errors = []
for fn in glob.glob("../data/Gutenberg/ebooks-zipped/*.zip"):
    print "extracting", fn
    try:
        zipfile.ZipFile(fn).extractall("../data/Gutenberg/ebooks-unzipped/"+LANGUAGE)
    except zipfile.BadZipfile:
        errors.append("Error: can't unzip %s" % fn) # Some files in the Gutenberg archive are damaged.

# Some extracted files will end up in a subdirectory. Move them up into 'ebooks-unzipped' and remove the empty subdirectory.
for dirn in glob.glob("../data/Gutenberg/ebooks-unzipped/"+LANGUAGE+"/*"):
    if os.path.isdir(dirn):
        print "moving", dirn
        for fn in glob.glob(os.path.join(dirn, "*")):
            parts = fn.split(os.sep)
            ofn = os.path.join("../data/Gutenberg/ebooks-unzipped/"+LANGUAGE, parts[-1])
            if os.path.exists(ofn):
                os.unlink(ofn)
            shutil.move(fn, "../data/Gutenberg/ebooks-unzipped/"+LANGUAGE)
        os.rmdir(dirn)

if errors:
    print "Errors:"
    for error in errors:
        print error

# %%
if not os.path.exists("../data/test"):
    os.mkdir("../data/test")
